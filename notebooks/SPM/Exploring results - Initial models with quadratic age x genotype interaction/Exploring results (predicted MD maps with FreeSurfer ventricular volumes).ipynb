# %% [markdown]
# # Exploring results (predicted MD maps with FreeSurfer ventricular volumes)

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
sys.path.append('/home/grg/git/alfa/')
import multireg_spm12 as mreg
# %matplotlib inline

# %%
paramtype = 'MD_pred'
analysis_name='%s_w_FS_ventvol'%paramtype
analysis_wd = osp.join('/home/grg/spm/analysis_20161219', analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_mask.nii'
excel_fp = '/home/grg/spm/designmatrix3.xls'
print 'Found SPM files:', spm
# Out:
# Found SPM files: ['/home/grg/spm/analysis_20161219/MD_pred_w_FS_ventvol/estimatecontrasts/SPM.mat']

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.original_version(paramtype, excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/spm/designmatrix3.xls looking up column MD_pred ...
# Analysis name: MD_pred_w_FS_ventvol
# Columns used in the model: ['Apoe2-3', 'Apoe2-4', 'Apoe3-3', 'Apoe3-4', 'Apoe4-4', 'age23', 'age24', 'age33', 'age34', 'age44', 'agesq23', 'agesq24', 'agesq33', 'agesq34', 'agesq44', 'Gender(0=female)', 'Years of Education']
# Analysis name: MD_pred_w_FS_ventvol
# Scans (513): [u'/home/grg/spm/MD_pred/10070_MD_pred.nii', u'/home/grg/spm/MD_pred/10102_MD_pred.nii', u'/home/grg/spm/MD_pred/10108_MD_pred.nii', u'/home/grg/spm/MD_pred/10235_MD_pred.nii', u'/home/grg/spm/MD_pred/10365_MD_pred.nii', u'/home/grg/spm/MD_pred/10419_MD_pred.nii', u'/home/grg/spm/MD_pred/10463_MD_pred.nii', u'/home/grg/spm/MD_pred/10530_MD_pred.nii', u'/home/grg/spm/MD_pred/10551_MD_pred.nii', u'/home/grg/spm/MD_pred/10563_MD_pred.nii', u'/home/grg/spm/MD_pred/10576_MD_pred.nii', u'/home/grg/spm/MD_pred/10630_MD_pred.nii', u'/home/grg/spm/MD_pred/10668_MD_pred.nii', u'/home/grg/spm/MD_pred/10692_MD_pred.nii', u'/home/grg/spm/MD_pred/10693_MD_pred.nii', u'/home/grg/spm/MD_pred/10703_MD_pred.nii', u'/home/grg/spm/MD_pred/10725_MD_pred.nii', u'/home/grg/spm/MD_pred/10737_MD_pred.nii', u'/home/grg/spm/MD_pred/10756_MD_pred.nii', u'/home/grg/spm/MD_pred/10809_MD_pred.nii', u'/home/grg/spm/MD_pred/11045_MD_pred.nii', u'/home/grg/spm/MD_pred/11047_MD_pred.nii', u'/home/grg/spm/MD_pred/11048_MD_pred.nii', u'/home/grg/spm/MD_pred/11133_MD_pred.nii', u'/home/grg/spm/MD_pred/11180_MD_pred.nii', u'/home/grg/spm/MD_pred/11225_MD_pred.nii', u'/home/grg/spm/MD_pred/11262_MD_pred.nii', u'/home/grg/spm/MD_pred/11305_MD_pred.nii', u'/home/grg/spm/MD_pred/11351_MD_pred.nii', u'/home/grg/spm/MD_pred/11360_MD_pred.nii', u'/home/grg/spm/MD_pred/11387_MD_pred.nii', u'/home/grg/spm/MD_pred/11407_MD_pred.nii', u'/home/grg/spm/MD_pred/11414_MD_pred.nii', u'/home/grg/spm/MD_pred/11416_MD_pred.nii', u'/home/grg/spm/MD_pred/11550_MD_pred.nii', u'/home/grg/spm/MD_pred/11610_MD_pred.nii', u'/home/grg/spm/MD_pred/11614_MD_pred.nii', u'/home/grg/spm/MD_pred/11638_MD_pred.nii', u'/home/grg/spm/MD_pred/11658_MD_pred.nii', u'/home/grg/spm/MD_pred/11721_MD_pred.nii', u'/home/grg/spm/MD_pred/11737_MD_pred.nii', u'/home/grg/spm/MD_pred/11768_MD_pred.nii', u'/home/grg/spm/MD_pred/11798_MD_pred.nii', u'/home/grg/spm/MD_pred/11803_MD_pred.nii', u'/home/grg/spm/MD_pred/11858_MD_pred.nii', u'/home/grg/spm/MD_pred/11902_MD_pred.nii', u'/home/grg/spm/MD_pred/11941_MD_pred.nii', u'/home/grg/spm/MD_pred/11975_MD_pred.nii', u'/home/grg/spm/MD_pred/11979_MD_pred.nii', u'/home/grg/spm/MD_pred/12032_MD_pred.nii', u'/home/grg/spm/MD_pred/12067_MD_pred.nii', u'/home/grg/spm/MD_pred/12079_MD_pred.nii', u'/home/grg/spm/MD_pred/12121_MD_pred.nii', u'/home/grg/spm/MD_pred/12140_MD_pred.nii', u'/home/grg/spm/MD_pred/12174_MD_pred.nii', u'/home/grg/spm/MD_pred/12244_MD_pred.nii', u'/home/grg/spm/MD_pred/12252_MD_pred.nii', u'/home/grg/spm/MD_pred/12323_MD_pred.nii', u'/home/grg/spm/MD_pred/12324_MD_pred.nii', u'/home/grg/spm/MD_pred/12331_MD_pred.nii', u'/home/grg/spm/MD_pred/12399_MD_pred.nii', u'/home/grg/spm/MD_pred/12425_MD_pred.nii', u'/home/grg/spm/MD_pred/12445_MD_pred.nii', u'/home/grg/spm/MD_pred/12479_MD_pred.nii', u'/home/grg/spm/MD_pred/12484_MD_pred.nii', u'/home/grg/spm/MD_pred/12493_MD_pred.nii', u'/home/grg/spm/MD_pred/12516_MD_pred.nii', u'/home/grg/spm/MD_pred/12637_MD_pred.nii', u'/home/grg/spm/MD_pred/12659_MD_pred.nii', u'/home/grg/spm/MD_pred/12730_MD_pred.nii', u'/home/grg/spm/MD_pred/12783_MD_pred.nii', u'/home/grg/spm/MD_pred/12787_MD_pred.nii', u'/home/grg/spm/MD_pred/12841_MD_pred.nii', u'/home/grg/spm/MD_pred/12920_MD_pred.nii', u'/home/grg/spm/MD_pred/12970_MD_pred.nii', u'/home/grg/spm/MD_pred/12976_MD_pred.nii', u'/home/grg/spm/MD_pred/13008_MD_pred.nii', u'/home/grg/spm/MD_pred/13035_MD_pred.nii', u'/home/grg/spm/MD_pred/13075_MD_pred.nii', u'/home/grg/spm/MD_pred/13090_MD_pred.nii', u'/home/grg/spm/MD_pred/13118_MD_pred.nii', u'/home/grg/spm/MD_pred/13138_MD_pred.nii', u'/home/grg/spm/MD_pred/13235_MD_pred.nii', u'/home/grg/spm/MD_pred/21092_MD_pred.nii', u'/home/grg/spm/MD_pred/44046_MD_pred.nii', u'/home/grg/spm/MD_pred/44205_MD_pred.nii', u'/home/grg/spm/MD_pred/55166_MD_pred.nii', u'/home/grg/spm/MD_pred/55529_MD_pred.nii', u'/home/grg/spm/MD_pred/55538_MD_pred.nii', u'/home/grg/spm/MD_pred/55854_MD_pred.nii', u'/home/grg/spm/MD_pred/66 ...
# Vectors (17)
# Names (17): ['Apoe2-3', 'Apoe2-4', 'Apoe3-3', 'Apoe3-4', 'Apoe4-4', 'age23', 'age24', 'age33', 'age34', 'age44', 'agesq23', 'agesq24', 'agesq33', 'agesq34', 'agesq44', 'Gender(0=female)', 'Years of Education']
# Contrasts (11): [('Apo2-3>Apo2-4', 'T', ['Apoe2-3', 'Apoe2-4'], [1, -1]), ('Apo2-4>Apo3-3', 'T', ['Apoe2-4', 'Apoe3-3'], [1, -1]), ('Apo3-3>Apo3-4', 'T', ['Apoe3-3', 'Apoe3-4'], [1, -1]), ('Apo3-4>Apo4-4', 'T', ['Apoe3-4', 'Apoe4-4'], [1, -1]), ('Main effect ApoE', 'F', [('Apo2-3>Apo2-4', 'T', ['Apoe2-3', 'Apoe2-4'], [1, -1]), ('Apo2-4>Apo3-3', 'T', ['Apoe2-4', 'Apoe3-3'], [1, -1]), ('Apo3-3>Apo3-4', 'T', ['Apoe3-3', 'Apoe3-4'], [1, -1]), ('Apo3-4>Apo4-4', 'T', ['Apoe3-4', 'Apoe4-4'], [1, -1])]), ('C<NC', 'T', ['Apoe2-3', 'Apoe2-4', 'Apoe3-3', 'Apoe3-4', 'Apoe4-4'], [3, -2, 3, -2, -2]), ('C>NC', 'T', ['Apoe2-3', 'Apoe2-4', 'Apoe3-3', 'Apoe3-4', 'Apoe4-4'], [-3, 2, -3, 2, 2]), ('HO<HZ', 'T', ['Apoe2-3', 'Apoe2-4', 'Apoe3-3', 'Apoe3-4', 'Apoe4-4'], [1, 1, 1, 1, -4]), ('HO>HZ', 'T', ['Apoe2-3', 'Apoe2-4', 'Apoe3-3', 'Apoe3-4', 'Apoe4-4'], [-1, -1, -1, -1, 4]), ('HO<All_Age_Squared', 'T', ['agesq23', 'agesq24', 'agesq33', 'agesq34', 'agesq44'], [3, -2, 3, -2, -2]), ('HO>All_Age_Squared', 'T', ['agesq23', 'agesq24', 'agesq33', 'agesq34', 'agesq44'], [-3, 2, -3, 2, 2])]
# # of scans included in the analysis: 513
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-56c7c2338973> in <module>()
#       4 n3 = a.get_node('estimatecontrasts')
#       5 print '# of scans included in the analysis:', len(n1.inputs.in_files)
# ----> 6 display_html(pd.DataFrame([e for e in n3.inputs.contrasts],
#       7              columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
#
# NameError: name 'pd' is not defined

# %%
spm_mat_file = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))[0]
for i in range(6, 12):
    img = osp.join(analysis_wd, 'estimatecontrasts/spmT_00%02d.nii'%i)
    print img
    contrast_name = n3.inputs.contrasts[i-1][0]
    thresholded_map1, threshold1 = map_threshold(img, threshold=0.001, cluster_threshold=0)
    plotting.plot_glass_brain(thresholded_map1,
                      title='(%s) %s - T>%.02f - p<0.001 (uncor.)'%(paramtype, contrast_name, threshold1), colorbar=True,
                      black_bg=True, display_mode='ortho', threshold=threshold1)  
plotting.show()
# Out:
# /home/grg/spm/analysis_20161219/MD_pred_w_FS_ventvol/estimatecontrasts/spmT_0006.nii
# /home/grg/spm/analysis_20161219/MD_pred_w_FS_ventvol/estimatecontrasts/spmT_0007.nii
# /home/grg/spm/analysis_20161219/MD_pred_w_FS_ventvol/estimatecontrasts/spmT_0008.nii
# /home/grg/spm/analysis_20161219/MD_pred_w_FS_ventvol/estimatecontrasts/spmT_0009.nii
# /home/grg/spm/analysis_20161219/MD_pred_w_FS_ventvol/estimatecontrasts/spmT_0010.nii
# /home/grg/spm/analysis_20161219/MD_pred_w_FS_ventvol/estimatecontrasts/spmT_0011.nii

# %%
for i in range(6, 12):
    img = osp.join(analysis_wd, 'estimatecontrasts/spmT_00%02d.nii'%i)
    print img
    contrast_name = n3.inputs.contrasts[i-1][0]
    thresholded_map1, threshold1 = map_threshold(img, threshold=0.001, cluster_threshold=0)

    plot_stat_map(thresholded_map1, threshold=threshold1, row_l=8, start=-32, end=34, step=2,
                  title= '(%s) %s - T>%.02f - p<0.001 (uncor.)'%(paramtype, contrast_name, threshold1))
        
plotting.show()
# Out:
# /home/grg/spm/analysis/MD_corr_w_FS_ventvol/estimatecontrasts/spmT_0006.nii
# Saving to... /tmp/tmpwaeZAm.png
# /home/grg/spm/analysis/MD_corr_w_FS_ventvol/estimatecontrasts/spmT_0007.nii
# Saving to... /tmp/tmpqzLIuA.png
# /home/grg/spm/analysis/MD_corr_w_FS_ventvol/estimatecontrasts/spmT_0008.nii
# Saving to... /tmp/tmp651eFV.png
# /home/grg/spm/analysis/MD_corr_w_FS_ventvol/estimatecontrasts/spmT_0009.nii
# Saving to... /tmp/tmpkkM7K0.png
# /home/grg/spm/analysis/MD_corr_w_FS_ventvol/estimatecontrasts/spmT_0010.nii
# Saving to... /tmp/tmpTKDIHh.png
# /home/grg/spm/analysis/MD_corr_w_FS_ventvol/estimatecontrasts/spmT_0011.nii
# Saving to... /tmp/tmp2ghKv3.png
