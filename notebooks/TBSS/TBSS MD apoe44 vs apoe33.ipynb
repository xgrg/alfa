# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/tbss_apoe44_vs_apoe33/stats/'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'design.con')).readlines() if 'ContrastName' in e]
for i in range(1, 3):
    plot_tbss(osp.join(wd, 'tbss_MD_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -15, 45, step=2, title=tcon[i-1])
# Out:
# /home/grg/tbss_apoe44_vs_apoe33/stats/tbss_MD_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_apoe44_vs_apoe33/stats/tbss_MD_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_apoe44_vs_apoe33/stats/tbss_MD_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_apoe44_vs_apoe33/stats/tbss_MD_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_apoe44_vs_apoe33/stats/tbss_MD_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_apoe44_vs_apoe33/stats/tbss_MD_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpdXgqSf.png (apoe44>apoe33)
# /home/grg/tbss_apoe44_vs_apoe33/stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_apoe44_vs_apoe33/stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_apoe44_vs_apoe33/stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# ...

# %%
for each in tcon:
    print each
# Out:
# apoe44>apoe34
# apoe44<apoe34
# apoe44>apoe24
# apoe44<apoe24
# apoe44>apoe33
# apoe44<apoe33
# apoe44>apoe23
# apoe44<apoe23
# apoe34>apoe33
# apoe34<apoe33
# apoe34>apoe23
# apoe34<apoe23
# apoe34>apoe24
# apoe34<apoe24
# apoe24>apoe33
# apoe24<apoe33
# apoe24>apoe23
# apoe24<apoe23
# apoe23>apoe33
# apoe23<apoe33
# C>NC
# C<NC
# HO<All
# HO>All
# Additive
# (-)

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/tbss/stats/'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'designmat/one_contrast.con')).readlines() if 'ContrastName' in e]
for i in range(1, 2):
    plot_tbss(osp.join(wd, 'tbss_MD_one_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -15, 45, step=2, title=tcon[i-1])
# Out:
# /home/grg/tbss/stats/tbss_MD_one_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss/stats/tbss_MD_one_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss/stats/tbss_MD_one_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss/stats/tbss_MD_one_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss/stats/tbss_MD_one_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss/stats/tbss_MD_one_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpBDg3LY.png (apoe44>apoe33)
