# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/tbss_agesq2/stats/'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'design_companion.con')).readlines() if 'ContrastName' in e]
for i in range(1, 7):
    plot_tbss(osp.join(wd, 'tbss_RD_companion_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'),  -15, 43, row_l=6, step=2, title=tcon[i-1])
# Out:
# /home/grg/tbss_agesq2/stats/tbss_RD_companion_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_companion_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_companion_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_companion_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_companion_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpSYT8Xr.png (Dominant-)
# /home/grg/tbss_agesq2/stats/tbss_RD_companion_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_companion_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_companion_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_companion_tfce_corrp_tstat2.nii.gz probably empty tbss map
# ...
