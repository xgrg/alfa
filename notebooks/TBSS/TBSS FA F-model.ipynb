# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/fmodel/stats/'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'design1.con')).readlines() if 'ContrastName' in e]
for i in range(1, 16):
    plot_tbss(osp.join(wd, 'tbss_FA_fmodel_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), 1, 32, step=2, title=tcon[i-1])
# Out:
# /home/grg/tbss_fmodel/stats/tbss_FA_fmodel_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel/stats/tbss_FA_fmodel_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel/stats/tbss_FA_fmodel_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpByibhh.png (Age(+))
# Saving to... /tmp/tmpqOl5hz.png (Age(-))
# /home/grg/tbss_fmodel/stats/tbss_FA_fmodel_tfce_corrp_tstat3.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel/stats/tbss_FA_fmodel_tfce_corrp_tstat3.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel/stats/tbss_FA_fmodel_tfce_corrp_tstat3.nii.gz probably empty tbss map
# Saving to... /tmp/tmpWawogi.png (Recessive(+))
# /home/grg/tbss_fmodel/stats/tbss_FA_fmodel_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel/stats/tbss_FA_fmodel_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel/stats/tbss_FA_fmodel_tfce_corrp_tstat4.nii.gz probably empty tbss map
# ...
