# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/tbss_fmodel//stats/'
wd2 = '/tmp/bsc_output/data/stats/'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'design1.con')).readlines() if 'ContrastName' in e]
for i in range(2, 3):
    plot_tbss(osp.join(wd, 'tbss_MD_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -15, 43, row_l=6, step=2, title='')
# Out:
# /home/grg/tbss_fmodel//stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel//stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel//stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel//stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel//stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# Saving to... /tmp/tmpG8MEdO.png ()

# %%
for i in range(2, 3):
    plot_tbss(osp.join(wd, 'tbss_MD_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -15, 43, row_l=6, step=2, title='')
# Out:
# /home/grg/tbss_fmodel//stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel//stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel//stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel//stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_fmodel//stats/tbss_MD_tfce_corrp_tstat2.nii.gz probably empty tbss map
# Saving to... /tmp/tmpZt_UqR.png ()

# %%
import nibabel as nib
skel = nib.load('/tmp/bsc_output/data/stats/mean_FA_skeleton_mask.nii.gz')
d = np.array(skel.dataobj)
print len(d[d>0])
skel2 = nib.load('/home/grg/tbss_fmodel/stats/mean_FA_skeleton_mask.nii.gz')
d2 = np.array(skel2.dataobj)
print len(d2[d2>0])
# Out:
# 137832
# 130657

# %%
137832/130657.0
# Out:
# 1.054914776858492

# %%
np.unique(d)
# Out:
# array([ 0.,  1.], dtype=float32)

# %%
d.size
# Out:
# 7221032
