# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/tbss_fazekas/stats/'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'design.con')).readlines() if 'ContrastName' in e]
for i in range(9, 12):
    plot_tbss(osp.join(wd, 'tbss_MD_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -15, 45, step=2, title=tcon[i-1])
# Out:
# /home/grg/tbss_fazekas/stats/tbss_MD_tfce_corrp_tstat9.nii.gz probably empty tbss map
# /home/grg/tbss_fazekas/stats/tbss_MD_tfce_corrp_tstat9.nii.gz probably empty tbss map
# /home/grg/tbss_fazekas/stats/tbss_MD_tfce_corrp_tstat9.nii.gz probably empty tbss map
# /home/grg/tbss_fazekas/stats/tbss_MD_tfce_corrp_tstat9.nii.gz probably empty tbss map
# /home/grg/tbss_fazekas/stats/tbss_MD_tfce_corrp_tstat9.nii.gz probably empty tbss map
# /home/grg/tbss_fazekas/stats/tbss_MD_tfce_corrp_tstat9.nii.gz probably empty tbss map
# Saving to... /tmp/tmpiMEzKw.png (Fazekas)
# Saving to... /tmp/tmpI6s1WH.png (Age)
# Saving to... /tmp/tmpBXbOIn.png (Gender)
