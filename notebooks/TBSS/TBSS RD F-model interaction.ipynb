# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/tbss_agesq2/stats/'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'design_interaction.con')).readlines() if 'ContrastName' in e]
for i in range(1, 7):
    plot_tbss(osp.join(wd, 'tbss_RD_interaction_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), 1, 32, step=2, title=tcon[i-1])
# Out:
# /home/grg/tbss_agesq2/stats/tbss_RD_interaction_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_interaction_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpgc4FLw.png (Recessive(+))
# /home/grg/tbss_agesq2/stats/tbss_RD_interaction_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_interaction_tfce_corrp_tstat2.nii.gz probably empty tbss map
# Saving to... /tmp/tmp0LmtPX.png (Recessive(-))
# /home/grg/tbss_agesq2/stats/tbss_RD_interaction_tfce_corrp_tstat3.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_interaction_tfce_corrp_tstat3.nii.gz probably empty tbss map
# Saving to... /tmp/tmp6jUDal.png (Dominant(+))
# /home/grg/tbss_agesq2/stats/tbss_RD_interaction_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_RD_interaction_tfce_corrp_tstat4.nii.gz probably empty tbss map
# Saving to... /tmp/tmp9A3pgs.png (Dominant(-))
# ...
