# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/tbss_3x65/stats'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'model5.con')).readlines() if 'ContrastName' in e]
for i in range(1, 8):
    plot_tbss(osp.join(wd, 'tbss_FA_model5_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -15, 43, row_l=6, step=2, title=tcon[i-1])
# Out:
# /home/grg/tbss_3x65/stats/tbss_FA_model5_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_3x65/stats/tbss_FA_model5_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_3x65/stats/tbss_FA_model5_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_3x65/stats/tbss_FA_model5_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_3x65/stats/tbss_FA_model5_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmp_6cFjt.png (Education(+))
# /home/grg/tbss_3x65/stats/tbss_FA_model5_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_3x65/stats/tbss_FA_model5_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_3x65/stats/tbss_FA_model5_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_3x65/stats/tbss_FA_model5_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/tbss_3x65/stats/tbss_FA_model5_tfce_corrp_tstat2.nii.gz probably empty tbss map
# ...
