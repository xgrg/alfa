# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/tmp/ALFA_20170915/data/stats'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'model2.con')).readlines() if 'ContrastName' in e]
for i in range(1, 9):
    plot_tbss(osp.join(wd, 'tbss_FA_model2_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -44, -4, axis='y', row_l=6, step=2, title=tcon[i-1])
# Out:
# /tmp/ALFA_20170915/data/stats/tbss_FA_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_FA_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_FA_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_FA_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpaiKgrY.png (Recessive(+))
# /tmp/ALFA_20170915/data/stats/tbss_FA_model2_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_FA_model2_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_FA_model2_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_FA_model2_tfce_corrp_tstat2.nii.gz probably empty tbss map
# Saving to... /tmp/tmpUE6t2u.png (Recessive(-))
# /tmp/ALFA_20170915/data/stats/tbss_FA_model2_tfce_corrp_tstat3.nii.gz probably empty tbss map
# ...

# %%
more /home/grg/bsc_output/data/stats/model4.con
