# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/tbss_agesq2/stats/'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'design_agesq.con')).readlines() if 'ContrastName' in e]
for i in range(1, 5):
    plot_tbss(osp.join(wd, 'tbss_MD_agesq_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), 1, 32, step=2, title=tcon[i-1])
# Out:
# /home/grg/tbss_agesq2/stats/tbss_MD_agesq_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_MD_agesq_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpwNY5NU.png (Agesq+)
# Saving to... /tmp/tmpaVp4qE.png (Agesq-)
# Saving to... /tmp/tmpz_fIEL.png (Age+)
# /home/grg/tbss_agesq2/stats/tbss_MD_agesq_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /home/grg/tbss_agesq2/stats/tbss_MD_agesq_tfce_corrp_tstat4.nii.gz probably empty tbss map
# Saving to... /tmp/tmpqAcPU0.png (Age-)
