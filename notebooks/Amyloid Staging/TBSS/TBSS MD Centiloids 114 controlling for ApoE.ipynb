# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/'
tcon = [e.rstrip('\n').split('"')[-2] for e in open(osp.join(wd, 'model3.con')).readlines() if 'ContrastName' in e]
for i in range(1, 17):
    plot_tbss(osp.join(wd, 'tbss_MD_model3_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -15, 43, row_l=6, step=2, title=tcon[i-1])
# Out:
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_MD_model3_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_MD_model3_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_MD_model3_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_MD_model3_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_MD_model3_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpVSrDa7.png (Centiloids (+))
# Saving to... /tmp/tmphEhVns.png (Centiloids (-))
# Saving to... /tmp/tmp8HwSin.png (Age(+))
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_MD_model3_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_MD_model3_tfce_corrp_tstat4.nii.gz probably empty tbss map
# ...

# %%
more /home/grg/bsc_output/data/stats/model4.con
