# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/'
tcon = [e.rstrip('\n').split('"')[-2] for e in open(osp.join(wd, 'model2.con')).readlines() if 'ContrastName' in e]
for i in range(1, 7):
    plot_tbss(osp.join(wd, 'tbss_L1_model2_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -15, 43, row_l=6, step=2, title=tcon[i-1])
# Out:
# /home/grg/jupyter/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 180205-09:51:16,508 interface WARNING:
# 	 Could not get linked libraries for "which".
# /home/grg/jupyter/local/lib/python2.7/site-packages/nilearn/plotting/displays.py:656: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))
# /home/grg/jupyter/local/lib/python2.7/site-packages/numpy/ma/core.py:2778: UserWarning: Warning: converting a masked element to nan.
#   order=order, subok=True, ndmin=ndmin)
# /home/grg/jupyter/local/lib/python2.7/site-packages/matplotlib/colors.py:943: UserWarning: Warning: converting a masked element to nan.
#   vmin = float(vmin)
# /home/grg/jupyter/local/lib/python2.7/site-packages/matplotlib/colors.py:944: UserWarning: Warning: converting a masked element to nan.
#   vmax = float(vmax)
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpQVROgP.png (Centiloids (+))
# Saving to... /tmp/tmpPc6YrF.png (Centiloids (-))
# Saving to... /tmp/tmpI4_sij.png (Age(+))
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# Saving to... /tmp/tmpujK_tr.png (Age(-))
# Saving to... /tmp/tmpQs2Gjf.png (Gender(m>f))
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat6.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat6.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat6.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat6.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylstaging/stats/tbss_L1_model2_tfce_corrp_tstat6.nii.gz probably empty tbss map
# Saving to... /tmp/tmpY2YE9g.png (Gender(f>m))

# %%
more /home/grg/bsc_output/data/stats/model4.con
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-7a7efa219564> in <module>()
# ----> 1 get_ipython().magic(u'more /home/grg/bsc_output/data/stats/model4.con')
#
# /home/grg/jupyter/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /home/grg/jupyter/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-114> in less(self, arg_s)
#
# /home/grg/jupyter/local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /home/grg/jupyter/local/lib/python2.7/site-packages/ipykernel/zmqshell.pyc in less(self, arg_s)
#     305             cont = self.shell.pycolorize(openpy.read_py_file(arg_s, skip_encoding_cookie=False))
#     306         else:
# --> 307             cont = open(arg_s).read()
#     308         page.page(cont)
#     309
#
# IOError: [Errno 2] No such file or directory: u'/home/grg/bsc_output/data/stats/model4.con'
