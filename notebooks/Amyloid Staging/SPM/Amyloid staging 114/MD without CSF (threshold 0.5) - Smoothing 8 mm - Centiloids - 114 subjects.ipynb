# %% [markdown]
# # MD maps without CSF - threshold 0.5 - smoothing 8 mm - Centiloids

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import multireg_spm12 as mreg
reload(mreg)
# %matplotlib inline

# %%
excel_fp = '/home/grg/SPM/2018/amylstaging_MD_wo_csf5_s8_centiloids.xls'

analysis_name, ext = osp.splitext(osp.split(excel_fp)[1])
paramtype = analysis_name.split('_')[1]
analysis_wd = osp.join(osp.dirname(excel_fp), analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
#aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_wo_csf.nii'
print 'Found SPM files:', spm
# Out:
# Found SPM files: ['/home/grg/SPM/2018/amylstaging_MD_wo_csf5_s8_centiloids/estimatecontrasts/SPM.mat']

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/SPM/2018/amylstaging_MD_wo_csf5_s8_centiloids.xls looking up column MD ...
# Analysis name: amylstaging_MD_wo_csf5_s8_centiloids
# First column: images
# Columns in the model: [u'centiloids', u'age', u'gender']
# Effect of Centiloids
# Effect of Gender
# Effect of Linear age
# Analysis name: amylstaging_MD_wo_csf5_s8_centiloids
# Scans (107): [u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10019_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10044_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10065_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10070_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10137_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10162_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10200_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10225_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10235_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10245_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10319_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10329_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10424_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10515_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10560_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10613_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10627_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10649_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10696_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10711_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10724_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10810_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10881_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/10949_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11042_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11125_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11127_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11132_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11248_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11257_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11262_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11273_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11291_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11387_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11397_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11478_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11514_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11587_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11593_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11656_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11711_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11742_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11745_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11747_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11829_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5_s8/11866_MD_wo_csf_s8.nii', u'/home/grg/data/AmylStaging/d ...
# Vectors (3)
# Names (3): [u'centiloids', u'age', u'gender']
# Contrasts (3): [('Effect Centiloids', 'T', ['centiloids'], [1]), ('Effect Gender', 'T', ['gender'], [1]), ('Effect Linear age', 'T', ['age'], [1])]
# # of scans included in the analysis: 107
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Effect Centiloids</td>
#       <td>T</td>
#       <td>[centiloids]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Effect Gender</td>
#       <td>T</td>
#       <td>[gender]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Effect Linear age</td>
#       <td>T</td>
#       <td>[age]</td>
#       <td>[1.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sections = sections_allcontrasts(analysis_wd, paramtype, axis='z', mode='uncorrected')
# Out:
# /home/grg/SPM/2018/amylstaging_MD_wo_csf5_s8_centiloids/estimatecontrasts/spmT_0001.nii T
# /home/grg/jupyter/local/lib/python2.7/site-packages/nilearn/plotting/displays.py:656: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))
# Saving to... /tmp/tmp14RDas.png
# /home/grg/SPM/2018/amylstaging_MD_wo_csf5_s8_centiloids/estimatecontrasts/spmT_0002.nii T
# Saving to... /tmp/tmpahmGeJ.png
# /home/grg/SPM/2018/amylstaging_MD_wo_csf5_s8_centiloids/estimatecontrasts/spmT_0003.nii T
# Saving to... /tmp/tmp53LUyU.png

# %%
spm_mat_file = '/tmp/analysis_amylstaging/ALFA_data_staging/estimatecontrasts/SPM.mat'
out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
pyAAL.to_dataframe(out)
# Out:
# creating tempfile /tmp/tmpSwRmPd.m
# matlab -nodisplay -nodesktop -nosplash -nojvm -r "addpath('/tmp/analysis_amylstaging/ALFA_data_staging/estimatecontrasts');run('/tmp/tmpSwRmPd');quit"
#
# Contrast: Stage2>Stage1
#      x,y,z {mm}       nom du label % Cluster Nb Vx Cluster % Label  \
# 0    14 -14 -22      Hippocampus_L     82.18           606   53.43
# 1    14 -14 -22  ParaHippocampal_L      9.74           606    6.03
# 2    14 -14 -22         Amygdala_L      6.77           606   18.64
# 3    14 -14 -22            OUTSIDE      0.17           606    0.00
# 4   -36  -2  48    Frontal_Mid_2_L     33.33           489    3.61
# 5   -36  -2  48    Frontal_Sup_2_L     30.47           489    3.06
# 6   -36  -2  48  Supp_Motor_Area_L     24.54           489    5.59
# 7   -36  -2  48       Precentral_L      0.61           489    0.09
# 8   -36  -2  48            OUTSIDE      0.20           489    0.00
# 9    38  -4  52    Frontal_Mid_2_R     23.20           181    0.86
# 10   38  -4  52    Frontal_Sup_2_R     22.65           181    0.80
# 11   38  -4  52       Precentral_R      0.55           181    0.03
# 12   -8 -62 -54      Cerebelum_9_L     29.41            17    0.58
# 13   -8 -62 -54      Cerebelum_8_L     11.76            17    0.11
# 14   -8 -62 -54            OUTSIDE      5.88            17    0.00
# 15   20 -22 -20  ParaHippocampal_R     10.00            10    0.09
# 16   30 -74 -22  Cerebelum_Crus1_R     18.82            85    0.60
# 17   30 -74 -22      Cerebelum_6_R      8.24            85    0.39
# 18   30 -74 -22         Fusiform_R      1.18            85    0.04
# 19  -12 -56  52        Precuneus_L     10.11            89    0.26
# 20  -12 -56  52     Parietal_Sup_L      1.12            89    0.05
#
#    Nb Vx Label
# 0          932
# 1          978
# 2          220
# 3            0
# 4         4509
# 5         4873
# 6         2147
# 7         3526
# 8            0
# 9         4860
# 10        5127
# 11        3381
# 12         869
# 13        1887
# 14           0
# 15        1132
# 16        2648
# 17        1795
# 18        2518
# 19        3528
# 20        2065
