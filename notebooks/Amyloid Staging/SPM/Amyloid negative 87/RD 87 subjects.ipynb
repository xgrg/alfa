# %% [markdown]
# # RD maps with amyloid negative

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import os.path as osp
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import multireg_spm12 as mreg
reload(mreg)
# %matplotlib inline

# %%
excel_fp = '/home/grg/SPM/2018/amylnegative_RD.xls'

analysis_name, ext = osp.splitext(osp.split(excel_fp)[1])
paramtype = analysis_name.split('_')[1]
analysis_wd = osp.join(osp.dirname(excel_fp), analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
#aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/SPM/MNI_T1_brain_wo_csf.nii'
print 'Found SPM files:', spm
pd.read_excel(excel_fp).head()
# Out:
# Found SPM files: ['/home/grg/SPM/2018/amylnegative_RD/estimatecontrasts/SPM.mat']
#                                               images        age  gender  NC  \
# 0  /home/grg/data/AmylStaging/dartel_final/spm/RD...  63.422313       2   1
# 1  /home/grg/data/AmylStaging/dartel_final/spm/RD...  54.757016       1   1
# 2  /home/grg/data/AmylStaging/dartel_final/spm/RD...  50.390144       2   0
# 3  /home/grg/data/AmylStaging/dartel_final/spm/RD...  54.151951       1   1
# 4  /home/grg/data/AmylStaging/dartel_final/spm/RD...  52.878850       1   1
#
#    HT  HO
# 0   0   0
# 1   0   0
# 2   0   1
# 3   0   0
# 4   0   0

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/SPM/2018/amylnegative_RD.xls looking up column RD ...
# Analysis name: amylnegative_RD
# First column: images
# Columns in the model: [u'age', u'gender', u'NC', u'HT', u'HO']
# Non-carriers / Heterozygotes / Homozygotes detected
# Effect of Gender
# Effect of Linear age
# Analysis name: amylnegative_RD
# Scans (82): [u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10019_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10044_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10065_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10070_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10137_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10200_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10225_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10235_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10245_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10424_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10515_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10649_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10711_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10724_RD_s.nii', u
_final/spm/RD/44231_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/44301_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/44329_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/44349_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/44363_RD_s.nii', u'/home/grg/data/AmylStagin ...
# Vectors (5)
# Names (5): [u'age', u'gender', u'NC', u'HT', u'HO']
# Contrasts (5): [('HO>HT', 'T', ['HO', 'HT'], [1, -1]), ('HO>NC', 'T', ['HO', 'NC'], [1, -1]), ('HT>NC', 'T', ['HT', 'NC'], [1, -1]), ('Effect Gender', 'T', ['gender'], [1]), ('Effect Linear age', 'T', ['age'], [1])]
# # of scans included in the analysis: 82
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>HO&gt;HT</td>
#       <td>T</td>
#       <td>[HO, HT]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>HO&gt;NC</td>
#       <td>T</td>
#       <td>[HO, NC]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>HT&gt;NC</td>
#       <td>T</td>
#       <td>[HT, NC]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Effect Gender</td>
#       <td>T</td>
#       <td>[gender]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Effect Linear age</td>
#       <td>T</td>
#       <td>[age]</td>
#       <td>[1.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sections = sections_allcontrasts(analysis_wd, paramtype, axis='z', mode='uncorrected')
# Out:
# /home/grg/SPM/2018/amylnegative_RD/estimatecontrasts/spmT_0001.nii T
# Saving to... /tmp/tmpmTdDb3.png
# /home/grg/SPM/2018/amylnegative_RD/estimatecontrasts/spmT_0002.nii T
# Saving to... /tmp/tmpBKnUm1.png
# /home/grg/SPM/2018/amylnegative_RD/estimatecontrasts/spmT_0003.nii T
# Saving to... /tmp/tmpfyxMbH.png
# /home/grg/SPM/2018/amylnegative_RD/estimatecontrasts/spmT_0004.nii T
# Saving to... /tmp/tmpx7ZUKH.png
# /home/grg/SPM/2018/amylnegative_RD/estimatecontrasts/spmT_0005.nii T
# Saving to... /tmp/tmpxg97Rz.png

# %%
spm_mat_file = spm[0]
print spm_mat_file
out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
pyAAL.to_dataframe(out)
# Out:
# /home/grg/SPM/2018/amylnegative_RD/estimatecontrasts/SPM.mat
# creating tempfile /tmp/tmpryTENZ.m
# matlab -nodisplay -nodesktop -nosplash -nojvm -r "addpath('/home/grg/SPM/2018/amylnegative_RD/estimatecontrasts');run('/tmp/tmpryTENZ');quit"
#
# Contrast: HO>NC
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-fd5f716d6d9d> in <module>()
#       2 print spm_mat_file
#       3 out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
# ----> 4 pyAAL.to_dataframe(out)
#
# /home/grg/git/pyAAL/pyAAL.pyc in to_dataframe(out)
#      80     import pandas as pd
#      81     d = [e.split('\t') for e in out if '\t' in e]
# ---> 82     columns = d[1]
#      83     columns.append('')
#      84     return pd.DataFrame(d[2:], columns=columns)
#
# IndexError: list index out of range
