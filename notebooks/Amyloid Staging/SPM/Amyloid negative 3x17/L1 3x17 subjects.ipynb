# %% [markdown]
# # L1 maps (amyloid negative) - matched groups 3x17

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import amyl_multireg_spm12 as mreg
reload(mreg)
# %matplotlib inline

# %%
excel_fp = '/home/grg/SPM/2018/amylnegmatched_L1.xls'

analysis_name, ext = osp.splitext(osp.split(excel_fp)[1])
paramtype = analysis_name.split('_')[1]
analysis_wd = osp.join(osp.dirname(excel_fp), analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
#aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_wo_csf.nii'
print 'Found SPM files:', spm
# Out:
# Found SPM files: ['/home/grg/SPM/2018/amylnegmatched_L1/estimatecontrasts/SPM.mat']

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/SPM/2018/amylnegmatched_L1.xls looking up column L1 ...
# Analysis name: amylnegmatched_L1
# First column: images
# Columns in the model: [u'age', u'gender', u'NC', u'HT', u'HO']
# Effect of Gender
# Effect of Linear age
# Analysis name: amylnegmatched_L1
# Scans (47): [u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10044_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10065_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10070_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10137_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10225_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10245_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10424_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10515_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10613_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10627_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10696_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10711_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/10724_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11042_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11125_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11248_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11291_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11397_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11593_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11656_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11711_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11745_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11829_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/11866_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/12118_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/12269_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/12279_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/12304_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/12308_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/12778_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/12991_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/13105_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/13244_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/21156_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/44214_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/44231_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/44301_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/44660_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/55210_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/55607_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/55630_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/55777_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/66237_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/66249_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/66488_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/66489_L1_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/L1/77104_L1_s.nii']
# Vectors (5)
# Names (5): [u'age', u'gender', u'NC', u'HT', u'HO']
# Contrasts (2): [('Effect Gender', 'T', ['gender'], [1]), ('Effect Linear age', 'T', ['age'], [1])]
# # of scans included in the analysis: 47
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Effect Gender</td>
#       <td>T</td>
#       <td>[gender]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Effect Linear age</td>
#       <td>T</td>
#       <td>[age]</td>
#       <td>[1.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sections = sections_allcontrasts(analysis_wd, paramtype, axis='z', mode='uncorrected')
# Out:
# /home/grg/SPM/2018/amylnegmatched_L1/estimatecontrasts/spmT_0001.nii T
# Saving to... /tmp/tmpJaT7Uv.png
# /home/grg/SPM/2018/amylnegmatched_L1/estimatecontrasts/spmT_0002.nii T
# Saving to... /tmp/tmp57jTY3.png
# /home/grg/SPM/2018/amylnegmatched_L1/estimatecontrasts/spmT_0003.nii T
# Saving to... /tmp/tmpsmoB0S.png
# /home/grg/SPM/2018/amylnegmatched_L1/estimatecontrasts/spmT_0004.nii T
# Saving to... /tmp/tmpYakRIo.png
# /home/grg/SPM/2018/amylnegmatched_L1/estimatecontrasts/spmT_0005.nii T
# Saving to... /tmp/tmpoOPgGh.png

# %%
spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
pyAAL.to_dataframe(out)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-df042931a3f8> in <module>()
#       1 spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
# ----> 2 out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
#       3 pyAAL.to_dataframe(out)
#
# /home/grg/git/pyAAL/pyAAL.pyc in pyAAL(source, contrast, k, threshold, mode, verbose)
#      87     '''`threshold` is a threshold on the spmT map.'''
#      88
# ---> 89     assert(osp.isfile(source))
#      90     filename, ext = osp.splitext(source)
#      91     workingDir = osp.split(source)[0]
#
# AssertionError:
