# %% [markdown]
# # Comparisons for EPAD (2017-05-16)

# %%
# After running find . > $file on both archives (BSC and UPCnet)
upcnet = open('/tmp/xnat_stats/EPAD_upcnet_20170516.txt').readlines()
bsc = open('/tmp/xnat_stats/EPAD_bsc_20170516.txt').readlines()

# %%
from glob import glob
import pandas as pd
import os.path as osp
upc_dcm = [(e.split('/')[-3], (osp.basename(e)[:-1],e[:-1])) for e in upcnet if e.endswith('.dcm\n')]
bsc_dcm = [(e.split('/')[-3], (osp.basename(e)[:-1], e[:-1])) for e in bsc if e.endswith('.dcm\n')]

# %% [markdown]
# ### Display the first identified DICOM files

# %%
print upc_dcm[:10], bsc_dcm[:10]
# Out:
# [('701', ('1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-210-w26tm4.dcm', './11001/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-210-w26tm4.dcm')), ('701', ('1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-221-w11ycx.dcm', './11001/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-221-w11ycx.dcm')), ('701', ('1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-139-wgyqfm.dcm', './11001/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-139-wgyqfm.dcm')), ('701', ('1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-149-wgg7sd.dcm', './11001/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-149-wgg7sd.dcm')), ('701', ('1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-48-w1n0zt.dcm', './11001/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-48-w1n0zt.dcm')), ('701', ('1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-110-w1ik1l.dcm', './11001/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-110-w1ik1l.dcm')), ('701', ('1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-160-wfv565.dcm', './11001/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-160-wfv565.dcm')), ('701', ('1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-47-w1l40h.dcm', './11001/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-47-w1l40h.dcm')), ('701', ('1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-111-w1n0z7.dcm', './11001/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-111-w1n0z7.dcm')), ('701', ('1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-206-w27gls.dcm', './11001/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.8592.2016101910162506002-701-206-w27gls.dcm'))] [('502', ('1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-32-ggva7u.dcm', './071044060716339/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-32-ggva7u.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-28-ggva75.dcm', './071044060716339/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-28-ggva75.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-20-ggun6t.dcm', './071044060716339/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-20-ggun6t.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-13-ggun6m.dcm', './071044060716339/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-13-ggun6m.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-29-ggva76.dcm', './071044060716339/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-29-ggva76.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-7-ggun5v.dcm', './071044060716339/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-7-ggun5v.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-18-ggun6r.dcm', './071044060716339/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-18-ggun6r.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-6-ggun5u.dcm', './071044060716339/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-6-ggun5u.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-3-ggu068.dcm', './071044060716339/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-3-ggu068.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-36-ggva7y.dcm', './071044060716339/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.4920.2016110311372315002-502-36-ggva7y.dcm'))]

# %% [markdown]
# ### Numbers of existing DICOM files on both sides:

# %%
print 'upc:', len(upc_dcm), 'bsc:', len(bsc_dcm)
# Out:
# upc: 106884 bsc: 106884

# %% [markdown]
# Numbers of non-dicom items:

# %%
nondcm_upcnet = [e[0] for e in upcnet if not '.dcm' in e]
nondcm_bsc = [e[0] for e in bsc if not '.dcm' in e]
print 'upc:', len(nondcm_upcnet), 'bsc:', len(nondcm_bsc)
# Out:
# upc: 2976 bsc: 4040

# %%
# removing all files in upcnet from subject 000000123
#upc_dcm = [(a,(b,e)) for (a, (b,e)) in upc_dcm if not '000123' in e.split('/')[1]]

# %% [markdown]
# Dictionaries by sequences:

# %%
# Creating dictionaries
upc_dict = {}
bsc_dict = {}

for seq, (dcmfile,_) in upc_dcm:
    upc_dict.setdefault(seq, []).append(dcmfile)
for seq, (dcmfile,_) in bsc_dcm:
    bsc_dict.setdefault(seq, []).append(dcmfile)

# %% [markdown]
# ## Matching files between servers for every sequence:

# %% [markdown]
# The good thing is that it appears that all files from BSC find their match on UPCnet.
#
# Yet the opposite is not true.

# %%
results = []
print set(upc_dict.keys()).difference(set(bsc_dict.keys())), 'are in UPC, missing in BSC'
print set(bsc_dict.keys()).difference(set(upc_dict.keys())), 'are in BSC, missing in UPC'
common_sq = set(bsc_dict.keys()).intersection(set(upc_dict.keys()))
print len(common_sq), 'in common'

for each in common_sq:
    row = []
    row.append(len(upc_dict[each]))
    row.append(len(bsc_dict[each]))
    row.append(len(set(upc_dict[each]).difference(set(bsc_dict[each]))))
    row.append(len(set(bsc_dict[each]).difference(set(upc_dict[each]))))
    row.append(len(upc_dict[each]) - len(bsc_dict[each]))
    results.append(row)
pd.DataFrame(results, index=common_sq, columns=['UPCnet', 'BSC', 'upc.diff(bsc)', 'bsc.diff(upc)', 'UPCnet - BSC (raw diff in numbers)'])
# Out:
# set([]) are in UPC, missing in BSC
# set([]) are in BSC, missing in UPC
# 44 in common
#         UPCnet    BSC  upc.diff(bsc)  bsc.diff(upc)  \
# 601      12442  12442              0              0
# 1301      5469   5469              0              0
# 602         80     80              0              0
# 704        352    352              0              0
# 1201      3973   3973              0              0
# 701      26793  26793              0              0
# 1203        60     60              0              0
# 703        176    176              0              0
# 100002       1      1              0              0
# 0          192    192              0              0
# 405        170    170              0              0
# 404        170    170              0              0
# 403        552    552              0              0
# 402       1782   1782              0              0
# 401       8573   8573              0              0
# 506         30     30              0              0
# 507         20     20              0              0
# 504         45     45              0              0
# 502        166    166              0              0
# 503         45     45              0              0
# 501       2924   2924              0              0
# 201         46     46              0              0
# 202         36     36              0              0
# 301       9422   9422              0              0
# 302       1978   1978              0              0
# 303       1550   1550              0              0
# 304        260    260              0              0
# 305         30     30              0              0
# 702         30     30              0              0
# 1501      1512   1512              0              0
# 101        482    482              0              0
# 1401     10752  10752              0              0
# 903         30     30              0              0
# 901      12116  12116              0              0
# 1601       480    480              0              0
# 100004       1      1              0              0
# 100001       1      1              0              0
# 1103        30     30              0              0
# 100003       1      1              0              0
# 1101      1943   1943              0              0
# 805         40     40              0              0
# 801       1471   1471              0              0
# 1003        30     30              0              0
# 1001       628    628              0              0
#
#         UPCnet - BSC (raw diff in numbers)
# 601                                      0
# 1301                                     0
# 602                                      0
# 704                                      0
# 1201                                     0
# 701                                      0
# 1203                                     0
# 703                                      0
# 100002                                   0
# 0                                        0
# 405                                      0
# 404                                      0
# 403                                      0
# 402                                      0
# 401                                      0
# 506                                      0
# 507                                      0
# 504                                      0
# 502                                      0
# 503                                      0
# 501                                      0
# 201                                      0
# 202                                      0
# 301                                      0
# 302                                      0
# 303                                      0
# 304                                      0
# 305                                      0
# 702                                      0
# 1501                                     0
# 101                                      0
# 1401                                     0
# 903                                      0
# 901                                      0
# 1601                                     0
# 100004                                   0
# 100001                                   0
# 1103                                     0
# 100003                                   0
# 1101                                     0
# 805                                      0
# 801                                      0
# 1003                                     0
# 1001                                     0
