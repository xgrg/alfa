# %% [markdown]
# # Comparisons for ALFA_PLUS2 (2017-05-16)

# %%
# After running find . > $file on both archives (BSC and UPCnet)
upcnet = open('/tmp/xnat_stats/ALFA_PLUS2_upcnet_20170516.txt').readlines()
bsc = open('/tmp/xnat_stats/ALFA_PLUS2_bsc_20170516.txt').readlines()

# %%
from glob import glob
import pandas as pd
import os.path as osp
upc_dcm = [(e.split('/')[-3], (osp.basename(e)[:-1],e[:-1])) for e in upcnet if e.endswith('.dcm\n')]
bsc_dcm = [(e.split('/')[-3], (osp.basename(e)[:-1], e[:-1])) for e in bsc if e.endswith('.dcm\n')]

# %% [markdown]
# ### Display the first identified DICOM files

# %%
print upc_dcm[:10], bsc_dcm[:10]
# Out:
# [('502', ('1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-181-19mzzt3.dcm', './66224/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-181-19mzzt3.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-871-1a2yo4a.dcm', './66224/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-871-1a2yo4a.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-331-19o1o23.dcm', './66224/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-331-19o1o23.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-301-19nlpdu.dcm', './66224/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-301-19nlpdu.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-661-1a1rvyd.dcm', './66224/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-661-1a1rvyd.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-0-1yqaoa6.dcm', './66224/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-0-1yqaoa6.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-361-19o4809.dcm', './66224/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-361-19o4809.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-241-19nh8h1.dcm', './66224/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-241-19nh8h1.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-571-1a0u1n8.dcm', './66224/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-571-1a0u1n8.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-691-1a1ufx4.dcm', './66224/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.5096.2017012314184728000-502-691-1a1ufx4.dcm'))] [('502', ('1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-61-tbh8v4.dcm', './040712160117783/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-61-tbh8v4.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-571-tev7g7.dcm', './040712160117783/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-571-tev7g7.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-91-tbjstv.dcm', './040712160117783/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-91-tbjstv.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-541-tesni1.dcm', './040712160117783/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-541-tesni1.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-751-tg02mw.dcm', './040712160117783/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-751-tg02mw.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-481-tea4v1.dcm', './040712160117783/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-481-tea4v1.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-451-tdu66s.dcm', './040712160117783/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-451-tdu66s.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-271-tcpb03.dcm', './040712160117783/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-271-tcpb03.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-151-tc1ogr.dcm', './040712160117783/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-151-tc1ogr.dcm')), ('502', ('1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-211-tc65dk.dcm', './040712160117783/SCANS/502/DICOM/1.3.46.670589.11.78036.5.0.2952.2017011614063176000-502-211-tc65dk.dcm'))]

# %% [markdown]
# ### Numbers of existing DICOM files on both sides:

# %%
print 'upc:', len(upc_dcm), 'bsc:', len(bsc_dcm)
# Out:
# upc: 96080 bsc: 96080

# %% [markdown]
# Numbers of non-dicom items:

# %%
nondcm_upcnet = [e[0] for e in upcnet if not '.dcm' in e]
nondcm_bsc = [e[0] for e in bsc if not '.dcm' in e]
print 'upc:', len(nondcm_upcnet), 'bsc:', len(nondcm_bsc)
# Out:
# upc: 2062 bsc: 3557

# %%
# removing all files in upcnet from subject 000000123
#upc_dcm = [(a,(b,e)) for (a, (b,e)) in upc_dcm if not '000123' in e.split('/')[1]]

# %% [markdown]
# Dictionaries by sequences:

# %%
# Creating dictionaries
upc_dict = {}
bsc_dict = {}

for seq, (dcmfile,_) in upc_dcm:
    upc_dict.setdefault(seq, []).append(dcmfile)
for seq, (dcmfile,_) in bsc_dcm:
    bsc_dict.setdefault(seq, []).append(dcmfile)

# %% [markdown]
# ## Matching files between servers for every sequence:

# %% [markdown]
# The good thing is that it appears that all files from BSC find their match on UPCnet.
#
# Yet the opposite is not true.

# %%
results = []
print set(upc_dict.keys()).difference(set(bsc_dict.keys())), 'are in UPC, missing in BSC'
print set(bsc_dict.keys()).difference(set(upc_dict.keys())), 'are in BSC, missing in UPC'
common_sq = set(bsc_dict.keys()).intersection(set(upc_dict.keys()))
print len(common_sq), 'in common'

for each in common_sq:
    row = []
    row.append(len(upc_dict[each]))
    row.append(len(bsc_dict[each]))
    row.append(len(set(upc_dict[each]).difference(set(bsc_dict[each]))))
    row.append(len(set(bsc_dict[each]).difference(set(upc_dict[each]))))
    row.append(len(upc_dict[each]) - len(bsc_dict[each]))
    results.append(row)
pd.DataFrame(results, index=common_sq, columns=['UPCnet', 'BSC', 'upc.diff(bsc)', 'bsc.diff(upc)', 'UPCnet - BSC (raw diff in numbers)'])
# Out:
# set([]) are in UPC, missing in BSC
# set([]) are in BSC, missing in UPC
# 43 in common
#       UPCnet    BSC  upc.diff(bsc)  bsc.diff(upc)  \
# 601     1841   1841              0              0
# 1301    2308   2308              0              0
# 602       33     33              0              0
# 1201    2351   2351              0              0
# 701       53     53              0              0
# 702       18     18              0              0
# 1202       2      2              0              0
# 1503    3412   3412              0              0
# 1303    1121   1121              0              0
# 0        148    148              0              0
# 404      200    200              0              0
# 403      250    250              0              0
# 402      150    150              0              0
# 401      773    773              0              0
# 1403    5774   5774              0              0
# 1401    3993   3993              0              0
# 502      619    619              0              0
# 501    36053  36053              0              0
# 201       19     19              0              0
# 202       19     19              0              0
# 903      250    250              0              0
# 301     3171   3171              0              0
# 302     3150   3150              0              0
# 303     5250   5250              0              0
# 304     4200   4200              0              0
# 1703    1121   1121              0              0
# 102       66     66              0              0
# 103     1100   1100              0              0
# 101     2222   2222              0              0
# 1501    2339   2339              0              0
# 104     1210   1210              0              0
# 902      154    154              0              0
# 1701     372    372              0              0
# 901     1282   1282              0              0
# 1801      91     91              0              0
# 904      200    200              0              0
# 1601    1427   1427              0              0
# 1603    4156   4156              0              0
# 1101    1653   1653              0              0
# 802       43     43              0              0
# 801     1829   1829              0              0
# 1002       4      4              0              0
# 1001    1653   1653              0              0
#
#       UPCnet - BSC (raw diff in numbers)
# 601                                    0
# 1301                                   0
# 602                                    0
# 1201                                   0
# 701                                    0
# 702                                    0
# 1202                                   0
# 1503                                   0
# 1303                                   0
# 0                                      0
# 404                                    0
# 403                                    0
# 402                                    0
# 401                                    0
# 1403                                   0
# 1401                                   0
# 502                                    0
# 501                                    0
# 201                                    0
# 202                                    0
# 903                                    0
# 301                                    0
# 302                                    0
# 303                                    0
# 304                                    0
# 1703                                   0
# 102                                    0
# 103                                    0
# 101                                    0
# 1501                                   0
# 104                                    0
# 902                                    0
# 1701                                   0
# 901                                    0
# 1801                                   0
# 904                                    0
# 1601                                   0
# 1603                                   0
# 1101                                   0
# 802                                    0
# 801                                    0
# 1002                                   0
# 1001                                   0
