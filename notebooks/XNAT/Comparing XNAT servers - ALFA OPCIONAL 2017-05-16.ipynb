# %% [markdown]
# # Comparisons for ALFA OPCIONAL (2017-05-16)

# %%
# After running find . > $file on both archives (BSC and UPCnet)
upcnet = open('/tmp/xnat_stats/ALFA_OPCIONAL_upcnet_20170516.txt').readlines()
bsc = open('/tmp/xnat_stats/ALFA_OPCIONAL_bsc_20170516.txt').readlines()

# %%
from glob import glob
import pandas as pd
import os.path as osp

upc_dcm = [(e.split('/')[-3], (e[:-1], osp.basename(e)[:-1])) for e in upcnet if e.endswith('.dcm\n')]
bsc_dcm = [(e.split('/')[-3], (e[:-1], osp.basename(e)[:-1])) for e in bsc if e.endswith('.dcm\n')]
files_upc = dict([(osp.basename(e)[:-1], e[-1]) for e in upcnet if e.endswith('.dcm\n')])

# %% [markdown]
# ### Display the first identified DICOM files

# %%
print upc_dcm[:10], bsc_dcm[:10]
# Out:
# [('1001', ('./13293/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-250-1vwkjka.dcm', '1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-250-1vwkjka.dcm')), ('1001', ('./13293/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-324-7oqudt.dcm', '1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-324-7oqudt.dcm')), ('1001', ('./13293/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-47-1vx5m5h.dcm', '1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-47-1vx5m5h.dcm')), ('1001', ('./13293/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-120-1wbg9mp.dcm', '1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-120-1wbg9mp.dcm')), ('1001', ('./13293/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-213-7qutva.dcm', '1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-213-7qutva.dcm')), ('1001', ('./13293/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-169-8anfwi.dcm', '1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-169-8anfwi.dcm')), ('1001', ('./13293/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-306-8oi4pc.dcm', '1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-306-8oi4pc.dcm')), ('1001', ('./13293/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-290-1vezqxr.dcm', '1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-290-1vezqxr.dcm')), ('1001', ('./13293/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-71-1vex6yz.dcm', '1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-71-1vex6yz.dcm')), ('1001', ('./13293/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-182-891yjy.dcm', '1.3.46.670589.11.78036.5.0.8760.2017012015122897000-1001-182-891yjy.dcm'))] [('1001', ('./040144130716058/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.6988.2016071310315383002-1001-1-1ldwrfd.dcm', '1.3.46.670589.11.78036.5.0.6988.2016071310315383002-1001-1-1ldwrfd.dcm')), ('1001', ('./040144130716058/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.6988.2016071310315383002-1001-1-18acy23.dcm', '1.3.46.670589.11.78036.5.0.6988.2016071310315383002-1001-1-18acy23.dcm')), ('1001', ('./040144130716058/SCANS/1001/DICOM/1.3.46.670589.11.78036.5.0.6988.2016071310315383002-1001-1-ewxk2e.dcm', '1.3.46.670589.11.78036.5.0.6988.2016071310315383002-1001-1-ewxk2e.dcm')), ('701', ('./040144130716058/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.6988.2016071310315383002-701-1-461og4.dcm', '1.3.46.670589.11.78036.5.0.6988.2016071310315383002-701-1-461og4.dcm')), ('701', ('./040144130716058/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.6988.2016071310315383002-701-1-106yia.dcm', '1.3.46.670589.11.78036.5.0.6988.2016071310315383002-701-1-106yia.dcm')), ('701', ('./040144130716058/SCANS/701/DICOM/1.3.46.670589.11.78036.5.0.6988.2016071310315383002-701-1-19tqcfj.dcm', '1.3.46.670589.11.78036.5.0.6988.2016071310315383002-701-1-19tqcfj.dcm')), ('704', ('./040144130716058/SCANS/704/DICOM/1.3.46.670589.11.78036.5.0.6988.2016071310315383002-704-1-8zdnv.dcm', '1.3.46.670589.11.78036.5.0.6988.2016071310315383002-704-1-8zdnv.dcm')), ('704', ('./040144130716058/SCANS/704/DICOM/1.3.46.670589.11.78036.5.0.6988.2016071310315383002-704-1-azw57t.dcm', '1.3.46.670589.11.78036.5.0.6988.2016071310315383002-704-1-azw57t.dcm')), ('704', ('./040144130716058/SCANS/704/DICOM/1.3.46.670589.11.78036.5.0.6988.2016071310315383002-704-1-1k1b3vq.dcm', '1.3.46.670589.11.78036.5.0.6988.2016071310315383002-704-1-1k1b3vq.dcm')), ('1301', ('./040144130716058/SCANS/1301/DICOM/1.3.46.670589.11.78036.5.0.6988.2016071310315383002-1301-1-1nptrk9.dcm', '1.3.46.670589.11.78036.5.0.6988.2016071310315383002-1301-1-1nptrk9.dcm'))]

# %% [markdown]
# ### Numbers of existing DICOM files on both sides:

# %%
print 'upc:', len(upc_dcm), 'bsc:', len(bsc_dcm)
# Out:
# upc: 7286318 bsc: 7265239

# %% [markdown]
# Numbers of non-dicom items:

# %%
nondcm_upcnet = [e for e in upcnet if not '.dcm' in e]
nondcm_bsc = [e for e in bsc if not '.dcm' in e]
print 'upc:', len(nondcm_upcnet), 'bsc:', len(nondcm_bsc)
# Out:
# upc: 35958 bsc: 50503

# %% [markdown]
# Dictionaries by sequences:

# %%
# Creating dictionaries
upc_dict = {}
bsc_dict = {}

for seq, (e, dcmfile) in upc_dcm:
    upc_dict.setdefault(seq, []).append(dcmfile)
for seq, (e, dcmfile) in bsc_dcm:
    bsc_dict.setdefault(seq, []).append(dcmfile)

# %% [markdown]
# ## Example of difference for a given sequence:

# %%
mismatch_all = []
for s in common_sq:
    mismatch_all.extend(list(set(upc_dict[s]).difference(set(bsc_dict[s]))))

# %%
print len(mismatch_all)
files = []
for i,each in enumerate(mismatch_all):
    if i%100 == 0:
        print i
    files.append([f for (s,(f,e)) in upc_dcm if each in e][0])
# Out:
# 21079
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000

# %%
files
# Out:
# ['./44842/SCANS/601/DICOM/1.3.46.670589.11.78036.5.0.9972.2016111116240926010-601-107-mzehn8.dcm',
#  './44842/SCANS/601/DICOM/1.3.46.670589.11.78036.5.0.9972.2016111116240926010-601-8521-1hoz4mx.dcm',
#  './44842/SCANS/601/DICOM/1.3.46.670589.11.78036.5.0.9972.2016111116240926010-601-1771-qwr0j1.dcm',
#  './44842/SCANS/601/DICOM/1.3.46.670589.11.78036.5.0.9972.2016111116240926010-601-6481-91q8gj.dcm',
#  './44842/SCANS/601/DICOM/1.3.46.670589.11.78036.5.0.9972.2016111116240926010-601-7912-111serq.dcm',
#  './44842/SCANS/601/DICOM/1.3.46.670589.11.78036.5.0.9972.2016111116240926010-601-7732-1w404rq.dcm',
#  './44842/SCANS/601/DICOM/1.3.46.670589.11.78036.5.0.9972.2016111116240926010-601-12413-11mnyz7.dcm',
#  './44842/SCANS/601/DICOM/1.3.46.670589.11.78036.5.0.9972.2016111116240926010-601-12077-184p0fb.dcm',
#  './44842/SCANS/601/DICOM/1.3.46.670589.11.78036.5.0.9972.2016111116240926010-601-11864-pnbxn3.dcm',
#  './44842/SCANS/601/DICOM/1.3.46.670589.11.78036.5.0.9972.2016111116240926010-601-1137-at3re5.dcm']

# %%
import json
json.dump(mismatch_all, open('/tmp/ALFA_OPCIONAL_diff_20170517.txt','w'))

# %% [markdown]
# Another one

# %%
#s = '701'
#mismatch_ex = list(set(upc_dict[s]).difference(set(bsc_dict[s])))[0]
#test = [e for e in upcnet if mismatch_ex in e]

#print 'Example of mismatching file:', mismatch_ex

#print 'is %s found in upcnet : %s, and in BSC: %s'%(test[0], test[0] in upcnet, test[0] in bsc)

# %% [markdown]
# ## Matching files between servers for every sequence:

# %% [markdown]
# The good thing is that it appears that all files from BSC find their match on UPCnet.
#
# Yet the opposite is not true.

# %%
results = []
print set(upc_dict.keys()).difference(set(bsc_dict.keys())), 'are in UPC, missing in BSC'
print set(bsc_dict.keys()).difference(set(upc_dict.keys())), 'are in BSC, missing in UPC'
common_sq = set(bsc_dict.keys()).intersection(set(upc_dict.keys()))
print len(common_sq), 'in common'

for each in common_sq:
    row = []
    row.append(len(upc_dict[each]))
    row.append(len(bsc_dict[each]))
    row.append(len(set(upc_dict[each]).difference(set(bsc_dict[each]))))
    row.append(len(set(bsc_dict[each]).difference(set(upc_dict[each]))))
    row.append(len(upc_dict[each]) - len(bsc_dict[each]))
    results.append(row)
pd.DataFrame(results, index=common_sq, columns=['UPCnet', 'BSC', 'upc.diff(bsc)', 'bsc.diff(upc)', 'UPCnet - BSC (raw diff in numbers)'])
# Out:
# set([]) are in UPC, missing in BSC
# set([]) are in BSC, missing in UPC
# 70 in common
#        UPCnet      BSC  upc.diff(bsc)  bsc.diff(upc)  \
# 604       135      135              0              0
