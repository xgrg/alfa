# %% [markdown]
# # Comparisons for ALFA (2017-08-31)

# %%
# After running find . > $file on both archives (BSC and UPCnet)
upcnet = open('/tmp/xnat_stats/ALFA_20170831_UPCnet.txt').readlines()
bsc = open('/tmp/xnat_stats/ALFA_20170831_BSC.txt').readlines()

# %%
from glob import glob
import pandas as pd
import os.path as osp
upc_dcm = [(e.split('/')[-3], (osp.basename(e)[:-1],e[:-1])) for e in upcnet if e.endswith('.dcm\n')]
bsc_dcm = [(e.split('/')[-3], (osp.basename(e)[:-1], e[:-1])) for e in bsc if e.endswith('.dcm\n')]

# %% [markdown]
# ### Display the first identified DICOM files

# %%
print upc_dcm[:10], bsc_dcm[:10]
# Out:
# [('900', ('1.2.840.113619.6.353.66826236179654918899816845301973961404-900-54-sktf51.dcm', './1430899/SCANS/900/DICOM/1.2.840.113619.6.353.66826236179654918899816845301973961404-900-54-sktf51.dcm')), ('900', ('1.2.840.113619.6.353.66826236179654918899816845301973961404-900-39-sktdig.dcm', './1430899/SCANS/900/DICOM/1.2.840.113619.6.353.66826236179654918899816845301973961404-900-39-sktdig.dcm')), ('900', ('1.2.840.113619.6.353.66826236179654918899816845301973961404-900-15-sktbmm.dcm', './1430899/SCANS/900/DICOM/1.2.840.113619.6.353.66826236179654918899816845301973961404-900-15-sktbmm.dcm')), ('900', ('1.2.840.113619.6.353.66826236179654918899816845301973961404-900-5-sks49f.dcm', './1430899/SCANS/900/DICOM/1.2.840.113619.6.353.66826236179654918899816845301973961404-900-5-sks49f.dcm')), ('900', ('1.2.840.113619.6.353.66826236179654918899816845301973961404-900-49-skteeb.dcm', './1430899/SCANS/900/DICOM/1.2.840.113619.6.353.66826236179654918899816845301973961404-900-49-skteeb.dcm')), ('900', ('1.2.840.113619.6.353.66826236179654918899816845301973961404-900-31-sktda8.dcm', './1430899/SCANS/900/DICOM/1.2.840.113619.6.353.66826236179654918899816845301973961404-900-31-sktda8.dcm')), ('900', ('1.2.840.113619.6.353.66826236179654918899816845301973961404-900-45-sktea7.dcm', './1430899/SCANS/900/DICOM/1.2.840.113619.6.353.66826236179654918899816845301973961404-900-45-sktea7.dcm')), ('900', ('1.2.840.113619.6.353.66826236179654918899816845301973961404-900-1-sks45b.dcm', './1430899/SCANS/900/DICOM/1.2.840.113619.6.353.66826236179654918899816845301973961404-900-1-sks45b.dcm')), ('900', ('1.2.840.113619.6.353.66826236179654918899816845301973961404-900-20-sktcdc.dcm', './1430899/SCANS/900/DICOM/1.2.840.113619.6.353.66826236179654918899816845301973961404-900-20-sktcdc.dcm')), ('900', ('1.2.840.113619.6.353.66826236179654918899816845301973961404-900-33-sktdca.dcm', './1430899/SCANS/900/DICOM/1.2.840.113619.6.353.66826236179654918899816845301973961404-900-33-sktdca.dcm'))] [('800', ('1.2.840.113619.6.353.205296510108802724873751358051835081611-800-39-sktdig.dcm', './1429657cc/SCANS/800/DICOM/1.2.840.113619.6.353.205296510108802724873751358051835081611-800-39-sktdig.dcm')), ('800', ('1.2.840.113619.6.353.205296510108802724873751358051835081611-800-36-sktdfd.dcm', './1429657cc/SCANS/800/DICOM/1.2.840.113619.6.353.205296510108802724873751358051835081611-800-36-sktdfd.dcm')), ('800', ('1.2.840.113619.6.353.205296510108802724873751358051835081611-800-33-sktdca.dcm', './1429657cc/SCANS/800/DICOM/1.2.840.113619.6.353.205296510108802724873751358051835081611-800-33-sktdca.dcm')), ('800', ('1.2.840.113619.6.353.205296510108802724873751358051835081611-800-83-skthrl.dcm', './1429657cc/SCANS/800/DICOM/1.2.840.113619.6.353.205296510108802724873751358051835081611-800-83-skthrl.dcm')), ('800', ('1.2.840.113619.6.353.205296510108802724873751358051835081611-800-72-sktgup.dcm', './1429657cc/SCANS/800/DICOM/1.2.840.113619.6.353.205296510108802724873751358051835081611-800-72-sktgup.dcm')), ('800', ('1.2.840.113619.6.353.205296510108802724873751358051835081611-800-82-skthqk.dcm', './1429657cc/SCANS/800/DICOM/1.2.840.113619.6.353.205296510108802724873751358051835081611-800-82-skthqk.dcm')), ('800', ('1.2.840.113619.6.353.205296510108802724873751358051835081611-800-41-skte63.dcm', './1429657cc/SCANS/800/DICOM/1.2.840.113619.6.353.205296510108802724873751358051835081611-800-41-skte63.dcm')), ('800', ('1.2.840.113619.6.353.205296510108802724873751358051835081611-800-15-sktbmm.dcm', './1429657cc/SCANS/800/DICOM/1.2.840.113619.6.353.205296510108802724873751358051835081611-800-15-sktbmm.dcm')), ('800', ('1.2.840.113619.6.353.205296510108802724873751358051835081611-800-1-sks45b.dcm', './1429657cc/SCANS/800/DICOM/1.2.840.113619.6.353.205296510108802724873751358051835081611-800-1-sks45b.dcm')), ('800', ('1.2.840.113619.6.353.205296510108802724873751358051835081611-800-3-sks47d.dcm', './1429657cc/SCANS/800/DICOM/1.2.840.113619.6.353.205296510108802724873751358051835081611-800-3-s ...

# %% [markdown]
# ### Numbers of existing DICOM files on both sides:

# %%
print 'upc:', len(upc_dcm), 'bsc:', len(bsc_dcm)
# Out:
# upc: 6072435 bsc: 6072435

# %% [markdown]
# Numbers of non-dicom items:

# %%
nondcm_upcnet = [e[0] for e in upcnet if not '.dcm' in e]
nondcm_bsc = [e[0] for e in bsc if not '.dcm' in e]
print 'upc:', len(nondcm_upcnet), 'bsc:', len(nondcm_bsc)
# Out:
# upc: 103968 bsc: 103612

# %%
# removing all files in upcnet from subject 000000123
#upc_dcm = [(a,(b,e)) for (a, (b,e)) in upc_dcm if not '000123' in e.split('/')[1]]

# %% [markdown]
# Dictionaries by sequences:

# %%
# Creating dictionaries
upc_dict = {}
bsc_dict = {}

for seq, (dcmfile,_) in upc_dcm:
    upc_dict.setdefault(seq, []).append(dcmfile)
for seq, (dcmfile,_) in bsc_dcm:
    bsc_dict.setdefault(seq, []).append(dcmfile)

# %% [markdown]
# ## Matching files between servers for every sequence:

# %% [markdown]
# The good thing is that it appears that all files from BSC find their match on UPCnet.
#
# Yet the opposite is not true.

# %%
results = []
print set(upc_dict.keys()).difference(set(bsc_dict.keys())), 'are in UPC, missing in BSC'
print set(bsc_dict.keys()).difference(set(upc_dict.keys())), 'are in BSC, missing in UPC'
common_sq = set(bsc_dict.keys()).intersection(set(upc_dict.keys()))
print len(common_sq), 'in common'

for each in common_sq:
    row = []
    row.append(len(upc_dict[each]))
    row.append(len(bsc_dict[each]))
    row.append(len(set(upc_dict[each]).difference(set(bsc_dict[each]))))
    row.append(len(set(bsc_dict[each]).difference(set(upc_dict[each]))))
    row.append(len(upc_dict[each]) - len(bsc_dict[each]))
    results.append(row)
pd.DataFrame(results, index=common_sq, columns=['UPCnet', 'BSC', 'upc.diff(bsc)', 'bsc.diff(upc)', 'UPCnet - BSC (raw diff in numbers)'])
# Out:
# set([]) are in UPC, missing in BSC
# set([]) are in BSC, missing in UPC
# 55 in common
#        UPCnet      BSC  upc.diff(bsc)  bsc.diff(upc)  \
# 601       752      752              0              0
# 600      1168     1168              0              0
# 1302      112      112              0              0
# 602      1080     1080              0              0
# 700     39158    39158              0              0
# 1200      237      237              0              0
# 1202      224      224              0              0
# 1300      112      112              0              0
# 1301      112      112              0              0
# 1502       56       56              0              0
# 1500       56       56              0              0
# 1          30       30              0              0
# 3       93765    93765              0              0
# 2       27208    27208              0              0
# 5       36415    36415              0              0
# 4       37810    37810              0              0
# 401      7134     7134              0              0
# 400     10584    10584              0              0
# 9     2234521  2234521              0              0
# 8     2193068  2193068              0              0
# 502       368      368              0              0
# 500       544      544              0              0
# 402     10496    10496              0              0
# 11      95830    95830              0              0
# 303       256      256              0              0
# 7      133154   133154              0              0
# 903        56       56              0              0
# 300    138061   138061              0              0
# 301     94366    94366              0              0
# 302    138463   138463              0              0
# 6       33593    33593              0              0
# 304       174      174              0              0
# 305       256      256              0              0
# 501       286      286              0              0
# 12      24072    24072              0              0
# 1501       56       56              0              0
# 13       7640     7640              0              0
# 902     23005    23005              0              0
# 10     594248   594248              0              0
# 900     23891    23891              0              0
# 901     23117    23117              0              0
# 15       3640     3640              0              0
# 14         60       60              0              0
# 17       5160     5160              0              0
# 16         60       60              0              0
# 1201      224      224              0              0
# 1102      619      619              0              0
# 1100      707      707              0              0
# 1101      619      619              0              0
# 802       424      424              0              0
# 801       342      342              0              0
# 800     11170    11170              0              0
# 1002     7908     7908              0              0
# 1001     7852     7852              0              0
# 1000     8116     8116              0              0
#
#       UPCnet - BSC (raw diff in numbers)
# 601                                    0
# 600                                    0
# 1302                                   0
# 602                                    0
# 700                                    0
# 1200                                   0
# 1202                                   0
# 1300                                   0
# 1301                                   0
# 1502                                   0
# 1500                                   0
# 1                                      0
# 3                                      0
# 2                                      0
# 5                                      0
# 4                                      0
# 401                                    0
# 400                                    0
# 9                                      0
# 8                                      0
# 502                                    0
# 500                                    0
# 402                                    0
# 11                                     0
# 303                                    0
# 7                                      0
# 903                                    0
# 300                                    0
# 301                                    0
# 302                                    0
# 6                                      0
# 304                                    0
# 305                                    0
# 501                                    0
# 12                                     0
# 1501                                   0
# 13                                     0
# 902                                    0
# 10                                     0
# 900                                    0
# 901                                    0
# 15                                     0
# 14                                     0
# 17                                     0
# 16                                     0
# 1201                                   0
# 1102                                   0
# 1100                                   0
# 1101                                   0
# 802                                    0
# 801                                    0
# 800                                    0
# 1002                                   0
# 1001                                   0
# 1000                                   0
