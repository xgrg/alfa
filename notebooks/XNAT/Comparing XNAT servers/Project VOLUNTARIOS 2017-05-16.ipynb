# %% [markdown]
# # Comparisons for VOLUNTARIOS (2017-05-16)

# %%
# After running find . > $file on both archives (BSC and UPCnet)
upcnet = open('/tmp/xnat_stats/VOLUNTARIOS_upcnet_20170516.txt').readlines()
bsc = open('/tmp/xnat_stats/VOLUNTARIOS_bsc_20170516.txt').readlines()

# %%
from glob import glob
import pandas as pd
import os.path as osp
upc_dcm = [(e.split('/')[-3], osp.basename(e)[:-1]) for e in upcnet if e.endswith('.dcm\n')]
bsc_dcm = [(e.split('/')[-3], osp.basename(e)[:-1]) for e in bsc if e.endswith('.dcm\n')]

# %% [markdown]
# ### Display the first identified DICOM files

# %%
print upc_dcm[:10], bsc_dcm[:10]
# Out:
# [('1001', '1.3.46.670589.11.78036.5.0.9696.2016070616572484010-1001-26-1rwk5ga.dcm'), ('1001', '1.3.46.670589.11.78036.5.0.9696.2016070616572484010-1001-24-144vsxw.dcm'), ('1001', '1.3.46.670589.11.78036.5.0.9696.2016070616572484010-1001-4-144xpxg.dcm'), ('1001', '1.3.46.670589.11.78036.5.0.9696.2016070616572484010-1001-12-1rwjp0j.dcm'), ('1001', '1.3.46.670589.11.78036.5.0.9696.2016070616572484010-1001-30-144yzy1.dcm'), ('1001', '1.3.46.670589.11.78036.5.0.9696.2016070616572484010-1001-6-144x2xv.dcm'), ('1001', '1.3.46.670589.11.78036.5.0.9696.2016070616572484010-1001-20-1rwk5b2.dcm'), ('1001', '1.3.46.670589.11.78036.5.0.9696.2016070616572484010-1001-30-4uieiw.dcm'), ('1001', '1.3.46.670589.11.78036.5.0.9696.2016070616572484010-1001-8-144x2xs.dcm'), ('1001', '1.3.46.670589.11.78036.5.0.9696.2016070616572484010-1001-6-1rwjocn.dcm')] [('101', '1.3.46.670589.11.78036.5.0.8916.2016072111310820002-101-38-1dpzeun.dcm'), ('101', '1.3.46.670589.11.78036.5.0.8916.2016072111310820002-101-7-1dpw7ue.dcm'), ('101', '1.3.46.670589.11.78036.5.0.8916.2016072111310820002-101-76-1dpec50.dcm'), ('101', '1.3.46.670589.11.78036.5.0.8916.2016072111310820002-101-23-1dpyru4.dcm'), ('101', '1.3.46.670589.11.78036.5.0.8916.2016072111310820002-101-20-1dpxhue.dcm'), ('101', '1.3.46.670589.11.78036.5.0.8916.2016072111310820002-101-71-1dpd1n5.dcm'), ('101', '1.3.46.670589.11.78036.5.0.8916.2016072111310820002-101-37-1dpzeum.dcm'), ('101', '1.3.46.670589.11.78036.5.0.8916.2016072111310820002-101-13-1dpxhu7.dcm'), ('101', '1.3.46.670589.11.78036.5.0.8916.2016072111310820002-101-17-1dpxhub.dcm'), ('101', '1.3.46.670589.11.78036.5.0.8916.2016072111310820002-101-52-1dowfxq.dcm')]

# %% [markdown]
# ### Numbers of existing DICOM files on both sides:

# %%
print 'upc:', len(upc_dcm), 'bsc:', len(bsc_dcm)
# Out:
# upc: 339775 bsc: 339775

# %% [markdown]
# Numbers of non-dicom items:

# %%
nondcm_upcnet = [e for e in upcnet if not '.dcm' in e]
nondcm_bsc = [e for e in bsc if not '.dcm' in e]
print 'upc:', len(nondcm_upcnet), 'bsc:', len(nondcm_bsc)
# Out:
# upc: 1349 bsc: 1232

# %% [markdown]
# Dictionaries by sequences:

# %%
# Creating dictionaries
upc_dict = {}
bsc_dict = {}

for seq, dcmfile in upc_dcm:
    upc_dict.setdefault(seq, []).append(dcmfile)
for seq, dcmfile in bsc_dcm:
    bsc_dict.setdefault(seq, []).append(dcmfile)

# %% [markdown]
# ## Matching files between servers for every sequence:

# %% [markdown]
# The good thing is that it appears that all files from BSC find their match on UPCnet.
#
# Yet the opposite is not true.

# %%
results = []
print set(upc_dict.keys()).difference(set(bsc_dict.keys())), 'are in UPC, missing in BSC'
print set(bsc_dict.keys()).difference(set(upc_dict.keys())), 'are in BSC, missing in UPC'
common_sq = set(bsc_dict.keys()).intersection(set(upc_dict.keys()))
print len(common_sq), 'in common'

for each in common_sq:
    row = []
    row.append(len(upc_dict[each]))
    row.append(len(bsc_dict[each]))
    row.append(len(set(upc_dict[each]).difference(set(bsc_dict[each]))))
    row.append(len(set(bsc_dict[each]).difference(set(upc_dict[each]))))
    row.append(len(upc_dict[each]) - len(bsc_dict[each]))
    results.append(row)
pd.DataFrame(results, index=common_sq, columns=['UPCnet', 'BSC', 'upc.diff(bsc)', 'bsc.diff(upc)', 'UPCnet - BSC (raw diff in numbers)'])
# Out:
# set([]) are in UPC, missing in BSC
# set([]) are in BSC, missing in UPC
# 44 in common
#       UPCnet    BSC  upc.diff(bsc)  bsc.diff(upc)  \
# 604      180    180              0              0
# 601    54154  54154              0              0
# 1301   11188  11188              0              0
# 603       90     90              0              0
# 704      290    290              0              0
# 705      115    115              0              0
# 1206     100    100              0              0
# 1201   29372  29372              0              0
# 701    39601  39601              0              0
# 1203     110    110              0              0
# 703      269    269              0              0
# 0         19     19              0              0
# 405       30     30              0              0
# 404       90     90              0              0
# 403     1710   1710              0              0
# 401    26163  26163              0              0
# 1204     100    100              0              0
# 1401   18778  18778              0              0
# 503       30     30              0              0
# 501    79276  79276              0              0
# 201        3      3              0              0
# 203        2      2              0              0
# 202        1      1              0              0
# 301     5208   5208              0              0
# 303     1350   1350              0              0
# 304     1029   1029              0              0
# 305      240    240              0              0
# 102        3      3              0              0
# 103       75     75              0              0
# 101     1367   1367              0              0
# 1501    1940   1940              0              0
# 504      180    180              0              0
# 104      760    760              0              0
# 903      420    420              0              0
# 901    30138  30138              0              0
# 1205     100    100              0              0
# 1103     330    330              0              0
# 1101   20631  20631              0              0
# 803       89     89              0              0
# 801    13386  13386              0              0
# 1004      69     69              0              0
# 1003      17     17              0              0
# 1001     592    592              0              0
# 804      180    180              0              0
#
#       UPCnet - BSC (raw diff in numbers)
# 604                                    0
# 601                                    0
# 1301                                   0
# 603                                    0
# 704                                    0
# 705                                    0
# 1206                                   0
# 1201                                   0
# 701                                    0
# 1203                                   0
# 703                                    0
# 0                                      0
# 405                                    0
# 404                                    0
# 403                                    0
# 401                                    0
# 1204                                   0
# 1401                                   0
# 503                                    0
# 501                                    0
# 201                                    0
# 203                                    0
# 202                                    0
# 301                                    0
# 303                                    0
# 304                                    0
# 305                                    0
# 102                                    0
# 103                                    0
# 101                                    0
# 1501                                   0
# 504                                    0
# 104                                    0
# 903                                    0
# 901                                    0
# 1205                                   0
# 1103                                   0
# 1101                                   0
# 803                                    0
# 801                                    0
# 1004                                   0
# 1003                                   0
# 1001                                   0
# 804                                    0
