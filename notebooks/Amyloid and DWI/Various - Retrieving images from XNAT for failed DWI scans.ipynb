# %% [markdown]
# # Download images from XNAT

# %%
import os
path_to_repository = '/home/grg/git/xnat-monitor'
os.chdir(path_to_repository)
import bbrc

# %% [markdown]
# Setting up a connection to XNAT and defining which images to retrieve.

# %%
# Author: Grégory Operto <goperto@barcelonabeta.org>
import string
from pyxnat import Interface
from bbrc import xnat

config_file = '/home/grg/.xnat_bsc.cfg'
dest_dir = '/tmp/downloads'
project = 'ALFA_PLUS'
subjects = [string.atoi(e) for e in open('/tmp/amyloid_subjects.txt').read().split('\n') if e != '']
#bvec_correct =  [10162, 10515, 10627, 10649, 10711, 10949, 11262, 11514, 11745, 12279, 12741, 12991, 13035, 13105, 13107, 13193, 13259,
#                 21136, 21138, 44008, 44301, 44396, 55854, 66008, 66027, 66100, 66162, 66301, 77012, 77164]
#subjects = [e for e in subjects if not e in bvec_correct]
subjects_opcional = [10065, 10613, 11042, 11114, 11248, 11711, 11829, 12308, 12810, 13244, 44214, 44660]
sequences = ['DWI_ALFA1']

# Setting up an active connexion to XNAT
central = Interface(config=config_file)

# %%
# Selecting a project from which download images

# Get a list of subjects in the project to download all of them (instead of a list)
#subjects = [e.label() for e in list(p.subjects())]

for subject in subjects:
    # For each subject iterate on associated experiments
    project = 'ALFA_OPCIONAL' if subject in subjects_opcional else 'ALFA_PLUS'
    p = central.select.project(project)
    exp = list(p.subject(str(subject)).experiments())    
    for e in exp:
        # Get a list of available sequences
        d = xnat.series_desc(central, e.id())        
        print('%s (%s) has the following sequences %s'%(subject, e.label(), d))
        for sq in sequences:                    
            # Get the scan corresponding to sequence if available and select the NIFTI resource
            if sq in d.values():
                sids = [k for k,v in d.items() if v == sq and not k.startswith('0')]
                assert(len(sids)!=0)
                for sid in sids:
                    sc = e.scan(sid)
                    res = sc.resource('NIFTI')

                    # Displays a list of contained files
                    print('Resource files of sequence %s: %s'%(sq, list(res.files())))

                    # Download the corresponding archive and extract it in dest_dir
                    fp1 = res.get(dest_dir, extract=True)
                    print('%s have been created successfully'%fp1)
            else:
                print('%s is missing for subject %s'%(sq, subject))
    print('')
# Out:
# 10019 (040510150217019) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '301': 'T1_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T1_Coronal', '0-OT3': 'RS_ALFA1 SENSE', '0-OT2': 'T1_ALFA1', '0-OT5': 'FLAIR_Coronal', '0-OT4': 'IR_ALFA1 SENSE', '0-OT7': 'FLAIR_Axial', '0-OT6': 'FLAIR_ALFA1', '0-OT9': 'DWI_ALFA1', '0-OT8': 'T1_Axial', '302': 'T1_Coronal', '303': 'T1_Axial', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_Coronal', '903': 'FLAIR_Axial', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10019_1301.bvec, <File Object> 10019_1301.bval, <File Object> 10019_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/10019_1301.bvec', u'/tmp/downloads/NIFTI/10019_1301.bval', u'/tmp/downloads/NIFTI/10019_1301.nii.gz'] have been created successfully
#
# 10044 (040510270617044) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '0': 'T1_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T1_ALFA1', '202': 'B1_calibration', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_CORONAL', '903': 'FLAIR_AXIAL', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10044_1301.bval, <File Object> 10044_1301.bvec, <File Object> 10044_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/10044_1301.bval', u'/tmp/downloads/NIFTI/10044_1301.bvec', u'/tmp/downloads/NIFTI/10044_1301.nii.gz'] have been created successfully
#
# 10065 (030410211016065) has the following sequences {'0-OT1': 'SmartBrain SENSE', '901': 'RS_ALFA1', '601': 'B0_ALFA1', '1301': 'T2_ALFA1', '1601': 'DWI_ALFA1', '1401': 'IR_ALFA1', '1201': 'FLAIR_ALFA1', '701': 'T1_ALFA1', '404': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '1101': 'SE-fMRI-PA', '103': 'SmartBrain SENSE', '801': 'rRS_ALFA1', '101': 'SmartBrain SENSE', '1501': 'rDWI_ALFA1', '503': 'B1_calibration', '1001': 'SE-fMRI-AP', '501': 'B1_calibration'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10065_1601.bvec, <File Object> 10065_1601.bval, <File Object> 10065_1601.nii.gz]
# [u'/tmp/downloads/NIFTI/10065_1601.bvec', u'/tmp/downloads/NIFTI/10065_1601.bval', u'/tmp/downloads/NIFTI/10065_1601.nii.gz'] have been created successfully
#
# 10070 (040510130617070) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10070_1301.nii.gz, <File Object> 10070_1301.bvec, <File Object> 10070_1301.bval]
# [u'/tmp/downloads/NIFTI/10070_1301.nii.gz', u'/tmp/downloads/NIFTI/10070_1301.bvec', u'/tmp/downloads/NIFTI/10070_1301.bval'] have been created successfully
#
# 10137 (040510070617137) has the following sequences {'601': 'rRS_ALFA1 SENSE', '1201': 'T2_ALFA1', '701': 'RS_ALFA1 SENSE', '1501': 'DWI_ALFA1', '403': 'Axial', '402': 'Coronal', '401': 'T1_ALFA1', '1401': 'rDWI_ALFA1', '501': 'B0_ALFA1', '0-OT1': 'T1_ALFA1', '0-OT3': 'FLAIR_ALFA1', '0-OT2': 'T2_ALFA1', '0-OT5': 'IR_ALFA1 SENSE', '0-OT4': 'Axial', '0-OT7': 'IR_ALFA1 SENSE', '0-OT6': 'T2_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '901': 'SE-fMRI-PA SENSE', '1601': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-AP SENSE', '1003': 'Axial', '1002': 'Coronal', '1001': 'FLAIR_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10137_1501.nii.gz, <File Object> 10137_1501.bvec, <File Object> 10137_1501.bval]
# [u'/tmp/downloads/NIFTI/10137_1501.nii.gz', u'/tmp/downloads/NIFTI/10137_1501.bvec', u'/tmp/downloads/NIFTI/10137_1501.bval'] have been created successfully
#
# 10162 (040510250417162) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'SmartBrain SENSE', '0-OT3': 'Coronal', '0-OT2': 'Axial', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_CORONAL', '903': 'FLAIR_AXIAL', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10162_1301.bvec, <File Object> 10162_1301.nii.gz, <File Object> 10162_1301.bval]
# [u'/tmp/downloads/NIFTI/10162_1301.bvec', u'/tmp/downloads/NIFTI/10162_1301.nii.gz', u'/tmp/downloads/NIFTI/10162_1301.bval'] have been created successfully
#
# 10200 (040510110117200) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10200_1301.nii.gz, <File Object> 10200_1301.bvec, <File Object> 10200_1301.bval]
# [u'/tmp/downloads/NIFTI/10200_1301.nii.gz', u'/tmp/downloads/NIFTI/10200_1301.bvec', u'/tmp/downloads/NIFTI/10200_1301.bval'] have been created successfully
#
# 10225 (040510240117225) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1403': 'T1_AXIAL', '1402': 'T1_CORONAL', '1401': 'T1_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'FLAIR_CORONAL', '0-OT3': 'T1_AXIAL', '0-OT2': 'T1_AXIAL', '0-OT5': 'T1_CORONAL', '0-OT4': 'T1_CORONAL', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_CORONAL', '903': 'FLAIR_AXIAL', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10225_1301.nii.gz, <File Object> 10225_1301.bvec, <File Object> 10225_1301.bval]
# [u'/tmp/downloads/NIFTI/10225_1301.nii.gz', u'/tmp/downloads/NIFTI/10225_1301.bvec', u'/tmp/downloads/NIFTI/10225_1301.bval'] have been created successfully
#
# 10235 (040510150317235) has the following sequences {'201': 'B1_calibration', '601': 'SmartBrain SENSE', '1301': 'RS_ALFA1 SENSE', '603': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '602': 'SmartBrain SENSE', '1201': 'rRS_ALFA1 SENSE', '701': 'B1_calibration', '702': 'B1_calibration', '1501': 'SE-fMRI-PA SENSE', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1401': 'SE-fMRI-AP SENSE', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'IR_ALFA1 SENSE', '202': 'B1_calibration', '1701': 'DWI_ALFA1', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_CORONAL', '903': 'FLAIR_AXIAL', '901': 'FLAIR_ALFA1', '1601': 'rDWI_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'B0_ALFA1', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10235_1701.bvec, <File Object> 10235_1701.nii.gz, <File Object> 10235_1701.bval]
# [u'/tmp/downloads/NIFTI/10235_1701.bvec', u'/tmp/downloads/NIFTI/10235_1701.nii.gz', u'/tmp/downloads/NIFTI/10235_1701.bval'] have been created successfully
#
# 10245 (040510200617245) has the following sequences {'0-OT1': 'IR_ALFA1 SENSE', '0-OT3': 'IR_ALFA1 SENSE', '0-OT2': 'DWI_ALFA1', '601': 'rRS_ALFA1 SENSE', '1301': 'rDWI_ALFA1', '1004': 'Axial', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '701': 'RS_ALFA1 SENSE', '1501': 'IR_ALFA1 SENSE', '901': 'SE-fMRI-PA SENSE', '401': 'B0_ALFA1', '1101': 'T2_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-AP SENSE', '101': 'SmartBrain SENSE', '1003': 'Coronal', '1401': 'DWI_ALFA1', '1001': 'FLAIR_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10245_1401.nii.gz, <File Object> 10245_1401.bvec, <File Object> 10245_1401.bval]
# [u'/tmp/downloads/NIFTI/10245_1401.nii.gz', u'/tmp/downloads/NIFTI/10245_1401.bvec', u'/tmp/downloads/NIFTI/10245_1401.bval'] have been created successfully
#
# 10319 (040510080217319) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '401': 'B0_ALFA1', '1401': 'IR_ALFA1 SENSE', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T1_Coronal', '202': 'B1_calibration', '301': 'T1_ALFA1', '302': 'T1_Coronal', '303': 'T1_Axial', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_Coronal', '903': 'FLAIR_Axial', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10319_1301.bvec, <File Object> 10319_1301.nii.gz, <File Object> 10319_1301.bval]
# [u'/tmp/downloads/NIFTI/10319_1301.bvec', u'/tmp/downloads/NIFTI/10319_1301.nii.gz', u'/tmp/downloads/NIFTI/10319_1301.bval'] have been created successfully
#
# 10329 (040510081116329) has the following sequences {'201': 'B1_calibration', '903': 'FLAIR_CORONAL', '203': 'B1_calibration', '901': 'FLAIR_ALFA1', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '904': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '404': 'T1_AXIAL', '403': 'T1_CORONAL', '1001': 'T2_ALFA1', '401': 'T1_ALFA1', '103': 'SmartBrain SENSE', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1401': 'IR_ALFA1', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10329_1301.bval, <File Object> 10329_1301.nii.gz, <File Object> 10329_1301.bvec]
# [u'/tmp/downloads/NIFTI/10329_1301.bval', u'/tmp/downloads/NIFTI/10329_1301.nii.gz', u'/tmp/downloads/NIFTI/10329_1301.bvec'] have been created successfully
#
# 10424 (040510310517424) has the following sequences {'601': 'RS_ALFA1 SENSE', '1301': 'T2_ALFA1', '1201': 'FLAIR_ALFA1', '701': 'SE-fMRI-AP SENSE', '1203': 'FLAIR_AXIAL', '1202': 'FLAIR_CORONAL', '1501': 'rDWI_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '501': 'rRS_ALFA1 SENSE', '201': 'B1_calibration', '202': 'B1_calibration', '1701': 'IR_ALFA1 SENSE', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'SmartBrain SENSE', '903': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '901': 'SmartBrain SENSE', '1601': 'DWI_ALFA1', '1101': 'B0_ALFA1', '801': 'SE-fMRI-PA SENSE', '1002': 'B1_calibration', '1001': 'B1_calibration'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10424_1601.bval, <File Object> 10424_1601.bvec, <File Object> 10424_1601.nii.gz]
# [u'/tmp/downloads/NIFTI/10424_1601.bval', u'/tmp/downloads/NIFTI/10424_1601.bvec', u'/tmp/downloads/NIFTI/10424_1601.nii.gz'] have been created successfully
#
# 10515 (040510270317515) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10515_1301.json, <File Object> 10515_1301.bvec, <File Object> 10515_1301.nii.gz, <File Object> 10515_1301.bval]
# [u'/tmp/downloads/NIFTI/10515_1301.json', u'/tmp/downloads/NIFTI/10515_1301.bvec', u'/tmp/downloads/NIFTI/10515_1301.nii.gz', u'/tmp/downloads/NIFTI/10515_1301.bval'] have been created successfully
#
# 10560 (040510080317560) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10560_1301.bval, <File Object> 10560_1301.nii.gz, <File Object> 10560_1301.bvec]
# [u'/tmp/downloads/NIFTI/10560_1301.bval', u'/tmp/downloads/NIFTI/10560_1301.nii.gz', u'/tmp/downloads/NIFTI/10560_1301.bvec'] have been created successfully
#
# 10613 (030410271016613) has the following sequences {'201': 'B1_calibration', '903': 'FLAIR_CORONAL', '203': 'B1_calibration', '901': 'FLAIR_ALFA1', '601': 'RS_ALFA1', '1301': 'DWI_ALFA1', '904': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP', '404': 'T1_AXIAL', '403': 'T1_CORONAL', '1001': 'T2_ALFA1', '401': 'T1_ALFA1', '1101': 'IR_ALFA1', '103': 'SmartBrain SENSE', '801': 'SE-fMRI-PA', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '501': 'rRS_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10613_1301.bval, <File Object> 10613_1301.bvec, <File Object> 10613_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/10613_1301.bval', u'/tmp/downloads/NIFTI/10613_1301.bvec', u'/tmp/downloads/NIFTI/10613_1301.nii.gz'] have been created successfully
#
# 10627 (040510050417627) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10627_1301.bval, <File Object> 10627_1301.bvec, <File Object> 10627_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/10627_1301.bval', u'/tmp/downloads/NIFTI/10627_1301.bvec', u'/tmp/downloads/NIFTI/10627_1301.nii.gz'] have been created successfully
#
# 10649 (040510180417649) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1401': 'IR_ALFA1 SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10649_1301.nii.gz, <File Object> 10649_1301.bvec, <File Object> 10649_1301.bval]
# [u'/tmp/downloads/NIFTI/10649_1301.nii.gz', u'/tmp/downloads/NIFTI/10649_1301.bvec', u'/tmp/downloads/NIFTI/10649_1301.bval'] have been created successfully
#
# 10696 (040510070317696) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10696_1301.bvec, <File Object> 10696_1301.bval, <File Object> 10696_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/10696_1301.bvec', u'/tmp/downloads/NIFTI/10696_1301.bval', u'/tmp/downloads/NIFTI/10696_1301.nii.gz'] have been created successfully
#
# 10711 (040510160517711) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'RS_ALFA1 SENSE', '0-OT2': 'rRS_ALFA1 SENSE', '301': 'T1_ALFA1', '302': 'T1_CORONAL', '303': 'T1_AXIAL', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_CORONAL', '903': 'FLAIR_AXIAL', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10711_1301.bval, <File Object> 10711_1301.nii.gz, <File Object> 10711_1301.bvec]
# [u'/tmp/downloads/NIFTI/10711_1301.bval', u'/tmp/downloads/NIFTI/10711_1301.nii.gz', u'/tmp/downloads/NIFTI/10711_1301.bvec'] have been created successfully
#
# 10724 (040510190617724) has the following sequences {'0-OT1': 'DWI_ALFA1', '201': 'B1_calibration', '1201': 'rDWI_ALFA1', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '902': 'Coronal', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '903': 'Axial', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '401': 'B0_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10724_1301.nii.gz, <File Object> 10724_1301.bvec, <File Object> 10724_1301.bval]
# [u'/tmp/downloads/NIFTI/10724_1301.nii.gz', u'/tmp/downloads/NIFTI/10724_1301.bvec', u'/tmp/downloads/NIFTI/10724_1301.bval'] have been created successfully
#
# 10779 (040510070317779) has the following sequences {'201': 'B1_calibration', '902': 'T1_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'rDWI_ALFA1', '903': 'T1_AXIAL', '301': 'B0_ALFA1', '1401': 'DWI_ALFA1', '1201': 'IR_ALFA1 SENSE', '701': 'SE-fMRI-AP SENSE', '901': 'T1_ALFA1', '1101': 'T2_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1003': 'FLAIR_AXIAL', '1002': 'FLAIR_CORONAL', '1001': 'FLAIR_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10779_1401.nii.gz, <File Object> 10779_1401.bvec, <File Object> 10779_1401.bval]
# [u'/tmp/downloads/NIFTI/10779_1401.nii.gz', u'/tmp/downloads/NIFTI/10779_1401.bvec', u'/tmp/downloads/NIFTI/10779_1401.bval'] have been created successfully
#
# 10810 (040510280217810) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10810_1301.bval, <File Object> 10810_1301.nii.gz, <File Object> 10810_1301.bvec]
# [u'/tmp/downloads/NIFTI/10810_1301.bval', u'/tmp/downloads/NIFTI/10810_1301.nii.gz', u'/tmp/downloads/NIFTI/10810_1301.bvec'] have been created successfully
#
# 10881 (040510100117881) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10881_1301.bval, <File Object> 10881_1301.nii.gz, <File Object> 10881_1301.bvec]
# [u'/tmp/downloads/NIFTI/10881_1301.bval', u'/tmp/downloads/NIFTI/10881_1301.nii.gz', u'/tmp/downloads/NIFTI/10881_1301.bvec'] have been created successfully
#
# 10949 (040510050417949) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T1_ALFA1', '0-OT3': 'T2_ALFA1', '0-OT2': 'IR_ALFA1 SENSE', '0-OT4': 'DWI_ALFA1', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'Coronal', '903': 'Axial', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 10949_1301.bvec, <File Object> 10949_1301.json, <File Object> 10949_1301.nii.gz, <File Object> 10949_1301.bval]
# [u'/tmp/downloads/NIFTI/10949_1301.bvec', u'/tmp/downloads/NIFTI/10949_1301.json', u'/tmp/downloads/NIFTI/10949_1301.nii.gz', u'/tmp/downloads/NIFTI/10949_1301.bval'] have been created successfully
#
# 11042 (030411201016042) has the following sequences {'0-OT1': 'T1_ALFA1', '0-OT3': 'FLAIR_Coronal', '0-OT2': 'FLAIR_ALFA1', '601': 'RS_ALFA1', '1301': 'rDWI_ALFA1', '301': 'B0_ALFA1', '1201': 'IR_ALFA1', '701': 'SE-fMRI-AP', '1504': 'FLAIR_Axial', '1503': 'FLAIR_Coronal', '404': 'T1_ALFA1_Axial', '403': 'T1_ALFA1_Coronal', '401': 'T1_ALFA1', '1101': 'T2_ALFA1', '103': 'SmartBrain SENSE', '801': 'SE-fMRI-PA', '101': 'SmartBrain SENSE', '1501': 'FLAIR_ALFA1', '1401': 'DWI_ALFA1', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '501': 'rRS_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11042_1401.nii.gz, <File Object> 11042_1401.bval, <File Object> 11042_1401.bvec]
# [u'/tmp/downloads/NIFTI/11042_1401.nii.gz', u'/tmp/downloads/NIFTI/11042_1401.bval', u'/tmp/downloads/NIFTI/11042_1401.bvec'] have been created successfully
#
# 11055 (040511270617055) has the following sequences {'0-OT1': 'T1_ALFA1', '201': 'B1_calibration', '1201': 'rDWI_ALFA1', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '902': 'FLAIR_CORONAL', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '903': 'FLAIR_AXIAL', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '401': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1401': 'IR_ALFA1 SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11055_1301.nii.gz, <File Object> 11055_1301.bvec, <File Object> 11055_1301.bval]
# [u'/tmp/downloads/NIFTI/11055_1301.nii.gz', u'/tmp/downloads/NIFTI/11055_1301.bvec', u'/tmp/downloads/NIFTI/11055_1301.bval'] have been created successfully
#
# 11111 (040511250717111) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11111_1301.nii.gz, <File Object> 11111_1301.bvec, <File Object> 11111_1301.bval]
# [u'/tmp/downloads/NIFTI/11111_1301.nii.gz', u'/tmp/downloads/NIFTI/11111_1301.bvec', u'/tmp/downloads/NIFTI/11111_1301.bval'] have been created successfully
#
# 11114 (030411151116114) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '203': 'B1_calibration', '404': 'T1_Axial', '403': 'T1_Coronal', '401': 'T1_ALFA1', '301': 'B0_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T2_ALFA1', '0-OT3': 'FLAIR_Coronal', '0-OT2': 'IR_ALFA1', '0-OT5': 'T1_Coronal', '0-OT4': 'FLAIR_Axial', '0-OT7': 'T1_ALFA1', '0-OT6': 'T1_Axial', '0-OT8': 'DWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '103': 'SmartBrain SENSE', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '903': 'FLAIR_Coronal', '901': 'FLAIR_ALFA1', '904': 'FLAIR_Axial', '1101': 'IR_ALFA1', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11114_1301.nii.gz, <File Object> 11114_1301.bvec, <File Object> 11114_1301.bval]
# [u'/tmp/downloads/NIFTI/11114_1301.nii.gz', u'/tmp/downloads/NIFTI/11114_1301.bvec', u'/tmp/downloads/NIFTI/11114_1301.bval'] have been created successfully
#
# 11125 (040511200617125) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'Axial', '0-OT3': 'IR_ALFA1 SENSE', '0-OT2': 'T1_ALFA1', '0-OT4': 'DWI_ALFA1', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'Coronal', '903': 'Axial', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11125_1301.nii.gz, <File Object> 11125_1301.bvec, <File Object> 11125_1301.bval]
# [u'/tmp/downloads/NIFTI/11125_1301.nii.gz', u'/tmp/downloads/NIFTI/11125_1301.bvec', u'/tmp/downloads/NIFTI/11125_1301.bval'] have been created successfully
#
# 11127 (040511141116127) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '203': 'B1_calibration', '404': 'T1_Axial', '403': 'T1_Coronal', '401': 'T1_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'IR_ALFA1', '0-OT3': 'T1_ALFA1', '0-OT2': 'DWI_ALFA1', '0-OT5': 'T1_Coronal', '0-OT4': 'T1_Axial', '301': 'B0_ALFA1', '701': 'SE-fMRI-AP SENSE', '103': 'SmartBrain SENSE', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '903': 'FLAIR_Coronal', '901': 'FLAIR_ALFA1', '904': 'FLAIR_Axial', '1101': 'IR_ALFA1', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11127_1301.bval, <File Object> 11127_1301.nii.gz, <File Object> 11127_1301.bvec]
# [u'/tmp/downloads/NIFTI/11127_1301.bval', u'/tmp/downloads/NIFTI/11127_1301.nii.gz', u'/tmp/downloads/NIFTI/11127_1301.bvec'] have been created successfully
#
# 11132 (040511070217132) has the following sequences {'201': 'B1_calibration', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'rDWI_ALFA1', '301': 'T1_ALFA1', '302': 'T1_CORONAL', '303': 'T1_AXIAL', '1201': 'IR_ALFA1 SENSE', '701': 'SE-fMRI-AP SENSE', '1401': 'DWI_ALFA1', '901': 'FLAIR_ALFA1', '401': 'B0_ALFA1', '1101': 'T2_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1003': 'FLAIR_AXIAL', '1002': 'FLAIR_CORONAL', '1001': 'FLAIR_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11132_1401.nii.gz, <File Object> 11132_1401.bval, <File Object> 11132_1401.bvec]
# [u'/tmp/downloads/NIFTI/11132_1401.nii.gz', u'/tmp/downloads/NIFTI/11132_1401.bval', u'/tmp/downloads/NIFTI/11132_1401.bvec'] have been created successfully
#
# 11248 (030411201016248) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '203': 'B1_calibration', '404': 'T1_Axial', '403': 'T1_Coronal', '401': 'T1_ALFA1', '301': 'B0_ALFA1', '0-OT10': 'rDWI_ALFA1', '501': 'rRS_ALFA1', '0-OT1': 'FLAIR_ALFA1', '0-OT3': 'FLAIR_Axial', '0-OT2': 'FLAIR_Coronal', '0-OT5': 'T1_Axial', '0-OT4': 'T1_Coronal', '0-OT7': 'T2_ALFA1', '0-OT6': 'IR_ALFA1', '0-OT9': 'DWI_ALFA1', '0-OT8': 'T1_ALFA1', '701': 'SE-fMRI-AP', '103': 'SmartBrain SENSE', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '903': 'FLAIR_Coronal', '901': 'FLAIR_ALFA1', '904': 'FLAIR_Axial', '1101': 'IR_ALFA1', '801': 'SE-fMRI-PA', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11248_1301.bval, <File Object> 11248_1301.nii.gz, <File Object> 11248_1301.bvec]
# [u'/tmp/downloads/NIFTI/11248_1301.bval', u'/tmp/downloads/NIFTI/11248_1301.nii.gz', u'/tmp/downloads/NIFTI/11248_1301.bvec'] have been created successfully
#
# 11257 (040511010317257) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11257_1301.bval, <File Object> 11257_1301.bvec, <File Object> 11257_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/11257_1301.bval', u'/tmp/downloads/NIFTI/11257_1301.bvec', u'/tmp/downloads/NIFTI/11257_1301.nii.gz'] have been created successfully
#
# 11262 (040511260417262) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'IR_ALFA1 SENSE', '0-OT2': 'FLAIR_ALFA1', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'Coronal', '903': 'Axial', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11262_1301.nii.gz, <File Object> 11262_1301.bvec, <File Object> 11262_1301.bval]
# [u'/tmp/downloads/NIFTI/11262_1301.nii.gz', u'/tmp/downloads/NIFTI/11262_1301.bvec', u'/tmp/downloads/NIFTI/11262_1301.bval'] have been created successfully
#
# 11273 (040511100117273) has the following sequences {'201': 'B1_calibration', '902': 'T1_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'rDWI_ALFA1', '903': 'T1_AXIAL', '301': 'B0_ALFA1', '1401': 'DWI_ALFA1', '1201': 'IR_ALFA1 SENSE', '701': 'SE-fMRI-AP SENSE', '901': 'T1_ALFA1', '401': 'T1_ALFA1', '1101': 'T2_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1003': 'FLAIR_AXIAL', '1002': 'FLAIR_CORONAL', '1001': 'FLAIR_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11273_1401.bvec, <File Object> 11273_1401.bval, <File Object> 11273_1401.nii.gz]
# [u'/tmp/downloads/NIFTI/11273_1401.bvec', u'/tmp/downloads/NIFTI/11273_1401.bval', u'/tmp/downloads/NIFTI/11273_1401.nii.gz'] have been created successfully
#
# 11291 (040511301116291) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '203': 'B1_calibration', '404': 'T1_Axial', '403': 'T1_Coronal', '401': 'T1_ALFA1', '1401': 'IR_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'IR_ALFA1', '0-OT3': 'T1_Coronal', '0-OT2': 'T1_ALFA1', '0-OT5': 'IR_ALFA1', '0-OT4': 'T1_Axial', '301': 'B0_ALFA1', '701': 'SE-fMRI-AP SENSE', '103': 'SmartBrain SENSE', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '903': 'FLAIR_Coronal', '901': 'FLAIR_ALFA1', '904': 'FLAIR_Axial', '1101': 'IR_ALFA1', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11291_1301.bval, <File Object> 11291_1301.nii.gz, <File Object> 11291_1301.bvec]
# [u'/tmp/downloads/NIFTI/11291_1301.bval', u'/tmp/downloads/NIFTI/11291_1301.nii.gz', u'/tmp/downloads/NIFTI/11291_1301.bvec'] have been created successfully
#
# 11387 (040511091116387) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '203': 'B1_calibration', '404': 'T1_Axial', '403': 'T1_Coronal', '401': 'T1_ALFA1', '1403': 'FLAIR_CORONAL', '1401': 'FLAIR_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T2_ALFA1', '0-OT3': 'FLAIR_ALFA1', '0-OT2': 'IR_ALFA1', '0-OT4': 'T1_ALFA1', '301': 'B0_ALFA1', '701': 'SE-fMRI-AP SENSE', '103': 'SmartBrain SENSE', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '1101': 'IR_ALFA1', '801': 'SE-fMRI-PA SENSE', '1404': 'FLAIR_AXIAL', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11387_1301.bval, <File Object> 11387_1301.nii.gz, <File Object> 11387_1301.bvec]
# [u'/tmp/downloads/NIFTI/11387_1301.bval', u'/tmp/downloads/NIFTI/11387_1301.nii.gz', u'/tmp/downloads/NIFTI/11387_1301.bvec'] have been created successfully
#
# 11397 (040511280617397) has the following sequences {'0-OT1': 'T1_ALFA1', '201': 'B1_calibration', '1201': 'rDWI_ALFA1', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '902': 'FLAIR_CORONAL', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '903': 'FLAIR_AXIAL', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '401': 'B0_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11397_1301.bval, <File Object> 11397_1301.bvec, <File Object> 11397_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/11397_1301.bval', u'/tmp/downloads/NIFTI/11397_1301.bvec', u'/tmp/downloads/NIFTI/11397_1301.nii.gz'] have been created successfully
#
# 11478 (040511251016478) has the following sequences {'201': 'B1_calibration', '903': 'FLAIR_CORONAL', '203': 'B1_calibration', '901': 'FLAIR_ALFA1', '601': 'RS_ALFA1', '1301': 'DWI_ALFA1', '904': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP', '404': 'T1_AXIAL', '403': 'T1_CORONAL', '1001': 'T2_ALFA1', '401': 'T1_ALFA1', '1101': 'IR_ALFA1', '103': 'SmartBrain SENSE', '801': 'SE-fMRI-PA', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '501': 'rRS_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11478_1301.nii.gz, <File Object> 11478_1301.bvec, <File Object> 11478_1301.bval]
# [u'/tmp/downloads/NIFTI/11478_1301.nii.gz', u'/tmp/downloads/NIFTI/11478_1301.bvec', u'/tmp/downloads/NIFTI/11478_1301.bval'] have been created successfully
#
# 11514 (040511180417514) has the following sequences {'201': 'B1_calibration', '1301': 'IR_ALFA1 SENSE', '1201': 'T2_ALFA1', '701': 'rRS_ALFA1 SENSE', '1501': 'DWI_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1401': 'rDWI_ALFA1', '0-OT1': 'T1_ALFA1', '202': 'B1_calibration', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '901': 'SE-fMRI-AP SENSE', '1601': 'T1_ALFA1', '1603': 'T1_AXIAL', '1602': 'T1_CORONAL', '1102': 'FLAIR_CORONAL', '1103': 'FLAIR_AXIAL', '1101': 'FLAIR_ALFA1', '801': 'RS_ALFA1 SENSE', '1001': 'SE-fMRI-PA SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11514_1501.bval, <File Object> 11514_1501.bvec, <File Object> 11514_1501.nii.gz]
# [u'/tmp/downloads/NIFTI/11514_1501.bval', u'/tmp/downloads/NIFTI/11514_1501.bvec', u'/tmp/downloads/NIFTI/11514_1501.nii.gz'] have been created successfully
#
# 11540 (040511210617540) has the following sequences {'0-OT1': 'Coronal', '201': 'B1_calibration', '1201': 'rDWI_ALFA1', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '902': 'Coronal', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '903': 'Axial', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '401': 'B0_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11540_1301.nii.gz, <File Object> 11540_1301.bvec, <File Object> 11540_1301.bval]
# [u'/tmp/downloads/NIFTI/11540_1301.nii.gz', u'/tmp/downloads/NIFTI/11540_1301.bvec', u'/tmp/downloads/NIFTI/11540_1301.bval'] have been created successfully
#
# 11587 (040511010217587) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1401': 'IR_ALFA1 SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11587_1301.bvec, <File Object> 11587_1301.bval, <File Object> 11587_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/11587_1301.bvec', u'/tmp/downloads/NIFTI/11587_1301.bval', u'/tmp/downloads/NIFTI/11587_1301.nii.gz'] have been created successfully
#
# 11593 (040511240117593) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'rDWI_ALFA1', '1201': 'IR_ALFA1 SENSE', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '1401': 'DWI_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T1_ALFA1', '0-OT3': 'T1_AXIAL', '0-OT2': 'T1_CORONAL', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'T1_CORONAL', '903': 'T1_AXIAL', '901': 'T1_ALFA1', '1101': 'T2_ALFA1', '801': 'SE-fMRI-PA SENSE', '1003': 'FLAIR_AXIAL', '1002': 'FLAIR_CORONAL', '1001': 'FLAIR_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11593_1401.nii.gz, <File Object> 11593_1401.bvec, <File Object> 11593_1401.bval]
# [u'/tmp/downloads/NIFTI/11593_1401.nii.gz', u'/tmp/downloads/NIFTI/11593_1401.bvec', u'/tmp/downloads/NIFTI/11593_1401.bval'] have been created successfully
#
# 11656 (040511210317656) has the following sequences {'201': 'B1_calibration', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'rDWI_ALFA1', '301': 'B0_ALFA1', '1401': 'DWI_ALFA1', '1201': 'IR_ALFA1 SENSE', '701': 'SE-fMRI-AP SENSE', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'T2_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1003': 'FLAIR_AXIAL', '1002': 'FLAIR_CORONAL', '1001': 'FLAIR_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11656_1401.bvec, <File Object> 11656_1401.bval, <File Object> 11656_1401.nii.gz]
# [u'/tmp/downloads/NIFTI/11656_1401.bvec', u'/tmp/downloads/NIFTI/11656_1401.bval', u'/tmp/downloads/NIFTI/11656_1401.nii.gz'] have been created successfully
#
# 11711 (030411081116711) has the following sequences {'201': 'B1_calibration', '903': 'FLAIR_CORONAL', '203': 'B1_calibration', '901': 'FLAIR_ALFA1', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '904': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '404': 'T1_AXIAL', '403': 'T1_CORONAL', '1001': 'T2_ALFA1', '401': 'T1_ALFA1', '1101': 'IR_ALFA1', '103': 'SmartBrain SENSE', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11711_1301.nii.gz, <File Object> 11711_1301.bvec, <File Object> 11711_1301.bval]
# [u'/tmp/downloads/NIFTI/11711_1301.nii.gz', u'/tmp/downloads/NIFTI/11711_1301.bvec', u'/tmp/downloads/NIFTI/11711_1301.bval'] have been created successfully
#
# 11742 (040511081116742) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '203': 'B1_calibration', '404': 'T1_Axial', '403': 'T1_Coronal', '401': 'T1_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T1_ALFA1', '0-OT3': 'T2_ALFA1', '0-OT2': 'IR_ALFA1', '0-OT5': 'T1_Coronal', '0-OT4': 'T1_Axial', '0-OT6': 'DWI_ALFA1', '301': 'B0_ALFA1', '701': 'SE-fMRI-AP SENSE', '103': 'SmartBrain SENSE', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '903': 'FLAIR_Coronal', '901': 'FLAIR_ALFA1', '904': 'FLAIR_Axial', '1101': 'IR_ALFA1', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11742_1301.bval, <File Object> 11742_1301.nii.gz, <File Object> 11742_1301.bvec]
# [u'/tmp/downloads/NIFTI/11742_1301.bval', u'/tmp/downloads/NIFTI/11742_1301.nii.gz', u'/tmp/downloads/NIFTI/11742_1301.bvec'] have been created successfully
#
# 11745 (040511020517745) has the following sequences {'0-OT1': 'T1_ALFA1', '201': 'B1_calibration', '1201': 'rDWI_ALFA1', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '902': 'FLAIR_CORONAL', '301': 'T1_ALFA1', '302': 'T1_CORONAL', '303': 'T1_AXIAL', '903': 'FLAIR_TRANVERSAL', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '401': 'B0_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11745_1301.nii.gz, <File Object> 11745_1301.bval, <File Object> 11745_1301.bvec]
# [u'/tmp/downloads/NIFTI/11745_1301.nii.gz', u'/tmp/downloads/NIFTI/11745_1301.bval', u'/tmp/downloads/NIFTI/11745_1301.bvec'] have been created successfully
#
# 11747 (040511170117747) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '404': 'T1_AXIAL', '403': 'T1_CORONAL', '401': 'T1_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'FLAIR_Coronal', '0-OT3': 'DWI_ALFA1', '0-OT2': 'FLAIR_Axial', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_Coronal', '901': 'FLAIR_ALFA1', '904': 'FLAIR_Axial', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11747_1301.bval, <File Object> 11747_1301.bvec, <File Object> 11747_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/11747_1301.bval', u'/tmp/downloads/NIFTI/11747_1301.bvec', u'/tmp/downloads/NIFTI/11747_1301.nii.gz'] have been created successfully
#
# 11829 (030411261016829) has the following sequences {'201': 'B1_calibration', '903': 'FLAIR_CORONAL', '203': 'B1_calibration', '901': 'FLAIR_ALFA1', '601': 'RS_ALFA1', '1301': 'DWI_ALFA1', '904': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP', '404': 'T1_AXIAL', '403': 'T1_CORONAL', '1001': 'T2_ALFA1', '401': 'T1_ALFA1', '1101': 'IR_ALFA1', '103': 'SmartBrain SENSE', '801': 'SE-fMRI-PA', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '501': 'rRS_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11829_1301.nii.gz, <File Object> 11829_1301.bvec, <File Object> 11829_1301.bval]
# [u'/tmp/downloads/NIFTI/11829_1301.nii.gz', u'/tmp/downloads/NIFTI/11829_1301.bvec', u'/tmp/downloads/NIFTI/11829_1301.bval'] have been created successfully
#
# 11866 (040511010317866) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'IR_ALFA1 SENSE', '0-OT2': 'T1_ALFA1', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_CORONAL', '903': 'FLAIR_AXIAL', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 11866_1301.bvec, <File Object> 11866_1301.nii.gz, <File Object> 11866_1301.bval]
# [u'/tmp/downloads/NIFTI/11866_1301.bvec', u'/tmp/downloads/NIFTI/11866_1301.nii.gz', u'/tmp/downloads/NIFTI/11866_1301.bval'] have been created successfully
#
# 12118 (040512210617118) has the following sequences {'0-OT1': 'IR_ALFA1 SENSE', '201': 'B1_calibration', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '902': 'FLAIR_CORONAL', '301': 'B0_ALFA1', '903': 'FLAIR_AXIAL', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 12118_1301.nii.gz, <File Object> 12118_1301.bvec, <File Object> 12118_1301.bval]
# [u'/tmp/downloads/NIFTI/12118_1301.nii.gz', u'/tmp/downloads/NIFTI/12118_1301.bvec', u'/tmp/downloads/NIFTI/12118_1301.bval'] have been created successfully
#
# 12184 (040512221116184) has the following sequences {'0-OT1': 'FLAIR_ALFA1', '201': 'B1_calibration', '203': 'B1_calibration', '901': 'FLAIR_ALFA1', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '904': 'FLAIR_AXIAL', '903': 'FLAIR_CORONAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '404': 'T1_AXIAL', '403': 'T1_CORONAL', '1001': 'T2_ALFA1', '401': 'T1_ALFA1', '103': 'SmartBrain SENSE', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1401': 'IR_ALFA1', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 12184_1301.bval, <File Object> 12184_1301.nii.gz, <File Object> 12184_1301.bvec]
# [u'/tmp/downloads/NIFTI/12184_1301.bval', u'/tmp/downloads/NIFTI/12184_1301.nii.gz', u'/tmp/downloads/NIFTI/12184_1301.bvec'] have been created successfully
#
# ...
# Resource files of sequence DWI_ALFA1: [<File Object> 66027_1301.bval, <File Object> 66027_1301.bvec, <File Object> 66027_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/66027_1301.bval', u'/tmp/downloads/NIFTI/66027_1301.bvec', u'/tmp/downloads/NIFTI/66027_1301.nii.gz'] have been created successfully
#
# 66045 (040566191216045) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'FLAIR_ALFA1', '0-OT3': 'FLAIR_Axial', '0-OT2': 'DWI_ALFA1', '0-OT5': 'T1_Coronal', '0-OT4': 'T1_ALFA1', '0-OT7': 'IR_ALFA1 SENSE', '0-OT6': 'T1_Axial', '301': 'T1_ALFA1', '302': 'T1_Coronal', '303': 'T1_Axial', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_Coronal', '903': 'FLAIR_Axial', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66045_1301.bval, <File Object> 66045_1301.bvec, <File Object> 66045_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/66045_1301.bval', u'/tmp/downloads/NIFTI/66045_1301.bvec', u'/tmp/downloads/NIFTI/66045_1301.nii.gz'] have been created successfully
#
# 66067 (040566310117067) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T1_ALFA1', '0-OT3': 'IR_ALFA1 SENSE', '0-OT2': 'FLAIR_ALFA1', '0-OT5': 'DWI_ALFA1', '0-OT4': 'T2_ALFA1', '301': 'T1_ALFA1', '302': 'T1_Coronal', '303': 'T1_Axial', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_Coronal', '903': 'FLAIR_Axial', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66067_1301.nii.gz, <File Object> 66067_1301.bval, <File Object> 66067_1301.bvec]
# [u'/tmp/downloads/NIFTI/66067_1301.nii.gz', u'/tmp/downloads/NIFTI/66067_1301.bval', u'/tmp/downloads/NIFTI/66067_1301.bvec'] have been created successfully
#
# 66100 (040566250417100) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T1_ALFA1', '0-OT3': 'DWI_ALFA1', '0-OT2': 'Axial', '0-OT5': 'T2_ALFA1', '0-OT4': 'IR_ALFA1 SENSE', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'Coronal', '903': 'Axial', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66100_1301.nii.gz, <File Object> 66100_1301.bvec, <File Object> 66100_1301.bval]
# [u'/tmp/downloads/NIFTI/66100_1301.nii.gz', u'/tmp/downloads/NIFTI/66100_1301.bvec', u'/tmp/downloads/NIFTI/66100_1301.bval'] have been created successfully
#
# 66162 (040566250417162) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '1502': 'Coronal', '1503': 'Axial', '1501': 'T1_ALFA1', '403': 'Axial', '402': 'Coronal', '401': 'T1_ALFA1', '1401': 'DWI_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'IR_ALFA1 SENSE', '0-OT3': 'T2_ALFA1', '0-OT2': 'Axial', '0-OT5': 'T1_ALFA1', '0-OT4': 'T1_ALFA1', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'Coronal', '903': 'Axial', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66162_1401.nii.gz, <File Object> 66162_1401.bval, <File Object> 66162_1401.bvec]
# [u'/tmp/downloads/NIFTI/66162_1401.nii.gz', u'/tmp/downloads/NIFTI/66162_1401.bval', u'/tmp/downloads/NIFTI/66162_1401.bvec'] have been created successfully
#
# 66224 (040566291116224) has the following sequences {'201': 'B1_calibration', '903': 'FLAIR_CORONAL', '203': 'B1_calibration', '901': 'FLAIR_ALFA1', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '904': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '404': 'T1_AXIAL', '403': 'T1_CORONAL', '1001': 'T2_ALFA1', '401': 'T1_ALFA1', '103': 'SmartBrain SENSE', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1401': 'IR_ALFA1', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66224_1301.bval, <File Object> 66224_1301.nii.gz, <File Object> 66224_1301.bvec]
# [u'/tmp/downloads/NIFTI/66224_1301.bval', u'/tmp/downloads/NIFTI/66224_1301.nii.gz', u'/tmp/downloads/NIFTI/66224_1301.bvec'] have been created successfully
#
# 66237 (040566150317237) has the following sequences {'201': 'B1_calibration', '601': 'rRS_ALFA1 SENSE', '1301': 'rDWI_ALFA1', '1201': 'IR_ALFA1 SENSE', '701': 'RS_ALFA1 SENSE', '1501': 'IR_ALFA1 SENSE', '1401': 'DWI_ALFA1', '502': 'T1_CORONAL', '503': 'T1_AXIAL', '501': 'T1_ALFA1', '0-OT1': 'IR_ALFA1 SENSE', '202': 'B1_calibration', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '901': 'SE-fMRI-PA SENSE', '1101': 'T2_ALFA1', '801': 'SE-fMRI-AP SENSE', '1003': 'FLAIR_AXIAL', '1002': 'FLAIR_CORONAL', '1001': 'FLAIR_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66237_1401.bvec, <File Object> 66237_1401.nii.gz, <File Object> 66237_1401.bval]
# [u'/tmp/downloads/NIFTI/66237_1401.bvec', u'/tmp/downloads/NIFTI/66237_1401.nii.gz', u'/tmp/downloads/NIFTI/66237_1401.bval'] have been created successfully
#
# 66249 (040566021116249) has the following sequences {'601': 'RS_ALFA1', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP', '1503': 'T1_Coronal', '1501': 'T1_ALFA1', '1504': 'T1_Axial', '501': 'rRS_ALFA1', '0-OT1': 'T1_Axial', '0-OT3': 'IR_ALFA1', '0-OT2': 'FLAIR_ALFA1', '0-OT5': 'T1_ALFA1', '0-OT4': 'T2_ALFA1', '0-OT6': 'T1_ALFA1', '301': 'B0_ALFA1', '103': 'SmartBrain SENSE', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '903': 'FLAIR_Coronal', '901': 'FLAIR_ALFA1', '904': 'FLAIR_Axial', '1101': 'IR_ALFA1', '801': 'SE-fMRI-PA', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66249_1301.bvec, <File Object> 66249_1301.bval, <File Object> 66249_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/66249_1301.bvec', u'/tmp/downloads/NIFTI/66249_1301.bval', u'/tmp/downloads/NIFTI/66249_1301.nii.gz'] have been created successfully
#
# 66296 (040566170117296) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '403': 'T1_Axial', '402': 'T1_Coronal', '401': 'T1_ALFA1', '301': 'B0_ALFA1', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T1_Axial', '0-OT3': 'FLAIR_ALFA1', '0-OT2': 'T1_Coronal', '0-OT5': 'FLAIR_Axial', '0-OT4': 'FLAIR_Coronal', '0-OT7': 'T2_ALFA1', '0-OT6': 'IR_ALFA1 SENSE', '0-OT8': 'DWI_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_ALFA1 SENSE', '903': 'FLAIR_Coronal', '901': 'FLAIR_ALFA1', '904': 'FLAIR_Axial', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66296_1301.bval, <File Object> 66296_1301.bvec, <File Object> 66296_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/66296_1301.bval', u'/tmp/downloads/NIFTI/66296_1301.bvec', u'/tmp/downloads/NIFTI/66296_1301.nii.gz'] have been created successfully
#
# 66301 (040566040417301) has the following sequences {'201': 'B1_calibration', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'rDWI_ALFA1', '301': 'T1_ALFA1', '302': 'T1_CORONAL', '303': 'T1_AXIAL', '1201': 'IR_ALFA1 SENSE', '701': 'B0_ALFA1', '1401': 'DWI_ALFA1', '901': 'SE-fMRI-PA SENSE', '401': 'B0_ALFA1', '1101': 'T2_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-AP SENSE', '101': 'SmartBrain SENSE', '1003': 'FLAIR_AXIAL', '1002': 'FLAIR_CORONAL', '1001': 'FLAIR_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66301_1401.bval, <File Object> 66301_1401.nii.gz, <File Object> 66301_1401.bvec]
# [u'/tmp/downloads/NIFTI/66301_1401.bval', u'/tmp/downloads/NIFTI/66301_1401.nii.gz', u'/tmp/downloads/NIFTI/66301_1401.bvec'] have been created successfully
#
# 66488 (040566060617488) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '1401': 'IR_ALFA1 SENSE', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'T1_ALFA1', '0-OT2': 'IR_ALFA1 SENSE', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'FLAIR_CORONAL', '903': 'FLAIR_AXIAL', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66488_1301.bval, <File Object> 66488_1301.nii.gz, <File Object> 66488_1301.bvec]
# [u'/tmp/downloads/NIFTI/66488_1301.bval', u'/tmp/downloads/NIFTI/66488_1301.nii.gz', u'/tmp/downloads/NIFTI/66488_1301.bvec'] have been created successfully
#
# 66489 (040566060617489) has the following sequences {'0-OT1': 'T1_ALFA1', '0-OT3': 'DWI_ALFA1', '0-OT2': 'T1_ALFA1', '601': 'rRS_ALFA1 SENSE', '1301': 'rDWI_ALFA1', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '1201': 'IR_ALFA1 SENSE', '701': 'RS_ALFA1 SENSE', '1401': 'DWI_ALFA1', '901': 'SE-fMRI-PA SENSE', '401': 'B0_ALFA1', '1101': 'T2_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-AP SENSE', '101': 'SmartBrain SENSE', '1003': 'Axial', '1002': 'Coronal', '1001': 'FLAIR_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 66489_1401.bvec, <File Object> 66489_1401.bval, <File Object> 66489_1401.nii.gz]
# [u'/tmp/downloads/NIFTI/66489_1401.bvec', u'/tmp/downloads/NIFTI/66489_1401.bval', u'/tmp/downloads/NIFTI/66489_1401.nii.gz'] have been created successfully
#
# 77012 (040577090517012) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 77012_1301.nii.gz, <File Object> 77012_1301.bvec, <File Object> 77012_1301.bval]
# [u'/tmp/downloads/NIFTI/77012_1301.nii.gz', u'/tmp/downloads/NIFTI/77012_1301.bvec', u'/tmp/downloads/NIFTI/77012_1301.bval'] have been created successfully
#
# 77101 (040577230517101) has the following sequences {'201': 'B1_calibration', '1301': 'rRS_ALFA1 SENSE', '1201': 'DWI_ALFA1', '202': 'B1_calibration', '1501': 'SE-fMRI-AP SENSE', '403': 'Coronal', '402': 'Axial', '401': 'T1_ALFA1', '1401': 'RS_ALFA1 SENSE', '0-OT1': 'Axial', '0-OT3': 'IR_ALFA1 SENSE', '0-OT2': 'T2_ALFA1', '0-OT4': 'T1_ALFA1', '301': 'B0_ALFA1', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'Coronal', '903': 'Axial', '901': 'FLAIR_ALFA1', '1601': 'SE-fMRI-PA SENSE', '1101': 'rDWI_ALFA1', '801': 'T2_ALFA1', '1001': 'IR_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 77101_1201.bvec, <File Object> 77101_1201.nii.gz, <File Object> 77101_1201.bval]
# [u'/tmp/downloads/NIFTI/77101_1201.bvec', u'/tmp/downloads/NIFTI/77101_1201.nii.gz', u'/tmp/downloads/NIFTI/77101_1201.bval'] have been created successfully
#
# 77104 (040577261016104) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '203': 'B1_calibration', '405': 'T1_Axial', '404': 'VWIP T1_Axial', '403': 'T1_Coronal', '401': 'T1_ALFA1', '501': 'rRS_ALFA1', '0-OT1': 'DWI_ALFA1', '0-OT3': 'T1_ALFA1', '0-OT2': 'IR_ALFA1', '0-OT5': 'SE-fMRI-AP', '0-OT4': 'T2_ALFA1', '0-OT6': 'FLAIR_ALFA1', '301': 'B0_ALFA1', '701': 'SE-fMRI-AP', '103': 'SmartBrain SENSE', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '903': 'FLAIR_Coronal', '901': 'FLAIR_ALFA1', '904': 'FLAIR_Axial', '1101': 'IR_ALFA1', '801': 'SE-fMRI-PA', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 77104_1301.bval, <File Object> 77104_1301.bvec, <File Object> 77104_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/77104_1301.bval', u'/tmp/downloads/NIFTI/77104_1301.bvec', u'/tmp/downloads/NIFTI/77104_1301.nii.gz'] have been created successfully
#
# 77164 (040577020517164) has the following sequences {'201': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '202': 'B1_calibration', '401': 'B0_ALFA1', '1401': 'IR_ALFA1 SENSE', '501': 'rRS_ALFA1 SENSE', '0-OT1': 'SmartBrain SENSE', '0-OT3': 'Axial', '0-OT2': 'Coronal', '0-OT4': 'T1_ALFA1', '301': 'T1_ALFA1', '302': 'Coronal', '303': 'Axial', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '101': 'SmartBrain SENSE', '902': 'Coronal', '903': 'Axial', '901': 'FLAIR_ALFA1', '1101': 'IR_ALFA1 SENSE', '801': 'SE-fMRI-PA SENSE', '1001': 'T2_ALFA1'}
# Resource files of sequence DWI_ALFA1: [<File Object> 77164_1301.bval, <File Object> 77164_1301.bvec, <File Object> 77164_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/77164_1301.bval', u'/tmp/downloads/NIFTI/77164_1301.bvec', u'/tmp/downloads/NIFTI/77164_1301.nii.gz'] have been created successfully
#
# 77224 (040577151116224) has the following sequences {'201': 'B1_calibration', '903': 'FLAIR_CORONAL', '203': 'B1_calibration', '901': 'FLAIR_ALFA1', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '904': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '404': 'T1_AXIAL', '403': 'T1_CORONAL', '1001': 'T2_ALFA1', '401': 'T1_ALFA1', '1101': 'IR_ALFA1', '103': 'SmartBrain SENSE', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '104': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 77224_1301.bval, <File Object> 77224_1301.nii.gz, <File Object> 77224_1301.bvec]
# [u'/tmp/downloads/NIFTI/77224_1301.bval', u'/tmp/downloads/NIFTI/77224_1301.nii.gz', u'/tmp/downloads/NIFTI/77224_1301.bvec'] have been created successfully
#
# 77341 (040577070217341) has the following sequences {'201': 'B1_calibration', '902': 'FLAIR_CORONAL', '202': 'B1_calibration', '601': 'RS_ALFA1 SENSE', '1301': 'DWI_ALFA1', '903': 'FLAIR_AXIAL', '301': 'B0_ALFA1', '1201': 'rDWI_ALFA1', '701': 'SE-fMRI-AP SENSE', '901': 'FLAIR_ALFA1', '403': 'T1_AXIAL', '402': 'T1_CORONAL', '401': 'T1_ALFA1', '1101': 'IR_ALFA1 SENSE', '102': 'SmartBrain SENSE', '103': 'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN', '801': 'SE-fMRI-PA SENSE', '101': 'SmartBrain SENSE', '1001': 'T2_ALFA1', '501': 'rRS_ALFA1 SENSE'}
# Resource files of sequence DWI_ALFA1: [<File Object> 77341_1301.bval, <File Object> 77341_1301.bvec, <File Object> 77341_1301.nii.gz]
# [u'/tmp/downloads/NIFTI/77341_1301.bval', u'/tmp/downloads/NIFTI/77341_1301.bvec', u'/tmp/downloads/NIFTI/77341_1301.nii.gz'] have been created successfully

# %% [markdown]
# Are there any missing subjects?

# %%
import os.path as osp
from glob import glob
import pandas as pd

wd = '/tmp/downloads/NIFTI'
t = [[subject, len(glob(osp.join(wd, '%s*'%subject)))] for subject in subjects]
df = pd.DataFrame(t, columns=['subject', 'n'])

missing = df[df['n']==0]['subject'].tolist()
print('Missing subjects: %s'%missing)
# Out:
# Missing subjects: ['10065']

# %% [markdown]
# Applying online protocol validation on first missing subject (first experiment if any)

# %%
first = missing[0]
expid = xnat.subject_experiments(central, project, first)[0].id()
destination = [['goperto@barcelonabeta.org'], ['goperto@barcelonabeta.org']]
res, logs = xnat.check_session(central, expid, destination=destination, send_mail=True)
print('%s resulted with %s'%(first, ['SUCCESS', 'WARNING', 'ERRORS'][res]))
logs
# Out:
# 10065 resulted with WARNING
# ['Ignoring sequence 0-OT1',
#  'Ignoring sequence 0-MR1',
#  'Ignoring sequence 0-MR2',
#  'rRS_ALFA1 SENSE is found as rRS_ALFA1',
#  'RS_ALFA1 SENSE is found as RS_ALFA1',
#  'SE-fMRI-AP SENSE is found as SE-fMRI-AP',
#  'SE-fMRI-PA SENSE is found as SE-fMRI-PA',
#  '<br> ===== Missing ========',
#  'T1_CORONAL missing',
#  'T1_AXIAL missing',
#  'FLAIR_CORONAL missing',
#  'FLAIR_AXIAL missing',
#  '<br> ========= Not identified ==========',
#  '<br> ========= Silently identified ==========',
#  'SmartBrain SENSE silently identified',
#  'SmartBrain SENSE silently identified',
#  'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN silently identified',
#  'B1_calibration silently identified',
#  'B1_calibration silently identified',
#  'B0_ALFA1 silently identified']

# %%
# Out:
# 84
