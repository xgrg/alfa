# %%
import sys, string
sys.path.append('/home/grg/git/thesaurus/')
import thesaurus as th
jf = '/home/grg/git/thesaurus/alfa_dwi_pipeline_aug2016.json'
dd = '/home/grg/data/AmylStaging'
json_io = '/home/grg/git/thesaurus/alfa_dwi_pipeline_io_aug2016.json'
step = 'ants_dwi_to_t1'

subjects = [string.atoi(e) for e in open('/tmp/amyloid_subjects.txt').read().split('\n') if e != '']
failed = [12118, 13041, 55854, 10162, 10515, 10627, 10649, 10711, 10949, 11262, 11514, 11745, 12279, 12741, 12991, 13035, 13105, 13107, 13193, 13259, 
             21136, 21138, 44008, 44301, 44396, 66008, 66027, 66100, 66162, 66301, 77012, 77164]
subjects = [e for e in subjects if not e in failed]

a = th.ALFAHelper(directory=dd, jsonfile=json_io)

cmds = []
for s in subjects:  
    cmd = a.parse_command(str(s), step, jsonfile=jf)
    cmds.append(cmd)
 
# Writing commands in a textfile
fp1 = '/tmp/%s.sh'%step
fp2 = '/tmp/%s.workflow'%step
w = open(fp1, 'w')
for e in cmds:
    w.write('%s\n'%e)
w.close()

import sys
sys.path.append('/home/grg/git/alfa')
import create_workflow as cw
names = [str(e) for e in subjects]

cw.create_workflow(fp1, fp2, names=names, verbose=True)
# Out:
# [['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10019/T1/10019_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10019/DWI/10019_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10019/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10044/T1/10044_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10044/DWI/10044_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10044/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10065/T1/10065_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10065/DWI/10065_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10065/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10070/T1/10070_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10070/DWI/10070_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10070/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10137/T1/10137_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10137/DWI/10137_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10137/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10200/T1/10200_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10200/DWI/10200_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10200/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10225/T1/10225_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10225/DWI/10225_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10225/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10235/T1/10235_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10235/DWI/10235_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10235/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10245/T1/10245_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10245/DWI/10245_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10245/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10319/T1/10319_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10319/DWI/10319_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10319/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10329/T1/10329_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10329/DWI/10329_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10329/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10424/T1/10424_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10424/DWI/10424_B0_brain_seg_1.nii.gz,', '1,', '4]', '-r', 'Gauss[0,3]', '-t', 'Elast[1.5]', '-i', '30x20x10', '-o', '/home/grg/data/AmylStaging/10424/DWI/ants_elast_dwi-to-t1_.nii.gz'], ['ANTS', '3', '-m', 'CC[', '/home/grg/data/AmylStaging/10560/T1/10560_mabonlm_nobias_spm_c2_d2.nii.gz,', '/home/grg/data/AmylStaging/10560/DWI/10560_B0_brain_s ...

# %%
cmds[0]
# Out:
# u'ANTS 3 -m CC[ /home/grg/data/AmylStaging/10019/T1/10019_mabonlm_nobias_spm_c2_d2.nii.gz, /home/grg/data/AmylStaging/10019/DWI/10019_B0_brain_seg_1.nii.gz, 1, 4] -r Gauss[0,3] -t Elast[1.5] -i 30x20x10 -o /home/grg/data/AmylStaging/10019/DWI/ants_elast_dwi-to-t1_.nii.gz'

# %% [markdown]
# ### ANTs using Nipype

# %%
dd = '/tmp/nipype'
import os.path as osp
from nipype.interfaces.ants import ANTS
reg = ANTS()
reg.inputs.fixed_image = osp.join(dd, '55854_mabonlm_nobias_spm_c2.nii')
reg.inputs.moving_image = osp.join(dd, '55854_B0_brain_seg_1.nii.gz')
reg.inputs.output_transform_prefix = 'ants_elast_dwi-to-t1_.nii.gz'
reg.inputs.dimension = 3
reg.inputs.metric = ['CC']*2
reg.inputs.radius = [4]*2
reg.inputs.transformation_model = 'Elast'
reg.inputs.gradient_step_length = 1.5
reg.inputs.number_of_iterations = [30,20,10]
reg.inputs.regularization = 'Gauss'
reg.inputs.regularization_deformation_field_sigma = 3
reg.inputs.regularization_gradient_field_sigma = 0
reg.cmdline
# Out:
# u'ANTS 3 --image-metric CC[ /tmp/nipype/55854_mabonlm_nobias_spm_c2.nii, /tmp/nipype/55854_B0_brain_seg_1.nii.gz, 1, 4 ] --number-of-iterations 30x20x10 --output-naming ants_elast_dwi-to-t1_.nii.gz --regularization Gauss[0.0,3.0] --transformation-model Elast[1.5] --use-Histogram-Matching 0'

# %%
from nipype.interfaces.ants import WarpImageMultiTransform
w = WarpImageMultiTransform()
w.inputs

# %%
dd = '/tmp/nipype'
import os.path as osp
from nipype.interfaces.ants import ANTS
reg = Registration()

reg.inputs.fixed_image = osp.join(dd, '55854_mabonlm_nobias_spm_c2.nii')
reg.inputs.moving_image = osp.join(dd, '55854_B0_brain_seg_1.nii.gz')
reg.inputs.output_transform_prefix = 'ants_elast_dwi-to-t1_'
reg.inputs.initial_moving_transform = 'trans.mat'
reg.inputs.transforms = ['Affine', 'SyN']
reg.inputs.transform_parameters = [(2.0,), (0.25, 3.0, 0.0)]
reg.inputs.number_of_iterations = [[1500, 200], [100, 50, 30]]
reg.inputs.dimension = 3
reg.inputs.write_composite_transform = True
reg.inputs.collapse_output_transforms = False
reg.inputs.initialize_transforms_per_stage = False
reg.inputs.metric = ['CC']*2
reg.inputs.metric_weight = [1]*2 # Default (value ignored currently by ANTs)
reg.inputs.radius_or_number_of_bins = [4]*2
reg.inputs.convergence_threshold = [1.e-8, 1.e-9]
reg.inputs.convergence_window_size = [20]*2
reg.inputs.smoothing_sigmas = [[1,0], [2,1,0]]
reg.inputs.sigma_units = ['vox'] * 2
reg.inputs.shrink_factors = [[2,1], [3,2,1]]
reg.inputs.use_estimate_learning_rate_once = [True, True]
reg.inputs.use_histogram_matching = [True, True] # This is the default
reg.inputs.output_warped_image = '55854_B0_warped_image.nii.gz'
reg.cmdline
# Out:
# u'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 0 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ ants_elast_dwi-to-t1_, 55854_B0_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric CC[ /tmp/nipype/55854_mabonlm_nobias_spm_c2.nii, /tmp/nipype/55854_B0_brain_seg_1.nii.gz, 1, 4 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric CC[ /tmp/nipype/55854_mabonlm_nobias_spm_c2.nii, /tmp/nipype/55854_B0_brain_seg_1.nii.gz, 1, 4 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'

# %%
subjects = [string.atoi(e) for e in open('/tmp/amyloid_subjects.txt').read().split('\n') if e != '']
cmds = []
names = []
dd = '/home/grg/data/AmylStaging/'
#for subject in subjects:
#    names.append('%s_fslbet'%subject)
#    cmd = 'fsl5.0-bet %s%s/T1/%s_mabonlm_nobias.nii %s%s/T1/%s_mabonlm_nobias_brain.nii.gz -B -f 0.2 -g 0 -m'%(dd, subject, subject, dd, subject, subject)
#    cmds.append(cmd)

for subject in subjects:
    names.append('%s_ants'%subject)
    #reg = ANTS()
    #reg.inputs.fixed_image = osp.join(dd, str(subject), 'T1', '%s_mabonlm_nobias_brain.nii.gz'%subject)
    #reg.inputs.moving_image = osp.join(dd, str(subject), 'T1', '%s_B0_brain.nii'%subject)
    #reg.inputs.output_transform_prefix = 'ants_elast_dwi-to-t1_.nii.gz'
    #reg.inputs.dimension = 3
    #reg.inputs.metric = ['CC']*2
    #reg.inputs.radius = [4]*2
    #reg.inputs.transformation_model = 'Elast'
    #reg.inputs.gradient_step_length = 1.5
    #reg.inputs.number_of_iterations = [30,20,10]
    #reg.inputs.regularization = 'Gauss'
    #reg.inputs.regularization_deformation_field_sigma = 3
    #reg.inputs.regularization_gradient_field_sigma = 0
    #cmds.append(reg.cmdline)
    cmd = 'ANTS 3 --image-metric MI[ /home/grg/data/AmylStaging/55854/T1/55854_mabonlm_nobias_brain.nii.gz, /home/grg/data/AmylStaging/55854/DWI/55854_B0.nii.gz, 1, 4 ] --number-of-iterations 30x20x10 --output-naming /home/grg/data/AmylStaging/55854/DWI/ants_elast_MI_dwi-to-t1_.nii.gz --regularization Gauss[0.0,3.0] --transformation-model Elast[1.5] --use-Histogram-Matching 0'
    cmd = cmd.replace('55854', str(subject))
    cmds.append(cmd)

step = 'ants_MI'
# Writing commands in a textfile
fp1 = '/tmp/%s.sh'%step
fp2 = '/tmp/%s.workflow'%step
w = open(fp1, 'w')
for e in cmds:
    w.write('%s\n'%e)
w.close()

import sys
sys.path.append('/home/grg/git/alfa')
import create_workflow as cw

cw.create_workflow(fp1, fp2, names=names, verbose=True)
# Out:
# [['ANTS', '3', '--image-metric', 'MI[', '/home/grg/data/AmylStaging/10019/T1/10019_mabonlm_nobias_brain.nii.gz,', '/home/grg/data/AmylStaging/10019/DWI/10019_B0.nii.gz,', '1,', '4', ']', '--number-of-iterations', '30x20x10', '--output-naming', '/home/grg/data/AmylStaging/10019/DWI/ants_elast_MI_dwi-to-t1_.nii.gz', '--regularization', 'Gauss[0.0,3.0]', '--transformation-model', 'Elast[1.5]', '--use-Histogram-Matching', '0'], ['ANTS', '3', '--image-metric', 'MI[', '/home/grg/data/AmylStaging/10044/T1/10044_mabonlm_nobias_brain.nii.gz,', '/home/grg/data/AmylStaging/10044/DWI/10044_B0.nii.gz,', '1,', '4', ']', '--number-of-iterations', '30x20x10', '--output-naming', '/home/grg/data/AmylStaging/10044/DWI/ants_elast_MI_dwi-to-t1_.nii.gz', '--regularization', 'Gauss[0.0,3.0]', '--transformation-model', 'Elast[1.5]', '--use-Histogram-Matching', '0'], ['ANTS', '3', '--image-metric', 'MI[', '/home/grg/data/AmylStaging/10065/T1/10065_mabonlm_nobias_brain.nii.gz,', '/home/grg/data/AmylStaging/10065/DWI/10065_B0.nii.gz,', '1,', '4', ']', '--number-of-iterations', '30x20x10', '--output-naming', '/home/grg/data/AmylStaging/10065/DWI/ants_elast_MI_dwi-to-t1_.nii.gz', '--regularization', 'Gauss[0.0,3.0]', '--transformation-model', 'Elast[1.5]', '--use-Histogram-Matching', '0'], ['ANTS', '3', '--image-metric', 'MI[', '/home/grg/data/AmylStaging/10070/T1/10070_mabonlm_nobias_brain.nii.gz,', '/home/grg/data/AmylStaging/10070/DWI/10070_B0.nii.gz,', '1,', '4', ']', '--number-of-iterations', '30x20x10', '--output-naming', '/home/grg/data/AmylStaging/10070/DWI/ants_elast_MI_dwi-to-t1_.nii.gz', '--regularization', 'Gauss[0.0,3.0]', '--transformation-model', 'Elast[1.5]', '--use-Histogram-Matching', '0'], ['ANTS', '3', '--image-metric', 'MI[', '/home/grg/data/AmylStaging/10137/T1/10137_mabonlm_nobias_brain.nii.gz,', '/home/grg/data/AmylStaging/10137/DWI/10137_B0.nii.gz,', '1,', '4', ']', '--number-of-iterations', '30x20x10', '--output-naming', '/home/grg/data/AmylStaging/10137/DWI/ants_elast_MI_dwi-to-t1_.nii.gz', '--regularization', 'Gauss[0.0,3.0]', '--transformation-model', 'Elast[1.5]', '--use-Histogram-Matching', '0'], ['ANTS', '3', '--image-metric', 'MI[', '/home/grg/data/AmylStaging/10162/T1/10162_mabonlm_nobias_brain.nii.gz,', '/home/grg/data/AmylStaging/10162/DWI/10162_B0.nii.gz,', '1,', '4', ']', '--number-of-iterations', '30x20x10', '--output-naming', '/home/grg/data/AmylStaging/10162/DWI/ants_elast_MI_dwi-to-t1_.nii.gz', '--regularization', 'Gauss[0.0,3.0]', '--transformation-model', 'Elast[1.5]', '--use-Histogram-Matching', '0'], ['ANTS', '3', '--image-metric', 'MI[', '/home/grg/data/AmylStaging/10200/T1/10200_mabonlm_nobias_brain.nii.gz,', '/home/grg/data/AmylStaging/10200/DWI/10200_B0.nii.gz,', '1,', '4', ']', '--number-of-iterations', '30x20x10', '--output-naming', '/home/grg/data/AmylStaging/10200/DWI/ants_elast_MI_dwi-to-t1_.nii.gz', '--regularization', 'Gauss[0.0,3.0]', '--transformation-model', 'Elast[1.5]', '--use-Histogram-Matching', '0'], ['ANTS', '3', '--image-metric', 'MI[', '/home/grg/data/AmylStaging/10225/T1/10225_mabonlm_nobias_brain.nii.gz,', '/home/grg/data/AmylStaging/10225/DWI/10225_B0.nii.gz,', '1,', '4', ']', '--number-of-iterations', '30x20x10', '--output-naming', '/home/grg/data/AmylStaging/10225/DWI/ants_elast_MI_dwi-to-t1_.nii.gz', '--regularization', 'Gauss[0.0,3.0]', '--transformation-model', 'Elast[1.5]', '--use-Histogram-Matching', '0'], ['ANTS', '3', '--image-metric', 'MI[', '/home/grg/data/AmylStaging/10235/T1/10235_mabonlm_nobias_brain.nii.gz,', '/home/grg/data/AmylStaging/10235/DWI/10235_B0.nii.gz,', '1,', '4', ']', '--number-of-iterations', '30x20x10', '--output-naming', '/home/grg/data/AmylStaging/10235/DWI/ants_elast_MI_dwi-to-t1_.nii.gz', '--regularization', 'Gauss[0.0,3.0]', '--transformation-model', 'Elast[1.5]', '--use-Histogram-Matching', '0'], ['ANTS', '3', '--image-metric', 'MI[', '/home/grg/data/AmylStaging/10245/T1/10245_mabonlm_nobias_brain.nii.gz,', '/home/grg/data/AmylStaging/10245/DWI/10245 ...

# %%
import sys, string
sys.path.append('/home/grg/git/thesaurus/')
import thesaurus as th
jf = '/home/grg/git/thesaurus/alfa_dwi_pipeline_aug2016.json'
dd = '/home/grg/data/AmylStaging'
json_io = '/home/grg/git/thesaurus/alfa_dwi_pipeline_io_aug2016.json'
step = 'warp_fa_to_t1'

subjects = [string.atoi(e) for e in open('/tmp/amyloid_subjects.txt').read().split('\n') if e != '']
failed = [12118, 13041, 55854, 10162, 10515, 10627, 10649, 10711, 10949, 11262, 11514, 11745, 12279, 12741, 12991, 13035, 13105, 13107, 13193, 13259, 
             21136, 21138, 44008, 44301, 44396, 66008, 66027, 66100, 66162, 66301, 77012, 77164]
#subjects = [e for e in subjects if not e in failed]
subjects = [10711, 11514,11745,12279,12741,55854]

a = th.ALFAHelper(directory=dd, jsonfile=json_io)

cmds = []
for s in subjects:  
    cmd = a.parse_command(str(s), step, jsonfile=jf)
    cmds.append(cmd)
 
# Writing commands in a textfile
fp1 = '/tmp/%s.sh'%step
fp2 = '/tmp/%s.workflow'%step
w = open(fp1, 'w')
for e in cmds:
    w.write('%s\n'%e)
w.close()

import sys
sys.path.append('/home/grg/git/alfa')
import create_workflow as cw
names = [str(e) for e in subjects]

cw.create_workflow(fp1, fp2, names=names, verbose=True)
# Out:
# [['WarpImageMultiTransform', '3', '/home/grg/data/AmylStaging/10711/DWI/10711_FA.nii.gz', '/home/grg/data/AmylStaging/10711/DWI/10711_FA_t1space.nii.gz', '-R', '/home/grg/data/AmylStaging/10711/T1/10711_mabonlm_nobias.nii', '/home/grg/data/AmylStaging/10711/DWI/ants_elast_dwi-to-t1_Warp.nii.gz', '/home/grg/data/AmylStaging/10711/DWI/ants_elast_dwi-to-t1_Affine.txt'], ['WarpImageMultiTransform', '3', '/home/grg/data/AmylStaging/11514/DWI/11514_FA.nii.gz', '/home/grg/data/AmylStaging/11514/DWI/11514_FA_t1space.nii.gz', '-R', '/home/grg/data/AmylStaging/11514/T1/11514_mabonlm_nobias.nii', '/home/grg/data/AmylStaging/11514/DWI/ants_elast_dwi-to-t1_Warp.nii.gz', '/home/grg/data/AmylStaging/11514/DWI/ants_elast_dwi-to-t1_Affine.txt'], ['WarpImageMultiTransform', '3', '/home/grg/data/AmylStaging/11745/DWI/11745_FA.nii.gz', '/home/grg/data/AmylStaging/11745/DWI/11745_FA_t1space.nii.gz', '-R', '/home/grg/data/AmylStaging/11745/T1/11745_mabonlm_nobias.nii', '/home/grg/data/AmylStaging/11745/DWI/ants_elast_dwi-to-t1_Warp.nii.gz', '/home/grg/data/AmylStaging/11745/DWI/ants_elast_dwi-to-t1_Affine.txt'], ['WarpImageMultiTransform', '3', '/home/grg/data/AmylStaging/12279/DWI/12279_FA.nii.gz', '/home/grg/data/AmylStaging/12279/DWI/12279_FA_t1space.nii.gz', '-R', '/home/grg/data/AmylStaging/12279/T1/12279_mabonlm_nobias.nii', '/home/grg/data/AmylStaging/12279/DWI/ants_elast_dwi-to-t1_Warp.nii.gz', '/home/grg/data/AmylStaging/12279/DWI/ants_elast_dwi-to-t1_Affine.txt'], ['WarpImageMultiTransform', '3', '/home/grg/data/AmylStaging/12741/DWI/12741_FA.nii.gz', '/home/grg/data/AmylStaging/12741/DWI/12741_FA_t1space.nii.gz', '-R', '/home/grg/data/AmylStaging/12741/T1/12741_mabonlm_nobias.nii', '/home/grg/data/AmylStaging/12741/DWI/ants_elast_dwi-to-t1_Warp.nii.gz', '/home/grg/data/AmylStaging/12741/DWI/ants_elast_dwi-to-t1_Affine.txt'], ['WarpImageMultiTransform', '3', '/home/grg/data/AmylStaging/55854/DWI/55854_FA.nii.gz', '/home/grg/data/AmylStaging/55854/DWI/55854_FA_t1space.nii.gz', '-R', '/home/grg/data/AmylStaging/55854/T1/55854_mabonlm_nobias.nii', '/home/grg/data/AmylStaging/55854/DWI/ants_elast_dwi-to-t1_Warp.nii.gz', '/home/grg/data/AmylStaging/55854/DWI/ants_elast_dwi-to-t1_Affine.txt']]

# %%
from glob import glob
files = glob('/home/grg/data/AmylStaging/*/T1/ants_elast_dwi-to-t1*')
for each in files:
    fp = each.replace('/T1/', '/DWI/')
    cmd = 'mv %s %s'%(each, fp)
    print cmd
    #os.system(cmd)
# Out:
# mv /home/grg/data/AmylStaging/66100/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66100/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66100/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66100/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44304/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44304/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44304/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44304/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10225/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10225/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10225/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10225/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10162/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10162/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10162/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10162/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11248/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11248/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11248/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11248/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/13107/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/13107/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/13107/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/13107/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/13244/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/13244/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/13244/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/13244/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66045/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66045/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66045/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66045/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12810/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12810/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12810/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12810/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11291/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11291/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11291/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11291/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10711/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10711/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10711/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10711/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12308/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12308/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12308/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12308/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66067/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66067/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66067/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66067/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/55797/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/55797/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/55797/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/55797/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44231/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44231/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44231/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44231/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66008/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66008/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66008/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66008/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/77101/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/77101/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/77101/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/77101/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66488/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66488/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66488/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66488/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10881/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10881/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10881/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10881/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/55834/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/55834/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/55834/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/55834/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/77164/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/77164/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/77164/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/77164/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66224/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66224/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66224/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66224/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11132/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11132/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11132/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11132/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/55210/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/55210/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/55210/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/55210/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10724/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10724/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10724/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10724/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/13193/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/13193/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/13193/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/13193/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12991/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12991/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12991/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12991/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/55607/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/55607/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/55607/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/55607/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/13059/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/13059/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/13059/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/13059/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12269/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12269/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12269/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12269/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44660/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44660/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44660/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44660/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66162/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66162/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66162/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66162/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66301/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66301/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66301/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66301/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11273/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11273/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11273/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11273/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/77224/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/77224/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/77224/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/77224/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10515/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10515/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10515/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10515/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10627/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10627/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10627/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10627/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10200/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10200/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10200/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10200/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/55038/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/55038/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/55038/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/55038/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10779/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10779/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10779/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10779/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44301/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44301/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44301/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44301/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66237/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66237/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66237/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66237/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44396/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44396/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44396/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44396/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/77012/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/77012/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/77012/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/77012/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10019/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10019/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10019/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10019/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/77341/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/77341/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/77341/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/77341/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/55630/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/55630/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/55630/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/55630/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10329/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10329/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10329/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10329/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11127/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11127/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11127/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11127/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12783/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12783/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12783/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12783/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66489/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66489/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66489/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66489/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11514/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11514/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11514/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11514/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11125/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11125/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11125/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11125/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66296/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66296/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66296/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66296/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11262/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11262/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11262/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11262/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10613/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10613/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10613/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10613/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12627/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12627/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12627/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12627/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11114/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11114/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11114/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11114/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11042/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11042/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11042/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11042/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/55777/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/55777/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/55777/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/55777/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10044/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10044/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10044/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10044/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12184/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12184/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12184/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12184/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44329/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44329/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44329/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44329/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11257/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11257/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11257/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11257/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11540/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11540/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11540/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11540/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12769/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12769/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12769/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12769/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10810/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10810/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10810/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10810/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10696/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10696/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10696/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10696/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44008/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44008/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44008/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44008/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10649/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10649/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10649/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10649/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/55854/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/55854/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/55854/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/55854/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44158/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44158/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44158/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44158/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11478/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11478/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11478/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11478/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/13105/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/13105/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/13105/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/13105/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12118/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12118/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12118/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12118/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66249/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66249/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66249/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66249/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/21156/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/21156/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/21156/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/21156/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12279/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12279/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12279/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12279/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10245/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10245/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10245/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10245/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/13035/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/13035/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/13035/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/13035/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11111/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11111/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11111/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11111/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/21138/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/21138/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/21138/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/21138/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10235/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10235/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10235/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10235/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11742/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11742/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11742/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11742/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10070/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10070/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10070/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10070/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/77104/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/77104/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/77104/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/77104/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/13041/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/13041/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/13041/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/13041/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12741/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12741/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12741/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12741/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44214/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44214/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44214/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44214/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11387/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11387/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11387/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11387/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11397/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11397/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11397/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11397/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11745/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11745/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11745/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11745/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10949/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10949/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10949/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10949/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/66027/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/66027/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/66027/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/66027/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11587/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11587/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11587/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11587/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44349/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44349/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44349/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44349/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10424/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10424/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10424/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10424/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12304/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12304/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12304/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12304/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/44363/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/44363/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/44363/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/44363/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11747/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11747/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11747/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11747/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11055/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11055/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11055/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11055/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/21136/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/21136/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/21136/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/21136/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11656/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11656/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11656/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11656/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/13166/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/13166/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/13166/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/13166/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11593/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11593/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11593/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11593/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10319/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10319/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10319/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10319/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11829/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11829/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11829/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11829/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/13259/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/13259/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/13259/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/13259/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10137/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10137/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10137/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10137/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/12778/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/12778/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/12778/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/12778/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10065/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10065/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10065/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10065/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11866/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11866/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11866/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11866/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/11711/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/11711/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/11711/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/11711/DWI/ants_elast_dwi-to-t1_Affine.txt
# mv /home/grg/data/AmylStaging/10560/T1/ants_elast_dwi-to-t1_Warp.nii.gz /home/grg/data/AmylStaging/10560/DWI/ants_elast_dwi-to-t1_Warp.nii.gz
# mv /home/grg/data/AmylStaging/10560/T1/ants_elast_dwi-to-t1_Affine.txt /home/grg/data/AmylStaging/10560/DWI/ants_elast_dwi-to-t1_Affine.txt

# %%
import os
