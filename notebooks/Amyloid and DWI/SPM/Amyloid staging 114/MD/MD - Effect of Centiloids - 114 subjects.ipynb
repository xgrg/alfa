# %% [markdown]
# # MD maps - Centiloids

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import multireg_spm12 as mreg
reload(mreg)
# %matplotlib inline
# Out:
# /home/grg/jupyter/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 180212-21:14:28,949 interface WARNING:
# 	 Could not get linked libraries for "which".

# %%
excel_fp = '/home/grg/SPM/2018/amylstaging_MD_centiloids.xls'

analysis_name, ext = osp.splitext(osp.split(excel_fp)[1])
paramtype = analysis_name.split('_')[1]
analysis_wd = osp.join(osp.dirname(excel_fp), analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
#aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_wo_csf.nii'
print 'Found SPM files:', spm
pd.read_excel(excel_fp).head()
# Out:
# Found SPM files: ['/home/grg/SPM/2018/amylstaging_MD_centiloids/estimatecontrasts/SPM.mat']
#                                               images        age  gender  apoe  \
# 0  /home/grg/data/AmylStaging/dartel_final/spm/MD...  63.422313       2     0
# 1  /home/grg/data/AmylStaging/dartel_final/spm/MD...  54.757016       1     0
# 2  /home/grg/data/AmylStaging/dartel_final/spm/MD...  50.390144       2     2
# 3  /home/grg/data/AmylStaging/dartel_final/spm/MD...  54.151951       1     0
# 4  /home/grg/data/AmylStaging/dartel_final/spm/MD...  52.878850       1     0
#
#    centiloids
# 0       -7.62
# 1       -1.84
# 2       -0.16
# 3       -4.12
# 4      -17.65

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/SPM/2018/amylstaging_MD_centiloids.xls looking up column MD ...
# Analysis name: amylstaging_MD_centiloids
# First column: images
# Columns in the model: [u'age', u'gender', u'apoe', u'centiloids']
# Effect of Gender
# Effect of Linear age
# Analysis name: amylstaging_MD_centiloids
# Scans (107): [u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10019_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10044_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10065_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10070_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10137_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10162_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10200_MD_s.nii', u'/home
dartel_final/spm/MD/12118_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12184_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12269_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12279_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12304_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12308_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12627_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12741_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12769_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12778_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12991_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/13035_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/13041_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/13059_MD_s.nii', u'/home/grg/data/AmylStagi ...
# Vectors (4)
# Names (4): [u'age', u'gender', u'apoe', u'centiloids']
# Contrasts (2): [('Effect Gender', 'T', ['gender'], [1]), ('Effect Linear age', 'T', ['age'], [1])]
# # of scans included in the analysis: 107
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Effect Gender</td>
#       <td>T</td>
#       <td>[gender]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Effect Linear age</td>
#       <td>T</td>
#       <td>[age]</td>
#       <td>[1.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sections = sections_allcontrasts(analysis_wd, paramtype, axis='z', mode='uncorrected')
# Out:
# /home/grg/SPM/2018/amylstaging_MD_centiloids/estimatecontrasts/spmT_0001.nii T
# Saving to... /tmp/tmpVgaOkQ.png
# /home/grg/SPM/2018/amylstaging_MD_centiloids/estimatecontrasts/spmT_0002.nii T
# Saving to... /tmp/tmpNvizzA.png
# /home/grg/SPM/2018/amylstaging_MD_centiloids/estimatecontrasts/spmT_0003.nii T
# Saving to... /tmp/tmpW_QeKw.png

# %%
spm_mat_file = '/tmp/analysis_amylstaging/ALFA_data_staging/estimatecontrasts/SPM.mat'
out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
pyAAL.to_dataframe(out)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-d38ca7a8a39f> in <module>()
#       1 spm_mat_file = '/tmp/analysis_amylstaging/ALFA_data_staging/estimatecontrasts/SPM.mat'
# ----> 2 out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
#       3 pyAAL.to_dataframe(out)
#
# /home/grg/git/pyAAL/pyAAL.pyc in pyAAL(source, contrast, k, threshold, mode, verbose)
#      87     '''`threshold` is a threshold on the spmT map.'''
#      88
# ---> 89     assert(osp.isfile(source))
#      90     filename, ext = osp.splitext(source)
#      91     workingDir = osp.split(source)[0]
#
# AssertionError:
