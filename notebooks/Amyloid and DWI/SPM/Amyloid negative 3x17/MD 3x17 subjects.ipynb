# %% [markdown]
# # MD maps (amyloid negative) - matched groups 3x17

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import multireg_spm12 as mreg
reload(mreg)
# %matplotlib inline

# %%
excel_fp = '/home/grg/SPM/2018/amylnegmatched_MD.xls'

analysis_name, ext = osp.splitext(osp.split(excel_fp)[1])
paramtype = analysis_name.split('_')[1]
analysis_wd = osp.join(osp.dirname(excel_fp), analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
#aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_wo_csf.nii'
print 'Found SPM files:', spm
pd.read_excel(excel_fp).head()
# Out:
# Found SPM files: ['/home/grg/SPM/2018/amylnegmatched_MD/estimatecontrasts/SPM.mat']
#                                               images        age  gender  NC  \
# 0  /home/grg/data/AmylStaging/dartel_final/spm/MD...  54.757016       1   1
# 1  /home/grg/data/AmylStaging/dartel_final/spm/MD...  50.390144       2   0
# 2  /home/grg/data/AmylStaging/dartel_final/spm/MD...  54.151951       1   1
# 3  /home/grg/data/AmylStaging/dartel_final/spm/MD...  52.878850       1   1
# 4  /home/grg/data/AmylStaging/dartel_final/spm/MD...  64.405202       1   0
#
#    HT  HO
# 0   0   0
# 1   0   1
# 2   0   0
# 3   0   0
# 4   1   0

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/SPM/2018/amylnegmatched_MD.xls looking up column MD ...
# Analysis name: amylnegmatched_MD
# First column: images
# Columns in the model: [u'age', u'gender', u'NC', u'HT', u'HO']
# Non-carriers / Heterozygotes / Homozygotes detected
# Effect of Gender
# Effect of Linear age
# Analysis name: amylnegmatched_MD
# Scans (47): [u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10044_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10065_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10070_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10137_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10225_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10245_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10424_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10515_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10613_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10627_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10696_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10711_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/10724_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11042_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11125_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11248_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11291_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11397_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11593_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11656_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11711_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11745_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11829_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/11866_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12118_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12269_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12279_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12304_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12308_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12778_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/12991_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/13105_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/13244_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/21156_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/44214_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/44231_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/44301_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/44660_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/55210_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/55607_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/55630_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/55777_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/66237_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/66249_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/66488_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/66489_MD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD/77104_MD_s.nii']
# Vectors (5)
# Names (5): [u'age', u'gender', u'NC', u'HT', u'HO']
# Contrasts (5): [('HO>HT', 'T', ['HO', 'HT'], [1, -1]), ('HO>NC', 'T', ['HO', 'NC'], [1, -1]), ('HT>NC', 'T', ['HT', 'NC'], [1, -1]), ('Effect Gender', 'T', ['gender'], [1]), ('Effect Linear age', 'T', ['age'], [1])]
# # of scans included in the analysis: 47
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>HO&gt;HT</td>
#       <td>T</td>
#       <td>[HO, HT]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>HO&gt;NC</td>
#       <td>T</td>
#       <td>[HO, NC]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>HT&gt;NC</td>
#       <td>T</td>
#       <td>[HT, NC]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Effect Gender</td>
#       <td>T</td>
#       <td>[gender]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Effect Linear age</td>
#       <td>T</td>
#       <td>[age]</td>
#       <td>[1.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sections = sections_allcontrasts(analysis_wd, paramtype, axis='z', mode='uncorrected')
# Out:
# /home/grg/SPM/2018/amylnegmatched_MD/estimatecontrasts/spmT_0001.nii T
# Saving to... /tmp/tmpDerWlA.png
# /home/grg/SPM/2018/amylnegmatched_MD/estimatecontrasts/spmT_0002.nii T
# Saving to... /tmp/tmpZA4D43.png
# /home/grg/SPM/2018/amylnegmatched_MD/estimatecontrasts/spmT_0003.nii T
# Saving to... /tmp/tmpNo2zB5.png
# /home/grg/SPM/2018/amylnegmatched_MD/estimatecontrasts/spmT_0004.nii T
# Saving to... /tmp/tmpv35qfI.png
# /home/grg/SPM/2018/amylnegmatched_MD/estimatecontrasts/spmT_0005.nii T
# Saving to... /tmp/tmp0IOitW.png

# %%
spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
pyAAL.to_dataframe(out)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-df042931a3f8> in <module>()
#       1 spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
# ----> 2 out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
#       3 pyAAL.to_dataframe(out)
#
# /home/grg/git/pyAAL/pyAAL.pyc in pyAAL(source, contrast, k, threshold, mode, verbose)
#      87     '''`threshold` is a threshold on the spmT map.'''
#      88
# ---> 89     assert(osp.isfile(source))
#      90     filename, ext = osp.splitext(source)
#      91     workingDir = osp.split(source)[0]
#
# AssertionError:
