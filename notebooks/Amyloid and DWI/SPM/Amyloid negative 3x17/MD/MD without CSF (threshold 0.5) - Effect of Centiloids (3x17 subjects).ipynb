# %% [markdown]
# # MD maps (amyloid negative) without CSF (threshold .5) - matched groups 3x17 - Centiloids

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import multireg_spm12 as mreg
reload(mreg)
# %matplotlib inline

# %%
excel_fp = '/home/grg/SPM/2018/amylmatched_MD_wo_csf5_centiloids.xls'

analysis_name, ext = osp.splitext(osp.split(excel_fp)[1])
paramtype = analysis_name.split('_')[1]
analysis_wd = osp.join(osp.dirname(excel_fp), analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
#aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_wo_csf.nii'
print 'Found SPM files:', spm
pd.read_excel(excel_fp).head()
# Out:
# Found SPM files: ['/home/grg/SPM/2018/amylmatched_MD_wo_csf5_centiloids/estimatecontrasts/SPM.mat']
#                                               images        age  gender  apoe  \
# 0  /home/grg/data/AmylStaging/dartel_final/spm/MD...  54.757016       1     0
# 1  /home/grg/data/AmylStaging/dartel_final/spm/MD...  50.390144       2     2
# 2  /home/grg/data/AmylStaging/dartel_final/spm/MD...  54.151951       1     0
# 3  /home/grg/data/AmylStaging/dartel_final/spm/MD...  52.878850       1     0
# 4  /home/grg/data/AmylStaging/dartel_final/spm/MD...  64.405202       1     1
#
#    centiloids
# 0       -1.84
# 1       -0.16
# 2       -4.12
# 3      -17.65
# 4      -18.08

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/SPM/2018/amylmatched_MD_wo_csf5_centiloids.xls looking up column MD ...
# Analysis name: amylmatched_MD_wo_csf5_centiloids
# First column: images
# Columns in the model: [u'age', u'gender', u'apoe', u'centiloids']
# Effect of Centiloids
# Effect of Gender
# Effect of Linear age
# Analysis name: amylmatched_MD_wo_csf5_centiloids
# Scans (47): [u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/10044_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/10065_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/10070_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/10137_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/10225_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/10245_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/10424_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/10515_MD_wo_csf_s.nii', u'/home/grg
f_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/55210_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/55607_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/55630_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/55777_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/66237_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/66249_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/66488_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/66489_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf.5/77104_MD_wo_csf_s.nii']
# Vectors (4)
# Names (4): [u'age', u'gender', u'apoe', u'centiloids']
# Contrasts (3): [('Effect Centiloids', 'T', ['centiloids'], [1]), ('Effect Gender', 'T', ['gender'], [1]), ('Effect Linear age', 'T', ['age'], [1])]
# # of scans included in the analysis: 47
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Effect Centiloids</td>
#       <td>T</td>
#       <td>[centiloids]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Effect Gender</td>
#       <td>T</td>
#       <td>[gender]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Effect Linear age</td>
#       <td>T</td>
#       <td>[age]</td>
#       <td>[1.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sections = sections_allcontrasts(analysis_wd, paramtype, axis='z', mode='uncorrected')
# Out:
# /home/grg/SPM/2018/amylmatched_MD_wo_csf5_centiloids/estimatecontrasts/spmT_0001.nii T
# Saving to... /tmp/tmpCsKjyk.png
# /home/grg/SPM/2018/amylmatched_MD_wo_csf5_centiloids/estimatecontrasts/spmT_0002.nii T
# Saving to... /tmp/tmpVzqjfk.png
# /home/grg/SPM/2018/amylmatched_MD_wo_csf5_centiloids/estimatecontrasts/spmT_0003.nii T
# Saving to... /tmp/tmp43q5fJ.png

# %%
spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
pyAAL.to_dataframe(out)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-df042931a3f8> in <module>()
#       1 spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
# ----> 2 out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
#       3 pyAAL.to_dataframe(out)
#
# /home/grg/git/pyAAL/pyAAL.pyc in pyAAL(source, contrast, k, threshold, mode, verbose)
#      87     '''`threshold` is a threshold on the spmT map.'''
#      88
# ---> 89     assert(osp.isfile(source))
#      90     filename, ext = osp.splitext(source)
#      91     workingDir = osp.split(source)[0]
#
# AssertionError:
