# %% [markdown]
# # MD without csf maps (amyloid negative) - matched groups 3x17

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import multireg_spm12 as mreg
reload(mreg)
# %matplotlib inline
# Out:
# /home/grg/jupyter/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 180212-19:28:36,902 interface WARNING:
# 	 Could not get linked libraries for "which".

# %%
excel_fp = '/home/grg/SPM/2018/amylnegmatched_MDwocsf.xls'

analysis_name, ext = osp.splitext(osp.split(excel_fp)[1])
paramtype = analysis_name.split('_')[1]
analysis_wd = osp.join(osp.dirname(excel_fp), analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
#aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_wo_csf.nii'
print 'Found SPM files:', spm
pd.read_excel(excel_fp).head()
# Out:
# Found SPM files: ['/home/grg/SPM/2018/amylnegmatched_MDwocsf/estimatecontrasts/SPM.mat']

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/SPM/2018/amylnegmatched_MDwocsf.xls looking up column MDwocsf ...
# Analysis name: amylnegmatched_MDwocsf
# First column: images
# Columns in the model: [u'age', u'gender', u'NC', u'HT', u'HO']
# Non-carriers / Heterozygotes / Homozygotes detected
# Effect of Gender
# Effect of Linear age
# Analysis name: amylnegmatched_MDwocsf
# Scans (47): [u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10044_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10065_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10070_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10137_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10225_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10245_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10424_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10515_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10613_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10627_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/10696_MD_wo_csf_s.nii', u'/home/grg/data
_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/66249_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/66488_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/66489_MD_wo_csf_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/MD_wo_csf/77104_MD_wo_csf_s.nii']
# Vectors (5)
# Names (5): [u'age', u'gender', u'NC', u'HT', u'HO']
# Contrasts (5): [('HO>HT', 'T', ['HO', 'HT'], [1, -1]), ('HO>NC', 'T', ['HO', 'NC'], [1, -1]), ('HT>NC', 'T', ['HT', 'NC'], [1, -1]), ('Effect Gender', 'T', ['gender'], [1]), ('Effect Linear age', 'T', ['age'], [1])]
# # of scans included in the analysis: 47
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>HO&gt;HT</td>
#       <td>T</td>
#       <td>[HO, HT]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>HO&gt;NC</td>
#       <td>T</td>
#       <td>[HO, NC]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>HT&gt;NC</td>
#       <td>T</td>
#       <td>[HT, NC]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Effect Gender</td>
#       <td>T</td>
#       <td>[gender]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Effect Linear age</td>
#       <td>T</td>
#       <td>[age]</td>
#       <td>[1.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sections = sections_allcontrasts(analysis_wd, paramtype, axis='z', mode='uncorrected')
# Out:
# /home/grg/SPM/2018/amylnegmatched_MDwocsf/estimatecontrasts/spmT_0001.nii T
# Saving to... /tmp/tmpV9Jkjx.png
# /home/grg/SPM/2018/amylnegmatched_MDwocsf/estimatecontrasts/spmT_0002.nii T
# Saving to... /tmp/tmpJmHQpT.png
# /home/grg/SPM/2018/amylnegmatched_MDwocsf/estimatecontrasts/spmT_0003.nii T
# Saving to... /tmp/tmpKVfZTr.png
# /home/grg/SPM/2018/amylnegmatched_MDwocsf/estimatecontrasts/spmT_0004.nii T
# Saving to... /tmp/tmp9QE8MI.png
# /home/grg/SPM/2018/amylnegmatched_MDwocsf/estimatecontrasts/spmT_0005.nii T
# Saving to... /tmp/tmpN6vJPX.png

# %%
spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
pyAAL.to_dataframe(out)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-df042931a3f8> in <module>()
#       1 spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
# ----> 2 out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
#       3 pyAAL.to_dataframe(out)
#
# /home/grg/git/pyAAL/pyAAL.pyc in pyAAL(source, contrast, k, threshold, mode, verbose)
#      87     '''`threshold` is a threshold on the spmT map.'''
#      88
# ---> 89     assert(osp.isfile(source))
#      90     filename, ext = osp.splitext(source)
#      91     workingDir = osp.split(source)[0]
#
# AssertionError:
