# %% [markdown]
# # RD maps (amyloid negative) - matched groups 3x17

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import amyl_multireg_spm12 as mreg
reload(mreg)
# %matplotlib inline

# %%
excel_fp = '/home/grg/SPM/2018/amylnegmatched_RD.xls'

analysis_name, ext = osp.splitext(osp.split(excel_fp)[1])
paramtype = analysis_name.split('_')[1]
analysis_wd = osp.join(osp.dirname(excel_fp), analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
#aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_wo_csf.nii'
print 'Found SPM files:', spm
# Out:
# Found SPM files: ['/home/grg/SPM/2018/amylnegmatched_RD/estimatecontrasts/SPM.mat']

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/SPM/2018/amylnegmatched_RD.xls looking up column RD ...
# Analysis name: amylnegmatched_RD
# First column: images
# Columns in the model: [u'age', u'gender', u'NC', u'HT', u'HO']
# Effect of Gender
# Effect of Linear age
# Analysis name: amylnegmatched_RD
# Scans (47): [u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10044_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10065_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10070_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10137_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10225_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10245_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10424_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10515_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10613_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10627_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10696_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10711_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/10724_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11042_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11125_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11248_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11291_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11397_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11593_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11656_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11711_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11745_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11829_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/11866_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/12118_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/12269_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/12279_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/12304_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/12308_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/12778_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/12991_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/13105_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/13244_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/21156_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/44214_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/44231_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/44301_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/44660_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/55210_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/55607_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/55630_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/55777_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/66237_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/66249_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/66488_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/66489_RD_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/RD/77104_RD_s.nii']
# Vectors (5)
# Names (5): [u'age', u'gender', u'NC', u'HT', u'HO']
# Contrasts (2): [('Effect Gender', 'T', ['gender'], [1]), ('Effect Linear age', 'T', ['age'], [1])]
# # of scans included in the analysis: 47
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Effect Gender</td>
#       <td>T</td>
#       <td>[gender]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Effect Linear age</td>
#       <td>T</td>
#       <td>[age]</td>
#       <td>[1.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sections = sections_allcontrasts(analysis_wd, paramtype, axis='z', mode='uncorrected')
# Out:
# /home/grg/SPM/2018/amylnegmatched_RD/estimatecontrasts/spmT_0001.nii T
# Saving to... /tmp/tmpbyLhVq.png
# /home/grg/SPM/2018/amylnegmatched_RD/estimatecontrasts/spmT_0002.nii T
# Saving to... /tmp/tmpeVuFT2.png
# /home/grg/SPM/2018/amylnegmatched_RD/estimatecontrasts/spmT_0003.nii T
# Saving to... /tmp/tmp5s2S2X.png
# /home/grg/SPM/2018/amylnegmatched_RD/estimatecontrasts/spmT_0004.nii T
# Saving to... /tmp/tmpXibTi6.png
# /home/grg/SPM/2018/amylnegmatched_RD/estimatecontrasts/spmT_0005.nii T
# Saving to... /tmp/tmplxulAp.png

# %%
spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
pyAAL.to_dataframe(out)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-df042931a3f8> in <module>()
#       1 spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
# ----> 2 out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
#       3 pyAAL.to_dataframe(out)
#
# /home/grg/git/pyAAL/pyAAL.pyc in pyAAL(source, contrast, k, threshold, mode, verbose)
#      87     '''`threshold` is a threshold on the spmT map.'''
#      88
# ---> 89     assert(osp.isfile(source))
#      90     filename, ext = osp.splitext(source)
#      91     workingDir = osp.split(source)[0]
#
# AssertionError:
