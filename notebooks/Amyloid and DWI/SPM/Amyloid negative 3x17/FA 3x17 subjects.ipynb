# %% [markdown]
# # FA maps (amyloid negative) - matched groups 3x17

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import amyl_multireg_spm12 as mreg
reload(mreg)
# %matplotlib inline
# Out:
# /home/grg/jupyter/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 180130-20:25:02,523 interface WARNING:
# 	 Could not get linked libraries for "which".

# %%
excel_fp = '/home/grg/SPM/2018/amylnegmatched_FA.xls'

analysis_name, ext = osp.splitext(osp.split(excel_fp)[1])
paramtype = analysis_name.split('_')[1]
analysis_wd = osp.join(osp.dirname(excel_fp), analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
#aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_wo_csf.nii'
print 'Found SPM files:', spm
# Out:
# Found SPM files: ['/home/grg/SPM/2018/amylnegmatched_FA/estimatecontrasts/SPM.mat']

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/SPM/2018/amylnegmatched_FA.xls looking up column FA ...
# Analysis name: amylnegmatched_FA
# First column: images
# Columns in the model: [u'age', u'gender', u'NC', u'HT', u'HO']
# Effect of Gender
# Effect of Linear age
# Analysis name: amylnegmatched_FA
# Scans (47): [u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10044_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10065_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10070_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10137_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10225_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10245_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10424_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10515_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10613_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10627_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10696_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10711_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10724_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11042_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11125_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11248_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11291_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11397_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11593_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11656_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11711_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11745_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11829_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11866_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/12118_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/12269_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/12279_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/12304_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/12308_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/12778_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/12991_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/13105_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/13244_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/21156_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44214_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44231_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44301_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44660_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/55210_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/55607_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/55630_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/55777_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/66237_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/66249_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/66488_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/66489_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/77104_FA_s.nii']
# Vectors (5)
# Names (5): [u'age', u'gender', u'NC', u'HT', u'HO']
# Contrasts (2): [('Effect Gender', 'T', ['gender'], [1]), ('Effect Linear age', 'T', ['age'], [1])]
# # of scans included in the analysis: 47
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Effect Gender</td>
#       <td>T</td>
#       <td>[gender]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Effect Linear age</td>
#       <td>T</td>
#       <td>[age]</td>
#       <td>[1.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sections = sections_allcontrasts(analysis_wd, paramtype, axis='z', mode='uncorrected')
# Out:
# /home/grg/SPM/2018/amylnegmatched_FA/estimatecontrasts/spmT_0001.nii T
# Saving to... /tmp/tmpiXbSTP.png
# /home/grg/SPM/2018/amylnegmatched_FA/estimatecontrasts/spmT_0002.nii T
# Saving to... /tmp/tmp6AZAiX.png
# /home/grg/SPM/2018/amylnegmatched_FA/estimatecontrasts/spmT_0003.nii T
# Saving to... /tmp/tmp6RKEsN.png
# /home/grg/SPM/2018/amylnegmatched_FA/estimatecontrasts/spmT_0004.nii T
# Saving to... /tmp/tmp6bh2Hh.png
# /home/grg/SPM/2018/amylnegmatched_FA/estimatecontrasts/spmT_0005.nii T
# Saving to... /tmp/tmpg9oyH5.png

# %%
spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
pyAAL.to_dataframe(out)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-df042931a3f8> in <module>()
#       1 spm_mat_file = '/tmp/analysis_amylstaging/amyloid_apoe_3x17/estimatecontrasts/SPM.mat'
# ----> 2 out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
#       3 pyAAL.to_dataframe(out)
#
# /home/grg/git/pyAAL/pyAAL.pyc in pyAAL(source, contrast, k, threshold, mode, verbose)
#      87     '''`threshold` is a threshold on the spmT map.'''
#      88
# ---> 89     assert(osp.isfile(source))
#      90     filename, ext = osp.splitext(source)
#      91     workingDir = osp.split(source)[0]
#
# AssertionError:
