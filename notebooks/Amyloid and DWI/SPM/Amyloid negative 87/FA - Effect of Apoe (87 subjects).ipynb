# %% [markdown]
# # FA maps with amyloid negative

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import amyl_multireg_spm12 as mreg
reload(mreg)
# %matplotlib inline

# %%
excel_fp = '/home/grg/SPM/2018/amylnegative_FA.xls'

analysis_name, ext = osp.splitext(osp.split(excel_fp)[1])
paramtype = analysis_name.split('_')[1]
analysis_wd = osp.join(osp.dirname(excel_fp), analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
#aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_wo_csf.nii'
print 'Found SPM files:', spm
# Out:
# Found SPM files: ['/home/grg/SPM/2018/amylnegative_FA/estimatecontrasts/SPM.mat']

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/SPM/2018/amylnegative_FA.xls looking up column FA ...
# Analysis name: amylnegative_FA
# First column: images
# Columns in the model: [u'age', u'gender', u'NC', u'HT', u'HO']
# Effect of Gender
# Effect of Linear age
# Analysis name: amylnegative_FA
# Scans (82): [u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10019_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10044_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10065_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10070_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10137_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10200_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10225_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10235_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10245_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10424_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10515_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10649_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10711_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10724_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/10810_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/11042_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final
m/FA/44008_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44158_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44214_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44231_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44301_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44329_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44349_FA_s.nii', u'/home/grg/data/AmylStaging/dartel_final/spm/FA/44363_FA_s.nii', u'/home/grg/data/AmylStagin ...
# Vectors (5)
# Names (5): [u'age', u'gender', u'NC', u'HT', u'HO']
# Contrasts (2): [('Effect Gender', 'T', ['gender'], [1]), ('Effect Linear age', 'T', ['age'], [1])]
# # of scans included in the analysis: 82
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Effect Gender</td>
#       <td>T</td>
#       <td>[gender]</td>
#       <td>[1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Effect Linear age</td>
#       <td>T</td>
#       <td>[age]</td>
#       <td>[1.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sections = sections_allcontrasts(analysis_wd, paramtype, axis='z', mode='uncorrected')
# Out:
# /home/grg/SPM/2018/amylnegative_FA/estimatecontrasts/spmT_0001.nii T
# Saving to... /tmp/tmpsOiaVb.png
# /home/grg/SPM/2018/amylnegative_FA/estimatecontrasts/spmT_0002.nii T
# Saving to... /tmp/tmp3pgyBb.png
# /home/grg/SPM/2018/amylnegative_FA/estimatecontrasts/spmT_0003.nii T
# Saving to... /tmp/tmpwTjErm.png
# /home/grg/SPM/2018/amylnegative_FA/estimatecontrasts/spmT_0004.nii T
# Saving to... /tmp/tmp2TGhT0.png
# /home/grg/SPM/2018/amylnegative_FA/estimatecontrasts/spmT_0005.nii T
# Saving to... /tmp/tmp9p45nV.png

# %%
spm_mat_file = '/tmp/analysis_amylstaging/ALFA_data_staging/estimatecontrasts/SPM.mat'
out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
pyAAL.to_dataframe(out)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-d38ca7a8a39f> in <module>()
#       1 spm_mat_file = '/tmp/analysis_amylstaging/ALFA_data_staging/estimatecontrasts/SPM.mat'
# ----> 2 out = pyAAL.pyAAL(spm_mat_file, 2, k=10, mode=2)
#       3 pyAAL.to_dataframe(out)
#
# /home/grg/git/pyAAL/pyAAL.pyc in pyAAL(source, contrast, k, threshold, mode, verbose)
#      87     '''`threshold` is a threshold on the spmT map.'''
#      88
# ---> 89     assert(osp.isfile(source))
#      90     filename, ext = osp.splitext(source)
#      91     workingDir = osp.split(source)[0]
#
# AssertionError:
