# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/TBSS/AMYLOID/tbss_amylneg_3x17/stats/'
tcon = [e.rstrip('\n').split('"')[-2] for e in open(osp.join(wd, 'model2.con')).readlines() if 'ContrastName' in e]
for i in range(1, 11):
    plot_tbss(osp.join(wd, 'tbss_MD_model2_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -15, 43, row_l=6, step=2, title=tcon[i-1])
# Out:
# /home/grg/TBSS/AMYLOID/tbss_amylneg_3x17/stats/tbss_MD_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylneg_3x17/stats/tbss_MD_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylneg_3x17/stats/tbss_MD_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylneg_3x17/stats/tbss_MD_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylneg_3x17/stats/tbss_MD_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpN2bMtx.png (Centiloids (+))
# Saving to... /tmp/tmpDpW4_O.png (Centiloids (-))
# Saving to... /tmp/tmputMG1_.png (Age(+))
# /home/grg/TBSS/AMYLOID/tbss_amylneg_3x17/stats/tbss_MD_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /home/grg/TBSS/AMYLOID/tbss_amylneg_3x17/stats/tbss_MD_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# ...

# %%
more /home/grg/bsc_output/data/stats/model4.con
