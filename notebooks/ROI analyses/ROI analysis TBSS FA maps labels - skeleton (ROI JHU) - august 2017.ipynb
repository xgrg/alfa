# %% [markdown]
# This plots ROI values extracted from images that have been normalized using DARTEL,
# but the values have been extracted from ROI derived from a prior analysis done using images normalized using DARTEL.

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py

# %% [markdown]
# This collect the values from \*\_stats.csv files, i.e. values that have been extracted from ROI manually drawn in MNI space.
# The bad thing with this is that the ROI is defined in a reference space. This is subject to individual registration errors.

# %%
regions = range(2, 49)
for x in [9,10,11,12,13]:
    regions.remove(x)
names = {1: 'Middle cerebellar peduncle',
 2: 'Pontine crossing tract (a part of MCP)',
 3: 'Genu of corpus callosum',
 4: 'Body of corpus callosum',
 5: 'Splenium of corpus callosum',
 6: 'Fornix (column and body of fornix)',
 7: 'Corticospinal tract R',
 8: 'Corticospinal tract L',
 9: 'Medial lemniscus R',
 10: 'Medial lemniscus L',
 11: 'Inferior cerebellar peduncle R  ',
 12: 'Inferior cerebellar peduncle L',
 13: 'Superior cerebellar peduncle R',
 14: 'Superior cerebellar peduncle L',
 15: 'Cerebral peduncle R',
 16: 'Cerebral peduncle L',
 17: 'Anterior limb of internal capsule R',
 18: 'Anterior limb of internal capsule L',
 19: 'Posterior limb of internal capsule R',
 20: 'Posterior limb of internal capsule L',
 21: 'Retrolenticular part of internal capsule R',
 22: 'Retrolenticular part of internal capsule L',
 23: 'Anterior corona radiata R',
 24: 'Anterior corona radiata L',
 25: 'Superior corona radiata R',
 26: 'Superior corona radiata L',
 27: 'Posterior corona radiata R',
 28: 'Posterior corona radiata L',
 29: 'Posterior thalamic radiation (include optic radiation) R',
 30: 'Posterior thalamic radiation (include optic radiation) L',
 31: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R',
 32: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L',
 33: 'External capsule R',
 34: 'External capsule L',
 35: 'Cingulum (cingulate gyrus) R',
 36: 'Cingulum (cingulate gyrus) L',
 37: 'Cingulum (hippocampus) R',
 38: 'Cingulum (hippocampus) L',
 39: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R',
 40: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L',
 41: 'Superior longitudinal fasciculus R',
 42: 'Superior longitudinal fasciculus L',
 43: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R',
 44: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L',
 45: 'Uncinate fasciculus R',
 46: 'Uncinate fasciculus L',
 47: 'Tapetum R',
 48: 'Tapetum L'}

data = pd.read_excel('/tmp/covariates.xlsx')
data = data.set_index(data['subject'])
data = data.sort_values(['apo', 'subject'])
src = '/home/grg/tbss_bsc_subjects/roivalues_labels_tbss_FA_skel/'
filepattern = '*_stats.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

#df = pd.read_excel('/home/grg/spm/data/covariates.xls')
#subjects = list(df[df['apo']!=1]['subject'].values)
#csvfiles = []
#for s in subjects:
#    csvfp = glob(osp.join(src, '%s%s'%(s, filepattern)))[0]
#    csvfiles.append(csvfp)

#values = collect_roivalues(3, csvfiles=csvfiles, subjects=subjects)

#data.join(values)
#poly = ols(formula='roi ~ 1 + age', data=data.join(values)).fit()
res = plot_regions(data, regions, csvfiles, subjects, groups=['apoe44', 'apoe34', 'apoe33'], by='apo', names=names,ylim=[0.4,0.7])
# Out:
# {1: 'Middle cerebellar peduncle', 2: 'Pontine crossing tract (a part of MCP)', 3: 'Genu of corpus callosum', 4: 'Body of corpus callosum', 5: 'Splenium of corpus callosum', 6: 'Fornix (column and body of fornix)', 7: 'Corticospinal tract R', 8: 'Corticospinal tract L', 9: 'Medial lemniscus R', 10: 'Medial lemniscus L', 11: 'Inferior cerebellar peduncle R  ', 12: 'Inferior cerebellar peduncle L', 13: 'Superior cerebellar peduncle R', 14: 'Superior cerebellar peduncle L', 15: 'Cerebral peduncle R', 16: 'Cerebral peduncle L', 17: 'Anterior limb of internal capsule R', 18: 'Anterior limb of internal capsule L', 19: 'Posterior limb of internal capsule R', 20: 'Posterior limb of internal capsule L', 21: 'Retrolenticular part of internal capsule R', 22: 'Retrolenticular part of internal capsule L', 23: 'Anterior corona radiata R', 24: 'Anterior corona radiata L', 25: 'Superior corona radiata R', 26: 'Superior corona radiata L', 27: 'Posterior corona radiata R', 28: 'Posterior corona radiata L', 29: 'Posterior thalamic radiation (include optic radiation) R', 30: 'Posterior thalamic radiation (include optic radiation) L', 31: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R', 32: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L', 33: 'External capsule R', 34: 'External capsule L', 35: 'Cingulum (cingulate gyrus) R', 36: 'Cingulum (cingulate gyrus) L', 37: 'Cingulum (hippocampus) R', 38: 'Cingulum (hippocampus) L', 39: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R', 40: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L', 41: 'Superior longitudinal fasciculus R', 42: 'Superior longitudinal fasciculus L', 43: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R', 44: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L', 45: 'Uncinate fasciculus R', 46: 'Uncinate fasciculus L', 47: 'Tapetum R', 48: 'Tapetum L'}
# groups ['apoe44', 'apoe34', 'apoe33']
# Standard deviation of label Pontine crossing tract (a part of MCP): 0.0329001403937
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.032747240102
# Region: Pontine crossing tract (a part of MCP)
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0325156633773
# 0.670379930058
# 0.23598865154
# 0.294307664897
# Standard deviation of label Genu of corpus callosum: 0.0357036175324
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0355409800035
# Region: Genu of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0341613168231
# 0.474099863182
# 0.0645938735031
# 0.177745640229
# Standard deviation of label Body of corpus callosum: 0.0370974770309
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.037063469608
# Region: Body of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0353740393947
# 0.890748878153
# 0.223081046492
# 0.166454023125
# Standard deviation of label Splenium of corpus callosum: 0.0295122533814
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0284742904691
# Region: Splenium of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0279393783319
# 0.262439839775
# 0.256657709479
# 0.889429320942
# Standard deviation of label Fornix (column and body of fornix): 0.0951437209286
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0947042287459
# Region: Fornix (column and body of fornix)
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0858959652668
# 0.0971933529564
# 0.781828171781
# 0.0149785763808
# Standard deviation of label Corticospinal tract R: 0.0260680533605
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0257189176422
# Region: Corticospinal tract R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0256393003925
# 0.714516839141
# 0.445421546818
# 0.142755633496
# Standard deviation of label Corticospinal tract L: 0.0294794958981
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0292602591137
# Region: Corticospinal tract L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0291802063869
# 0.864008221426
# 0.782006931116
# 0.879357452791
# Standard deviation of label Superior cerebellar peduncle L: 0.0336542658875
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0329813424179
# Region: Superior cerebellar peduncle L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0326446439231
# 0.162755375887
# 0.200233955114
# 0.921013593117
# Standard deviation of label Cerebral peduncle R: 0.0216709496641
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.021624344483
# Region: Cerebral peduncle R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0213616898172
# 0.321051916758
# 0.971759868109
# 0.214297106872
# Standard deviation of label Cerebral peduncle L: 0.0311220776758
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.030658612441
# Region: Cerebral peduncle L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0300734185866
# 0.0691917305683
# 0.0952638282648
# 0.900950490341
# Standard deviation of label Anterior limb of internal capsule R: 0.0303648819017
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0303631840879
# Region: Anterior limb of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0300637544958
# 0.868579170424
# 0.237228652073
# 0.211444681377
# Standard deviation of label Anterior limb of internal capsule L: 0.0335888841511
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.033356418954
# Region: Anterior limb of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0331488717919
# 0.191719566521
# 0.0359881767023
# 0.343227690752
# Standard deviation of label Posterior limb of internal capsule R: 0.0315833443709
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0315366218653
# Region: Posterior limb of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0314785323353
# 0.139562725393
# 0.382084678282
# 0.371833713757
# Standard deviation of label Posterior limb of internal capsule L: 0.0362208150296
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0360576490549
# Region: Posterior limb of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0357216326666
# 0.348102320795
# 0.410313861911
# 0.827548461794
# Standard deviation of label Retrolenticular part of internal capsule R: 0.0359587167955
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0356097679106
# Region: Retrolenticular part of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0355092646066
# 0.0167305357316
# 0.247431792819
# 0.0973162631125
# Standard deviation of label Retrolenticular part of internal capsule L: 0.0307889624134
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.030492443844
# Region: Retrolenticular part of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0304889398988
# 0.112371957021
# 0.329855477629
# 0.434585863666
# Standard deviation of label Anterior corona radiata R: 0.0350358553479
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0350338124489
# Region: Anterior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0336988206346
# 0.526851845447
# 0.0846686266021
# 0.254529165097
# Standard deviation of label Anterior corona radiata L: 0.0328980888436
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0328422850021
# Region: Anterior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0309813916099
# 0.803521274752
# 0.149167912085
# 0.16736134742
# Standard deviation of label Superior corona radiata R: 0.0289682975766
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0289576664398
# Region: Superior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0287861305229
# 0.485219316461
# 0.581276630259
# 0.768033642426
# Standard deviation of label Superior corona radiata L: 0.0289240881956
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0288819070011
# Region: Superior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0285672560985
# 0.512778003164
# 0.209380897665
# 0.496179627347
# Standard deviation of label Posterior corona radiata R: 0.0349756213138
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0342873758651
# Region: Posterior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.034217478428
# 0.041889865041
# 0.205657366433
# 0.170295093372
# Standard deviation of label Posterior corona radiata L: 0.0304270252139
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0303898215298
# Region: Posterior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0301400487713
# 0.158106261888
# 0.508057102712
# 0.270909240483
# Standard deviation of label Posterior thalamic radiation (include optic radiation) R: 0.0386027769508
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0383100149555
# Region: Posterior thalamic radiation (include optic radiation) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0378169225308
# 0.12652768385
# 0.100465333671
# 0.997639771296
# Standard deviation of label Posterior thalamic radiation (include optic radiation) L: 0.0402620403887
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0402599996492
# Region: Posterior thalamic radiation (include optic radiation) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0386929266615
# 0.0149539433818
# 0.0060558459765
# 0.558442375857
# Standard deviation of label Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R: 0.0366302736176
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0366241823456
# Region: Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0363914498159
# 0.150370013622
# 0.0996781187081
# 0.882160484678
# Standard deviation of label Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L: 0.0350709559201
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0350102075261
# Region: Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0349235145596
# 0.132230935409
# 0.0680277559487
# 0.851001914344
# Standard deviation of label External capsule R: 0.0266383166977
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0266046664622
# Region: External capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0260296002337
# 0.307087810505
# 0.354047089867
# 0.751097148086
# Standard deviation of label External capsule L: 0.0265893163664
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.026288470456
# Region: External capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0258263873512
# 0.806446060689
# 0.991266973832
# 0.754862001496
# Standard deviation of label Cingulum (cingulate gyrus) R: 0.0438904029604
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0421844575433
# Region: Cingulum (cingulate gyrus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0414767293116
# 0.474107264198
# 0.0472205214121
# 0.119042023146
# Standard deviation of label Cingulum (cingulate gyrus) L: 0.0446727533163
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0432151369069
# Region: Cingulum (cingulate gyrus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0424197181508
# 0.866113068674
# 0.0648313664427
# 0.0393104711294
# Standard deviation of label Cingulum (hippocampus) R: 0.066934739713
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0665679277013
# Region: Cingulum (hippocampus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0665635492808
# 0.266926786942
# 0.525095886537
# 0.477461965
# Standard deviation of label Cingulum (hippocampus) L: 0.0541674440846
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0537805035885
# Region: Cingulum (hippocampus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0535798298206
# 0.541739755913
# 0.544107193395
# 0.999825505852
# Standard deviation of label Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R: 0.0357013555031
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.035662762581
# Region: Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0349850713993
# 0.597931659573
# 0.680680898233
# 0.902023187148
# Standard deviation of label Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L: 0.0377447627079
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0375297917269
# Region: Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0371278156257
# 0.878944666322
# 0.595779899991
# 0.591843640353
# Standard deviation of label Superior longitudinal fasciculus R: 0.0306389540346
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0303212721791
# Region: Superior longitudinal fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0303200801573
# 0.118434260303
# 0.220914695789
# 0.557265961605
# Standard deviation of label Superior longitudinal fasciculus L: 0.0301807586387
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0301663216835
# Region: Superior longitudinal fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0299136102239
# 0.135186225855
# 0.133004681536
# 0.927528541252
# Standard deviation of label Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R: 0.0450144001193
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0449522302451
# Region: Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0448200448778
# 0.994269334989
# 0.260099180916
# 0.158845793204
# Standard deviation of label Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L: 0.0512971339814
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0511994978177
# Region: Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0507900591732
# 0.607602878333
# 0.0479753507604
# 0.0474939642235
# Standard deviation of label Uncinate fasciculus R: 0.0321764852937
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0319903413345
# Region: Uncinate fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0313466293641
# 0.189462077851
# 0.92310921575
# 0.0985243318918
# Standard deviation of label Uncinate fasciculus L: 0.0504789217408
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.049759433083
# Region: Uncinate fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.049388157604
# 0.936301500363
# 0.474964912263
# 0.284322913775
# Standard deviation of label Tapetum R: 0.0710665402871
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0710652322183
# Region: Tapetum R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0695652223436
# 0.284625162596
# 0.11965400818
# 0.688006755434
# Standard deviation of label Tapetum L: 0.0766239659904
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0764153601873
# Region: Tapetum L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0753757992328
# 0.563863956484
# 0.80957760371
# 0.65052024201

# %%
res
# Out:
#                                              roi_name  (HO, HT)  (HO, NC)  \
# 0              Pontine crossing tract (a part of MCP)  0.680230  0.550716
# 1                             Genu of corpus callosum  0.336397  0.033126
# 2                             Body of corpus callosum  0.731416  0.131609
# 3                         Splenium of corpus callosum  0.203146  0.153938
# 4                  Fornix (column and body of fornix)  0.092564  0.947338
# 5                               Corticospinal tract R  0.950469  0.406673
# 6                               Corticospinal tract L  0.928707  0.897731
# 7                      Superior cerebellar peduncle L  0.160481  0.313900
# 8                                 Cerebral peduncle R  0.220918  0.662716
# 9                                 Cerebral peduncle L  0.107279  0.200727
# 10                Anterior limb of internal capsule R  0.638060  0.297755
# 11                Anterior limb of internal capsule L  0.104126  0.038194
# 12               Posterior limb of internal capsule R  0.121598  0.296246
# 13               Posterior limb of internal capsule L  0.369059  0.297130
# 14         Retrolenticular part of internal capsule R  0.024555  0.245811
# 15         Retrolenticular part of internal capsule L  0.138567  0.230234
# 16                          Anterior corona radiata R  0.428618  0.069124
# 17                          Anterior corona radiata L  0.568169  0.097900
# 18                          Superior corona radiata R  0.586887  0.646547
# 19                          Superior corona radiata L  0.676030  0.227980
# 20                         Posterior corona radiata R  0.048751  0.165930
# 21                         Posterior corona radiata L  0.201156  0.198935
# 22  Posterior thalamic radiation (include optic ra...  0.087892  0.084363
# 23  Posterior thalamic radiation (include optic ra...  0.019855  0.003732
# 24  Sagittal stratum (include inferior longitidina...  0.186667  0.146033
# 25  Sagittal stratum (include inferior longitidina...  0.159700  0.072256
# 26                                 External capsule R  0.263301  0.411132
# 27                                 External capsule L  0.692197  0.926207
# 28                       Cingulum (cingulate gyrus) R  0.375823  0.063889
# 29                       Cingulum (cingulate gyrus) L  0.839534  0.101145
# 30                           Cingulum (hippocampus) R  0.326679  0.891912
# 31                           Cingulum (hippocampus) L  0.616365  0.963961
# 32  Fornix (cres) / Stria terminalis (can not be r...  0.482300  0.989472
# 33  Fornix (cres) / Stria terminalis (can not be r...  0.779588  0.685910
# 34                 Superior longitudinal fasciculus R  0.124259  0.270642
# 35                 Superior longitudinal fasciculus L  0.177377  0.154235
# 36  Superior fronto-occipital fasciculus (could be...  0.972712  0.647733
# 37  Superior fronto-occipital fasciculus (could be...  0.561353  0.212307
# 38                              Uncinate fasciculus R  0.133328  0.506134
# 39                              Uncinate fasciculus L  0.594608  0.742452
# 40                                          Tapetum R  0.301365  0.172854
# 41                                          Tapetum L  0.425430  0.324198
#
#     (HT, NC)
# 0   0.798187
# 1   0.152032
# 2   0.121853
# 3   0.882542
# 4   0.024794
# 5   0.213323
# 6   0.956051
# 7   0.750108
# 8   0.277302
# 9   0.642875
# 10  0.461049
# 11  0.637054
# 12  0.320107
# 13  0.980022
# 14  0.073548
# 15  0.594040
# 16  0.249811
# 17  0.188937
# 18  0.784520
# 19  0.339013
# 20  0.156662
# 21  0.759825
# 22  0.735158
# 23  0.488096
# 24  0.998187
# 25  0.742342
# 26  0.497599
# 27  0.631411
# 28  0.255568
# 29  0.057501
# 30  0.096022
# 31  0.517280
# 32  0.342772
# 33  0.875126
# 34  0.430916
# 35  0.935547
# 36  0.572645
# 37  0.341629
# 38  0.174768
# 39  0.190218
# 40  0.782455
# 41  0.874780

# %%
res.to_excel('/tmp/FA-labels-BSC-full-HOHTNC_wo-E2.xls')

# %%
data.head()
# Out:
#          subject        age  apo  gender  educyears
# subject
# 10019      10019  60.487337    0       1         18
# 10070      10070  50.781656    0       0         10
# 10102      10102  64.065708    0       1         18
# 10108      10108  58.683094    0       0         15
# 10113      10113  47.772758    0       0         11
