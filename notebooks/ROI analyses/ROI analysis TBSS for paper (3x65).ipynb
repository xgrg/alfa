# %% [raw]
# This plots ROI values extracted from images that have been normalized using DARTEL,
# but the values have been extracted from ROI derived from a prior analysis done using images normalized using DARTEL.

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py

# %% [markdown]
# This collect the values from \*\_stats.csv files, i.e. values that have been extracted from ROI manually drawn in MNI space.
# The bad thing with this is that the ROI is defined in a reference space. This is subject to individual registration errors.

# %%
regions = [32767]
#regions = [17,18,19,20]
names = {32767: 'supra'}

data = pd.read_excel('/home/grg/spm/data/covariates.xls')
data = data.set_index(data['subject'])
data = data.sort_values(['apo', 'subject'])

# %% [markdown]
# # MD recessive

# %%
src = '/tmp/roistats_3x65/MD/'
filepattern = '*_stats_recessive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.0007,0.0010])
# Out:
# {32767: 'supra'}
# groups ['HO', 'HT', 'NC']
# Standard deviation of label supra: 3.92476555538e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.89054180883e-05
# Region: supra
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.83055166777e-05
# 6.45908455922e-05
# 0.00869576385276
# 0.104414888472
#   roi_name  (HO, HT)  (HO, NC)  (HT, NC)
# 0    supra  0.000065  0.008696  0.104415

# %% [markdown]
# # MD additive

# %%
src = '/tmp/roistats_3x65/MD'
filepattern = '*_stats_additive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.0007,0.0010])
# Out:
# {32767: 'supra'}
# groups ['HO', 'HT', 'NC']
# Standard deviation of label supra: 3.99557938552e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.99249801606e-05
# Region: supra
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.80667549791e-05
# 0.000115776722949
# 0.00261273440682
# 0.385702550069
#   roi_name  (HO, HT)  (HO, NC)  (HT, NC)
# 0    supra  0.000116  0.002613  0.385703

# %% [markdown]
# # RD recessive

# %%
src = '/tmp/roistats_3x65/RD'
filepattern = '*_stats_recessive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.0005,0.0008])
# Out:
# {32767: 'supra'}
# groups ['HO', 'HT', 'NC']
# Standard deviation of label supra: 3.9077859687e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.85454993182e-05
# Region: supra
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.73315211888e-05
# 0.000218578872887
# 0.00577041108403
# 0.288474769492
#   roi_name  (HO, HT)  (HO, NC)  (HT, NC)
# 0    supra  0.000219   0.00577  0.288475

# %% [markdown]
# # RD additive

# %%
src = '/tmp/roistats_3x65/RD'
filepattern = '*_stats_additive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.0005,0.0008])
# Out:
# {32767: 'supra'}
# groups ['HO', 'HT', 'NC']
# Standard deviation of label supra: 4.13420964026e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.05573133491e-05
# Region: supra
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.85554734153e-05
# 0.00609912898108
# 0.0014095443595
# 0.525120197143
#   roi_name  (HO, HT)  (HO, NC)  (HT, NC)
# 0    supra  0.006099   0.00141   0.52512

# %% [markdown]
# # L1 recessive

# %%
src = '/tmp/roistats_3x65/L1'
filepattern = '*_stats_recessive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

plot_regions(data, regions, csvfiles, subjects, groups=['apoe44', 'apoe34', 'apoe33'], by='apo', names=names, ylim=[0.0012,0.0014])
# Out:
# {32767: 'supra'}
# groups ['apoe44', 'apoe34', 'apoe33']
# Standard deviation of label supra: 6.71576241665e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.68680796924e-05
# Region: supra
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.67321255431e-05
# 8.92288883197e-10
# 0.0015562535419
# 0.00444694055681
#   roi_name  (apoe44, apoe34)  (apoe44, apoe33)  (apoe34, apoe33)
# 0    supra      8.922889e-10          0.001556          0.004447

# %% [markdown]
# # L1 additive

# %%
src = '/tmp/roistats_3x65/L1'
filepattern = '*_stats_additive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.0005,0.0010])
# Out:
# {32767: 'supra'}
# groups ['HO', 'HT', 'NC']
# IndexError: skipped subject 10901 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12172 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12582 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 21130 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10493 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13061 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11474 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10522 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11196 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10330 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12636 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10988 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11620 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12125 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13244 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12391 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10034 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10029 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 55216 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 55388 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10436 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 44057 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11850 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 55734 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10038 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12271 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10944 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10841 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 77179 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11247 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10160 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11646 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11641 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11292 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11222 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10199 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 44491 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11461 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12711 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10333 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12327 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10496 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10071 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11874 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10065 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13214 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10846 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11245 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10036 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12874 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10334 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10697 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11019 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13306 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11152 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12765 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12812 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13151 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10170 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11656 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10032 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10212 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10178 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11254 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13293 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10013 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11213 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10259 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11630 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10326 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12133 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10393 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12975 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10504 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12379 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10900 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 77047 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11257 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13345 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10613 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11137 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12138 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 66257 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10538 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10298 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10024 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10239 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13083 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11583 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10053 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11882 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10180 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11687 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13144 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12269 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 66085 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10144 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10433 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11540 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 66030 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12548 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10744 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10217 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10821 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10118 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12056 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10870 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10325 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13215 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13063 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 44660 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12186 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 44229 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11291 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10822 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11264 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13169 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10678 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10134 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10385 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11184 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10251 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12304 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12356 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10156 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10515 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10855 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10035 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10701 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10367 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10099 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 21039 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10166 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10052 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10894 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11007 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11127 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 21042 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12502 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10226 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10550 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12904 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11747 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10724 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10245 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12483 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11711 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11114 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11561 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12963 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 55630 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11042 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11015 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 66309 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10042 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12308 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13019 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10117 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11939 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12785 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11030 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10096 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11012 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11458 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11796 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10151 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11679 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 66048 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 77252 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11092 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 55057 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 21051 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10541 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12893 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12699 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10106 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11063 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11593 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11592 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12767 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10811 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10741 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13242 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10182 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10946 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12279 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11829 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12511 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10322 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 12947 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10418 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10942 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 11323 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 13059 label index 32767 is out of bounds for axis 0 with size 0
# IndexError: skipped subject 10225 label index 32767 is out of bounds for axis 0 with size 0
# Standard deviation of label supra: nan
# Model used for correction: roi ~ 1 + gender
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-24-f54888ec4dbf> in <module>()
#       4 subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]
#       5
# ----> 6 plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.0005,0.0010])
#
# /home/grg/git/alfa/roicollect.py in plot_regions(data, labels, csvfiles, subjects, names, groups, by, nb_orders, do_correct, ylim)
#     179             # correction without ajusting for age
#     180             adj_model = 'roi ~ 1 + gender'
# --> 181             ycorr = pd.DataFrame(correct(df, adj_model), columns=['roi'])
#     182             df = data.join(ycorr)
#     183             print 'Standard deviation after correction for model %s:'%adj_model,\
#
# /home/grg/git/alfa/roicollect.py in correct(df, model)
#      45     ''' Applies a correction for covariates to a given DataFrame'''
#      46     print 'Model used for correction:', model
# ---> 47     test_scores = ols(model, data=df).fit()
#      48
#      49     err = test_scores.predict(df) - df['roi']
#
# /home/grg/jupyter/local/lib/python2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# /home/grg/jupyter/local/lib/python2.7/site-packages/statsmodels/formula/formulatools.pyc in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /home/grg/jupyter/local/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
# --> 312         raise PatsyError("model is missing required outcome variables")
#     313     return (lhs, rhs)
#
# PatsyError: model is missing required outcome variables
