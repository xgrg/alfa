# %% [raw]
# This plots ROI values extracted from images that have been normalized using DARTEL,
# but the values have been extracted from ROI derived from a prior analysis done using images normalized using DARTEL.

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py
import seaborn as sns
reload(sns)
sns.set()

# %% [markdown]
# This collect the values from \*\_stats.csv files, i.e. values that have been extracted from ROI manually drawn in MNI space.
# The bad thing with this is that the ROI is defined in a reference space. This is subject to individual registration errors.

# %%
regions = [1]
names = {1: 'supra'}

data = pd.read_excel('/home/grg/spm/data/covariates.xls')
data = data.set_index(data['subject'])
data = data.sort_values(['apo', 'subject'])
data.head()
# Out:
#          subject  apo        age  gender  educyears  ventricles
# subject
# 10070      10070    0  50.781656       0         10    4.520876
# 10102      10102    0  64.065708       1         18   16.507219
# 10108      10108    0  58.683094       0         15   10.421616
# 10235      10235    0  61.245722       0          8    7.564201
# 10365      10365    0  48.720055       0         12    7.770477

# %% [markdown]
# # MD recessive

# %%
src = '/tmp/roistats_bsc_20170821/MD'
filepattern = '*_stats_recessive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

#plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.00073,0.0009])

roivalues = collect_roivalues(1, csvfiles=csvfiles, subjects=subjects)
lm_plot(data, roivalues, ylim=[0.00073,0.0009])
# Out:
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.44607027577e-05

# %% [markdown]
# # MD additive

# %%
src = '/tmp/roistats_bsc_20170821//MD'
#src = '/tmp/additive_effect_voxel/MD'
filepattern = '*_stats_additive.csv'
regions = [1]
names = {1: 'supra'}
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

#plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.0006,0.0011])
roivalues = collect_roivalues(1, csvfiles=csvfiles, subjects=subjects)
lm_plot(data, roivalues, ylim=[0.0007,0.00091])
# Out:
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.71272068382e-05

# %% [markdown]
# # RD recessive

# %%
src = '/tmp/roistats_bsc_20170821//RD'
filepattern = '*_stats_recessive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]
roivalues = collect_roivalues(1, csvfiles=csvfiles, subjects=subjects)

#plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.00049,0.0007])
roivalues = collect_roivalues(1, csvfiles=csvfiles, subjects=subjects)

lm_plot(data, roivalues, ylim=[0.00048,0.0007])
# Out:
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.77843996975e-05

# %% [markdown]
# # RD additive

# %%
src = '/tmp/roistats_bsc_20170821//RD'
#src = '/tmp/additive_effect_voxel/RD'
filepattern = '*_stats_additive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

#plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.00035,0.00085])
roivalues = collect_roivalues(1, csvfiles=csvfiles, subjects=subjects)
lm_plot(data, roivalues, ylim=[0.00048,0.0007])
# Out:
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.83275553414e-05

# %% [markdown]
# # L1 recessive

# %%
src = '/tmp/roistats_bsc_20170821/L1'
filepattern = '*_stats_recessive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

#plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.001125,0.0014])
roivalues = collect_roivalues(1, csvfiles=csvfiles, subjects=subjects)

lm_plot(data, roivalues, ylim=[0.001125,0.0014])
# Out:
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.68642381865e-05

# %% [markdown]
# # L1 additive

# %%
src = '/tmp/roistats_bsc_20170821/L1'
#src = '/tmp/additive_effect_voxel///L1'

filepattern = '*_stats_additive.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

#plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.0009,0.0016])
roivalues = collect_roivalues(1, csvfiles=csvfiles, subjects=subjects)

lm_plot(data, roivalues, ylim=[0.00105,0.0014])
# Out:
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.86545667433e-05

# %% [markdown]
# ### FA voxel

# %%
src = '/tmp/roistats_bsc_20170821/FA'
filepattern = '*_stats_voxel.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'HT', 'NC'], by='apo', names=names,ylim=[0.3,0.6])
# Out:
# {1: 'supra'}
# groups ['HO', 'HT', 'NC']
# Standard deviation of label supra: 0.0768089886264
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.0768003447389
# Region: supra
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.0767088502231
# 0.0324227470111
# 0.0102496607832
# 0.604728941661
#   roi_name  (HO, HT)  (HO, NC)  (HT, NC)
# 0    supra  0.032423   0.01025  0.604729
