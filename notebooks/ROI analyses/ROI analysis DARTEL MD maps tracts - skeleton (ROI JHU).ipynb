# %% [markdown]
# This plots ROI values extracted from images that have been normalized using DARTEL,
# but the values have been extracted from ROI derived from a prior analysis done using images normalized using DARTEL.

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py

# %% [markdown]
# This collect the values from \*\_stats.csv files, i.e. values that have been extracted from ROI manually drawn in MNI space.
# The bad thing with this is that the ROI is defined in a reference space. This is subject to individual registration errors.

# %%
regions = range(1,20 )
#for x in [9]: #,10,11,12,13]:
#    regions.remove(x)
names = {0: 'Anterior thalamic radiation L',
 1: 'Anterior thalamic radiation R',
 2: 'Corticospinal tract L',
 3: 'Corticospinal tract R',
 4: 'Cingulum (cingulate gyrus) L',
 5: 'Cingulum (cingulate gyrus) R',
 6: 'Cingulum (hippocampus) L',
 7: 'Cingulum (hippocampus) R',
 8: 'Forceps major',
 9: 'Forceps minor',
 10: 'Inferior fronto-occipital fasciculus L',
 11: 'Inferior fronto-occipital fasciculus R',
 12: 'Inferior longitudinal fasciculus L',
 13: 'Inferior longitudinal fasciculus R',
 14: 'Superior longitudinal fasciculus L',
 15: 'Superior longitudinal fasciculus R',
 16: 'Uncinate fasciculus L',
 17: 'Uncinate fasciculus R',
 18: 'Superior longitudinal fasciculus (temporal part) L',
 19: 'Superior longitudinal fasciculus (temporal part) R'}

data = pd.read_excel('/home/grg/spm/data/covariates.xls')
data = data.set_index(data['subject'])
data = data.sort_values(['apo', 'subject'])
src = '/tmp/roivalues_tracts_skel_DARTEL_MD/'
filepattern = '*_stats.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

to_remove = [10551, 10397, 11383, 13083, 10701, 21092] # failed DARTEL subjects

# remove wrong subjects
data = data[~data['subject'].isin(to_remove)]
for e in to_remove:
    if e in subjects:
        s = subjects.index(e)
        subjects.pop(s)
        csvfiles.pop(s)
values = collect_roivalues(3, csvfiles=csvfiles, subjects=subjects)

#data.join(values)
#poly = ols(formula='roi ~ 1 + age', data=data.join(values)).fit()
plot_regions(data, regions, csvfiles, subjects,  names=names ,ylim=[0.0007,0.0013])
# Out:
# using default groups
# Standard deviation of label Anterior thalamic radiation R: 5.61439399547e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 5.50498047511e-05
# Region: Anterior thalamic radiation R
# Standard deviation of label Corticospinal tract L: 6.10707437398e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 5.9830784361e-05
# Region: Corticospinal tract L
# Standard deviation of label Corticospinal tract R: 4.18035014297e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 4.11814874121e-05
# Region: Corticospinal tract R
# Standard deviation of label Cingulum (cingulate gyrus) L: 4.26830617593e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 4.19445879904e-05
# Region: Cingulum (cingulate gyrus) L
# Standard deviation of label Cingulum (cingulate gyrus) R: 3.84279414686e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 3.55305640603e-05
# Region: Cingulum (cingulate gyrus) R
# Standard deviation of label Cingulum (hippocampus) L: 3.78483070817e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 3.69512492449e-05
# Region: Cingulum (hippocampus) L
# Standard deviation of label Cingulum (hippocampus) R: 6.35000571786e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 6.12483298854e-05
# Region: Cingulum (hippocampus) R
# Standard deviation of label Forceps major: 6.91577134687e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 6.58991747106e-05
# Region: Forceps major
# Standard deviation of label Forceps minor: 3.93794606123e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 3.52826772751e-05
# Region: Forceps minor
# Standard deviation of label Inferior fronto-occipital fasciculus L: 5.10356408053e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 5.07733852519e-05
# Region: Inferior fronto-occipital fasciculus L
# Standard deviation of label Inferior fronto-occipital fasciculus R: 3.86506998056e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 3.66594409002e-05
# Region: Inferior fronto-occipital fasciculus R
# Standard deviation of label Inferior longitudinal fasciculus L: 4.165760459e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 3.86566655515e-05
# Region: Inferior longitudinal fasciculus L
# Standard deviation of label Inferior longitudinal fasciculus R: 3.72490927391e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 3.5891763916e-05
# Region: Inferior longitudinal fasciculus R
# Standard deviation of label Superior longitudinal fasciculus L: 4.14001912692e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 3.65992649562e-05
# Region: Superior longitudinal fasciculus L
# Standard deviation of label Superior longitudinal fasciculus R: 3.77072256126e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 3.51104222241e-05
# Region: Superior longitudinal fasciculus R
# Standard deviation of label Uncinate fasciculus L: 3.78412084636e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 3.61661383799e-05
# Region: Uncinate fasciculus L
# Standard deviation of label Uncinate fasciculus R: 4.75971639644e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 4.53572033574e-05
# Region: Uncinate fasciculus R
# Standard deviation of label Superior longitudinal fasciculus (temporal part) L: 4.79282872776e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 4.37397083513e-05
# Region: Superior longitudinal fasciculus (temporal part) L
# Standard deviation of label Superior longitudinal fasciculus (temporal part) R: 4.05448457389e-05
# Model used for correction: roi ~ 1 + C(apo) + gender + educyears + ventricles
# Standard deviation after correction for covariates: 3.96681657593e-05
# Region: Superior longitudinal fasciculus (temporal part) R
