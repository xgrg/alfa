# %% [markdown]
# This plots ROI values extracted from images that have been normalized using DARTEL,
# but the values have been extracted from ROI derived from a prior analysis done using images normalized using DARTEL.

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py
# Out:
# /home/grg/jupyter/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/grg/jupyter/local/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# This collect the values from \*\_stats.csv files, i.e. values that have been extracted from ROI manually drawn in MNI space.
# The bad thing with this is that the ROI is defined in a reference space. This is subject to individual registration errors.

# %%
#regions = [11,12,13,14] 
#regions = [15,16,19,20]
#regions = [5,6,7,8]
regions = range(1,21)
#for x in [9]: #,10,11,12,13]:
#    regions.remove(x)
names = {1: 'Anterior thalamic radiation L',
 2: 'Anterior thalamic radiation R',
 3: 'Corticospinal tract L',
 4: 'Corticospinal tract R',
 5: 'Cingulum (cingulate gyrus) L',
 6: 'Cingulum (cingulate gyrus) R',
 7: 'Cingulum (hippocampus) L',
 8: 'Cingulum (hippocampus) R',
 9: 'Forceps major',
 10: 'Forceps minor',
 11: 'Inferior fronto-occipital fasciculus L',
 12: 'Inferior fronto-occipital fasciculus R',
 13: 'Inferior longitudinal fasciculus L',
 14: 'Inferior longitudinal fasciculus R',
 15: 'Superior longitudinal fasciculus L',
 16: 'Superior longitudinal fasciculus R',
 17: 'Uncinate fasciculus L',
 18: 'Uncinate fasciculus R',
 19: 'Superior longitudinal fasciculus (temporal part) L',
 20: 'Superior longitudinal fasciculus (temporal part) R'}

data = pd.read_excel('/tmp/covariates.xlsx')
data = data.set_index(data['subject'])
data = data.sort_values(['apo', 'subject'])
src = '/tmp/roivalues_tracts_tbss_L1_skel/'
filepattern = '*_stats.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

#import json
#j = json.load(open('/home/grg/spm/data/matched_groups.json'))
#subjects = []
#for each in j:
#    subjects.extend(each)
#csvfiles = []
#for s in subjects:
#    csvfp = glob(osp.join(src, '%s%s'%(s, filepattern)))[0]
#    csvfiles.append(csvfp)



values = collect_roivalues(3, csvfiles=csvfiles, subjects=subjects)

#data.join(values)
#poly = ols(formula='roi ~ 1 + age', data=data.join(values)).fit()
res = plot_regions(data, regions, csvfiles, subjects, groups=['HO', 'notHO'], by='apo', names=names,ylim=[0.0011,0.0016])
# Out:
# {1: 'Anterior thalamic radiation L', 2: 'Anterior thalamic radiation R', 3: 'Corticospinal tract L', 4: 'Corticospinal tract R', 5: 'Cingulum (cingulate gyrus) L', 6: 'Cingulum (cingulate gyrus) R', 7: 'Cingulum (hippocampus) L', 8: 'Cingulum (hippocampus) R', 9: 'Forceps major', 10: 'Forceps minor', 11: 'Inferior fronto-occipital fasciculus L', 12: 'Inferior fronto-occipital fasciculus R', 13: 'Inferior longitudinal fasciculus L', 14: 'Inferior longitudinal fasciculus R', 15: 'Superior longitudinal fasciculus L', 16: 'Superior longitudinal fasciculus R', 17: 'Uncinate fasciculus L', 18: 'Uncinate fasciculus R', 19: 'Superior longitudinal fasciculus (temporal part) L', 20: 'Superior longitudinal fasciculus (temporal part) R'}
# groups ['HO', 'notHO']
# Standard deviation of label Anterior thalamic radiation L: 0.000104062104777
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000101619564119
# Region: Anterior thalamic radiation L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 9.6462470571e-05
# 0.886366920617
# Standard deviation of label Anterior thalamic radiation R: 0.000103045325157
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000100341658294
# Region: Anterior thalamic radiation R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 9.76898426635e-05
# 0.424079273916
# Standard deviation of label Corticospinal tract L: 8.93986393942e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.70640622997e-05
# Region: Corticospinal tract L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.68272768498e-05
# 0.481243643154
# Standard deviation of label Corticospinal tract R: 5.05995258642e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.98547606736e-05
# Region: Corticospinal tract R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.97087869543e-05
# 0.111883062679
# Standard deviation of label Cingulum (cingulate gyrus) L: 8.05129487025e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.95798355648e-05
# Region: Cingulum (cingulate gyrus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.89343594913e-05
# 0.389625088821
# Standard deviation of label Cingulum (cingulate gyrus) R: 7.89827842774e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.88591121896e-05
# Region: Cingulum (cingulate gyrus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.86374992788e-05
# 0.480522099331
# Standard deviation of label Cingulum (hippocampus) L: 9.9409646321e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 9.93533011952e-05
# Region: Cingulum (hippocampus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 9.93395726949e-05
# 0.00898387176375
# Standard deviation of label Cingulum (hippocampus) R: 0.000134425060577
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000134275498612
# Region: Cingulum (hippocampus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.00013418956468
# 0.260472662255
# Standard deviation of label Forceps major: 8.17945619683e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.1458784568e-05
# Region: Forceps major
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.12589030997e-05
# 0.148917571081
# Standard deviation of label Forceps minor: 6.61939197777e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.45195685238e-05
# Region: Forceps minor
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.41526635709e-05
# 0.737143507306
# Standard deviation of label Inferior fronto-occipital fasciculus L: 5.46628163924e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.39240299182e-05
# Region: Inferior fronto-occipital fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.36176691959e-05
# 0.0286997962111
# Standard deviation of label Inferior fronto-occipital fasciculus R: 5.53607513029e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.42185975849e-05
# Region: Inferior fronto-occipital fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.37018212482e-05
# 0.0790985716227
# Standard deviation of label Inferior longitudinal fasciculus L: 5.14689948702e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.09231655447e-05
# Region: Inferior longitudinal fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.06439869325e-05
# 0.0991074451917
# Standard deviation of label Inferior longitudinal fasciculus R: 6.2412579998e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.11206880865e-05
# Region: Inferior longitudinal fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.07938253336e-05
# 0.0645208357462
# Standard deviation of label Superior longitudinal fasciculus L: 4.59770370337e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.56901338455e-05
# Region: Superior longitudinal fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.49964037493e-05
# 0.0401219536945
# Standard deviation of label Superior longitudinal fasciculus R: 4.66989763354e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.64088191952e-05
# Region: Superior longitudinal fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.62225299763e-05
# 0.0381960078057
# Standard deviation of label Uncinate fasciculus L: 6.11474973718e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.09772385746e-05
# Region: Uncinate fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.09611698228e-05
# 0.325367971741
# Standard deviation of label Uncinate fasciculus R: 8.80372676129e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.6258446614e-05
# Region: Uncinate fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.61547564774e-05
# 0.859233248834
# Standard deviation of label Superior longitudinal fasciculus (temporal part) L: 7.09081768593e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.07702823887e-05
# Region: Superior longitudinal fasciculus (temporal part) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.06163733023e-05
# 0.0726066500631
# Standard deviation of label Superior longitudinal fasciculus (temporal part) R: 6.44960411746e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.44949425415e-05
# Region: Superior longitudinal fasciculus (temporal part) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.43926391716e-05
# 0.0195863793569

# %%
res
# Out:
#                                              roi_name  (HO, notHO)
# 0                       Anterior thalamic radiation L     0.404126
# 1                       Anterior thalamic radiation R     0.202275
# 2                               Corticospinal tract L     0.033721
# 3                               Corticospinal tract R     0.178938
# 4                        Cingulum (cingulate gyrus) L     0.068471
# 5                        Cingulum (cingulate gyrus) R     0.060704
# 6                            Cingulum (hippocampus) L     0.083289
# 7                            Cingulum (hippocampus) R     0.050371
# 8                                       Forceps major     0.336099
# 9                                       Forceps minor     0.085275
# 10             Inferior fronto-occipital fasciculus L     0.001537
# 11             Inferior fronto-occipital fasciculus R     0.011987
# 12                 Inferior longitudinal fasciculus L     0.007093
# 13                 Inferior longitudinal fasciculus R     0.002904
# 14                 Superior longitudinal fasciculus L     0.016102
# 15                 Superior longitudinal fasciculus R     0.010404
# 16                              Uncinate fasciculus L     0.403110
# 17                              Uncinate fasciculus R     0.275502
# 18  Superior longitudinal fasciculus (temporal par...     0.001834
# 19  Superior longitudinal fasciculus (temporal par...     0.000057

# %%
res.to_excel('/tmp/L1-tracts-BSC-full-HOnotHO.xls')

# %%
pwd
# Out:
# u'/home/grg/git/alfa/notebooks/ROI analyses'
