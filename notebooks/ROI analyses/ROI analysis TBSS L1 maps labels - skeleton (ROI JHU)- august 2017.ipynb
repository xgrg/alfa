# %% [raw]
# This plots ROI values extracted from images that have been normalized using DARTEL,
# but the values have been extracted from ROI derived from a prior analysis done using images normalized using DARTEL.

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py
# Out:
# /home/grg/jupyter/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/grg/jupyter/local/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# This collect the values from \*\_stats.csv files, i.e. values that have been extracted from ROI manually drawn in MNI space.
# The bad thing with this is that the ROI is defined in a reference space. This is subject to individual registration errors.

# %%
regions = range(2, 49)
for x in [9,10,11,12,13]:
    regions.remove(x)

#regions = [17,18,19,20]
names = {1: 'Middle cerebellar peduncle',
 2: 'Pontine crossing tract (a part of MCP)',
 3: 'Genu of corpus callosum',
 4: 'Body of corpus callosum',
 5: 'Splenium of corpus callosum',
 6: 'Fornix (column and body of fornix)',
 7: 'Corticospinal tract R',
 8: 'Corticospinal tract L',
 9: 'Medial lemniscus R',
 10: 'Medial lemniscus L',
 11: 'Inferior cerebellar peduncle R  ',
 12: 'Inferior cerebellar peduncle L',
 13: 'Superior cerebellar peduncle R',
 14: 'Superior cerebellar peduncle L',
 15: 'Cerebral peduncle R',
 16: 'Cerebral peduncle L',
 17: 'Anterior limb of internal capsule R',
 18: 'Anterior limb of internal capsule L',
 19: 'Posterior limb of internal capsule R',
 20: 'Posterior limb of internal capsule L',
 21: 'Retrolenticular part of internal capsule R',
 22: 'Retrolenticular part of internal capsule L',
 23: 'Anterior corona radiata R',
 24: 'Anterior corona radiata L',
 25: 'Superior corona radiata R',
 26: 'Superior corona radiata L',
 27: 'Posterior corona radiata R',
 28: 'Posterior corona radiata L',
 29: 'Posterior thalamic radiation (include optic radiation) R',
 30: 'Posterior thalamic radiation (include optic radiation) L',
 31: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R',
 32: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L',
 33: 'External capsule R',
 34: 'External capsule L',
 35: 'Cingulum (cingulate gyrus) R',
 36: 'Cingulum (cingulate gyrus) L',
 37: 'Cingulum (hippocampus) R',
 38: 'Cingulum (hippocampus) L',
 39: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R',
 40: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L',
 41: 'Superior longitudinal fasciculus R',
 42: 'Superior longitudinal fasciculus L',
 43: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R',
 44: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L',
 45: 'Uncinate fasciculus R',
 46: 'Uncinate fasciculus L',
 47: 'Tapetum R',
 48: 'Tapetum L'}

data = pd.read_excel('/home/grg/spm/data/covariates.xls')
data = data.set_index(data['subject'])
data = data.sort_values(['apo', 'subject'])
src = '/home/grg/tbss_bsc_subjects/roivalues_labels_tbss_L1_skel/'
filepattern = '*_stats.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]


#data.join(values)
#poly = ols(formula='roi ~ 1 + age', data=data.join(values)).fit()
res = plot_regions(data, regions, csvfiles, subjects, groups=['HO','HT', 'NC'], by='apo', names=names,ylim=[0.0005,0.0010])
# Out:
# {1: 'Middle cerebellar peduncle', 2: 'Pontine crossing tract (a part of MCP)', 3: 'Genu of corpus callosum', 4: 'Body of corpus callosum', 5: 'Splenium of corpus callosum', 6: 'Fornix (column and body of fornix)', 7: 'Corticospinal tract R', 8: 'Corticospinal tract L', 9: 'Medial lemniscus R', 10: 'Medial lemniscus L', 11: 'Inferior cerebellar peduncle R  ', 12: 'Inferior cerebellar peduncle L', 13: 'Superior cerebellar peduncle R', 14: 'Superior cerebellar peduncle L', 15: 'Cerebral peduncle R', 16: 'Cerebral peduncle L', 17: 'Anterior limb of internal capsule R', 18: 'Anterior limb of internal capsule L', 19: 'Posterior limb of internal capsule R', 20: 'Posterior limb of internal capsule L', 21: 'Retrolenticular part of internal capsule R', 22: 'Retrolenticular part of internal capsule L', 23: 'Anterior corona radiata R', 24: 'Anterior corona radiata L', 25: 'Superior corona radiata R', 26: 'Superior corona radiata L', 27: 'Posterior corona radiata R', 28: 'Posterior corona radiata L', 29: 'Posterior thalamic radiation (include optic radiation) R', 30: 'Posterior thalamic radiation (include optic radiation) L', 31: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R', 32: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L', 33: 'External capsule R', 34: 'External capsule L', 35: 'Cingulum (cingulate gyrus) R', 36: 'Cingulum (cingulate gyrus) L', 37: 'Cingulum (hippocampus) R', 38: 'Cingulum (hippocampus) L', 39: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R', 40: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L', 41: 'Superior longitudinal fasciculus R', 42: 'Superior longitudinal fasciculus L', 43: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R', 44: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L', 45: 'Uncinate fasciculus R', 46: 'Uncinate fasciculus L', 47: 'Tapetum R', 48: 'Tapetum L'}
# groups ['HO', 'HT', 'NC']
# Standard deviation of label Pontine crossing tract (a part of MCP): 6.67404203186e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.66907196942e-05
# Region: Pontine crossing tract (a part of MCP)
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.57850053058e-05
# 0.341178234666
# 0.90409230222
# 0.210766860957
# Standard deviation of label Genu of corpus callosum: 0.000130326573457
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000125252194071
# Region: Genu of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000124908438318
# 0.251985827592
# 0.239432583199
# 0.873922831242
# Standard deviation of label Body of corpus callosum: 9.52329900767e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 9.17121366196e-05
# Region: Body of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 9.13784522766e-05
# 0.887744273688
# 0.64195061406
# 0.632944559321
# Standard deviation of label Splenium of corpus callosum: 0.000112326322086
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000110822048867
# Region: Splenium of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000108919539152
# 0.849592617626
# 0.527738737984
# 0.237280424902
# Standard deviation of label Fornix (column and body of fornix): 0.000433200251586
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000419906776136
# Region: Fornix (column and body of fornix)
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000400757097228
# 0.861864409347
# 0.832711940255
# 0.567689602484
# Standard deviation of label Corticospinal tract R: 6.73193196272e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.62361336029e-05
# Region: Corticospinal tract R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.58657676969e-05
# 0.104605442317
# 0.489616923617
# 0.187937327321
# Standard deviation of label Corticospinal tract L: 0.000104030464578
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000103483321545
# Region: Corticospinal tract L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000103472893106
# 0.0472617139173
# 0.555949862166
# 0.0340111644877
# Standard deviation of label Superior cerebellar peduncle L: 9.46074310292e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 9.12308544774e-05
# Region: Superior cerebellar peduncle L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 9.05931923157e-05
# 0.957037337476
# 0.794565684733
# 0.645100203962
# Standard deviation of label Cerebral peduncle R: 8.28037069932e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.01095544653e-05
# Region: Cerebral peduncle R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.00624088502e-05
# 0.75649559663
# 0.713994882121
# 0.332396496356
# Standard deviation of label Cerebral peduncle L: 0.000213862975612
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000207383056354
# Region: Cerebral peduncle L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000205816920923
# 0.763706651998
# 0.575185526445
# 0.193246136073
# Standard deviation of label Anterior limb of internal capsule R: 7.20838360274e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.0809378873e-05
# Region: Anterior limb of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.0088841482e-05
# 0.822907244675
# 0.348031829837
# 0.337567144738
# Standard deviation of label Anterior limb of internal capsule L: 9.13649759755e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.95065423154e-05
# Region: Anterior limb of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.93261215026e-05
# 0.924170074803
# 0.296750455659
# 0.158072461683
# Standard deviation of label Posterior limb of internal capsule R: 8.30258382881e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.09002319001e-05
# Region: Posterior limb of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.06418021234e-05
# 0.440429404976
# 0.288633705243
# 0.815361043761
# Standard deviation of label Posterior limb of internal capsule L: 8.37115109191e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.30778212423e-05
# Region: Posterior limb of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.30324148022e-05
# 0.138077001194
# 0.239696740226
# 0.674923425013
# Standard deviation of label Retrolenticular part of internal capsule R: 7.40870815018e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.22462595736e-05
# Region: Retrolenticular part of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.12509622917e-05
# 0.121232488788
# 0.105129718227
# 0.785336245719
# Standard deviation of label Retrolenticular part of internal capsule L: 6.38959490669e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.34688810549e-05
# Region: Retrolenticular part of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.2619666128e-05
# 0.100564044317
# 0.0755912640698
# 0.83242529037
# Standard deviation of label Anterior corona radiata R: 5.80047920699e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.74856242082e-05
# Region: Anterior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.64187352179e-05
# 0.258260584849
# 0.749112355178
# 0.215975038515
# Standard deviation of label Anterior corona radiata L: 5.75028967259e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.71271867394e-05
# Region: Anterior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.64024436132e-05
# 0.0405804493883
# 0.356923528209
# 0.101894622198
# Standard deviation of label Superior corona radiata R: 5.45243578574e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.39729806704e-05
# Region: Superior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.34405665593e-05
# 0.026672933913
# 0.0723314070614
# 0.427596858611
# Standard deviation of label Superior corona radiata L: 5.29371527539e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.19171390006e-05
# Region: Superior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.04456906546e-05
# 0.0574693883043
# 0.0528887531119
# 0.969752690953
# Standard deviation of label Posterior corona radiata R: 6.87159754505e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.86652905876e-05
# Region: Posterior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.613894677e-05
# 0.0232287377711
# 0.0744221970484
# 0.405779504461
# Standard deviation of label Posterior corona radiata L: 5.95873715007e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.89895070681e-05
# Region: Posterior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.57084847659e-05
# 0.0607045950236
# 0.350485531689
# 0.202569226176
# Standard deviation of label Posterior thalamic radiation (include optic radiation) R: 7.17725045313e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.17236431517e-05
# Region: Posterior thalamic radiation (include optic radiation) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.17168117438e-05
# 0.000491995087446
# 0.0321376768296
# 0.0417053267062
# Standard deviation of label Posterior thalamic radiation (include optic radiation) L: 7.14335892307e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.09356276125e-05
# Region: Posterior thalamic radiation (include optic radiation) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.08951883406e-05
# 0.0334780862212
# 0.436069695671
# 0.0550094341071
# Standard deviation of label Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R: 7.56602763223e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.30026646323e-05
# Region: Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.24540597525e-05
# 0.0568759410327
# 0.117327919788
# 0.47293855068
# Standard deviation of label Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L: 6.9472954333e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.77444784699e-05
# Region: Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.69156364177e-05
# 0.00771805534682
# 0.233051118905
# 0.0255680017865
# Standard deviation of label External capsule R: 7.6262347715e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.52485317715e-05
# Region: External capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.43050513196e-05
# 0.0956653703349
# 0.436223346203
# 0.102629577209
# Standard deviation of label External capsule L: 6.5405055892e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.50445210307e-05
# Region: External capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.34899817138e-05
# 0.0388007109743
# 0.0713717861235
# 0.524774595789
# Standard deviation of label Cingulum (cingulate gyrus) R: 7.52777547274e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.49347280331e-05
# Region: Cingulum (cingulate gyrus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.48134992563e-05
# 0.257585045718
# 0.347218424717
# 0.655818348415
# Standard deviation of label Cingulum (cingulate gyrus) L: 8.09045294288e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.98414525015e-05
# Region: Cingulum (cingulate gyrus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.93089931328e-05
# 0.110145631669
# 0.634258759464
# 0.0991505657203
# Standard deviation of label Cingulum (hippocampus) R: 0.000133610950006
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000133442149405
# Region: Cingulum (hippocampus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000133205785341
# 0.320688966864
# 0.2565975931
# 0.989121346326
# Standard deviation of label Cingulum (hippocampus) L: 0.000102015496281
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000101898455676
# Region: Cingulum (hippocampus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000101891008506
# 0.105375010603
# 0.00484287726415
# 0.0919807760096
# Standard deviation of label Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R: 0.000106586857754
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000103530857256
# Region: Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000103472166906
# 0.630754823276
# 0.432873758255
# 0.712368413008
# Standard deviation of label Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L: 8.80168205346e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.72984826425e-05
# Region: Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.72980091597e-05
# 0.202722276034
# 0.476119957924
# 0.447895921462
# Standard deviation of label Superior longitudinal fasciculus R: 4.68640752278e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.66809194479e-05
# Region: Superior longitudinal fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.64657194421e-05
# 0.0658922808399
# 0.0417235200762
# 0.99886143158
# Standard deviation of label Superior longitudinal fasciculus L: 4.68485912498e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.66002594483e-05
# Region: Superior longitudinal fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.6108163375e-05
# 0.0461008477688
# 0.0621363657426
# 0.744567362201
# Standard deviation of label Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R: 8.72805421651e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.65178145551e-05
# Region: Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.60869867922e-05
# 0.0177913463048
# 0.246085936955
# 0.0721899859047
# Standard deviation of label Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L: 9.16065475032e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 9.05319385324e-05
# Region: Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 9.05273001581e-05
# 0.439024955713
# 0.9104986442
# 0.349655426151
# Standard deviation of label Uncinate fasciculus R: 7.02471566613e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.90770731616e-05
# Region: Uncinate fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.90483180702e-05
# 0.529687174161
# 0.530805020185
# 0.931651274245
# Standard deviation of label Uncinate fasciculus L: 8.73963263078e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.73607429233e-05
# Region: Uncinate fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.71956906619e-05
# 0.950749502273
# 0.701183408395
# 0.455630931199
# Standard deviation of label Tapetum R: 0.000146846633714
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000146016889634
# Region: Tapetum R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000143792889652
# 0.0439644490831
# 0.172325606891
# 0.278376316997
# Standard deviation of label Tapetum L: 0.000203499494661
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000203024334532
# Region: Tapetum L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000193931581453
# 0.545722976506
# 0.841583512887
# 0.249811975405

# %%
res.to_excel('/tmp/L1-labels-BSC-full-HOHTNC.xls')
