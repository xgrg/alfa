# %% [raw]
# This plots ROI values extracted from images that have been normalized using DARTEL,
# but the values have been extracted from ROI derived from a prior analysis done using images normalized using DARTEL.

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py

# %% [markdown]
# This collect the values from \*\_stats.csv files, i.e. values that have been extracted from ROI manually drawn in MNI space.
# The bad thing with this is that the ROI is defined in a reference space. This is subject to individual registration errors.

# %%
regions = range(2, 49)
for x in [9,10,11,12,13]:
    regions.remove(x)
#regions = [
#regions = [17,18,19,20]
names = {1: 'Middle cerebellar peduncle',
 2: 'Pontine crossing tract (a part of MCP)',
 3: 'Genu of corpus callosum',
 4: 'Body of corpus callosum',
 5: 'Splenium of corpus callosum',
 6: 'Fornix (column and body of fornix)',
 7: 'Corticospinal tract R',
 8: 'Corticospinal tract L',
 9: 'Medial lemniscus R',
 10: 'Medial lemniscus L',
 11: 'Inferior cerebellar peduncle R  ',
 12: 'Inferior cerebellar peduncle L',
 13: 'Superior cerebellar peduncle R',
 14: 'Superior cerebellar peduncle L',
 15: 'Cerebral peduncle R',
 16: 'Cerebral peduncle L',
 17: 'Anterior limb of internal capsule R',
 18: 'Anterior limb of internal capsule L',
 19: 'Posterior limb of internal capsule R',
 20: 'Posterior limb of internal capsule L',
 21: 'Retrolenticular part of internal capsule R',
 22: 'Retrolenticular part of internal capsule L',
 23: 'Anterior corona radiata R',
 24: 'Anterior corona radiata L',
 25: 'Superior corona radiata R',
 26: 'Superior corona radiata L',
 27: 'Posterior corona radiata R',
 28: 'Posterior corona radiata L',
 29: 'Posterior thalamic radiation (include optic radiation) R',
 30: 'Posterior thalamic radiation (include optic radiation) L',
 31: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R',
 32: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L',
 33: 'External capsule R',
 34: 'External capsule L',
 35: 'Cingulum (cingulate gyrus) R',
 36: 'Cingulum (cingulate gyrus) L',
 37: 'Cingulum (hippocampus) R',
 38: 'Cingulum (hippocampus) L',
 39: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R',
 40: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L',
 41: 'Superior longitudinal fasciculus R',
 42: 'Superior longitudinal fasciculus L',
 43: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R',
 44: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L',
 45: 'Uncinate fasciculus R',
 46: 'Uncinate fasciculus L',
 47: 'Tapetum R',
 48: 'Tapetum L'}

data = pd.read_excel('/home/grg/spm/data/covariates.xls')
data = data.set_index(data['subject'])
data = data.sort_values(['apo', 'subject'])
src = '/home/grg/tbss_bsc_subjects/roivalues_labels_tbss_MD_skel/'
filepattern = '*_stats.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

df = pd.read_excel('/home/grg/spm/data/covariates.xls')
subjects = list(df[df['apo']!=1]['subject'].values)
csvfiles = []
for s in subjects:
    csvfp = glob(osp.join(src, '%s%s'%(s, filepattern)))[0]
    csvfiles.append(csvfp)
        
#data.join(values)
#poly = ols(formula='roi ~ 1 + age', data=data.join(values)).fit()
res = plot_regions(data, regions, csvfiles, subjects, groups=['HO','HT', 'NC'], by='apo', names=names,ylim=[0.0005,0.0010])
# Out:
# {1: 'Middle cerebellar peduncle', 2: 'Pontine crossing tract (a part of MCP)', 3: 'Genu of corpus callosum', 4: 'Body of corpus callosum', 5: 'Splenium of corpus callosum', 6: 'Fornix (column and body of fornix)', 7: 'Corticospinal tract R', 8: 'Corticospinal tract L', 9: 'Medial lemniscus R', 10: 'Medial lemniscus L', 11: 'Inferior cerebellar peduncle R  ', 12: 'Inferior cerebellar peduncle L', 13: 'Superior cerebellar peduncle R', 14: 'Superior cerebellar peduncle L', 15: 'Cerebral peduncle R', 16: 'Cerebral peduncle L', 17: 'Anterior limb of internal capsule R', 18: 'Anterior limb of internal capsule L', 19: 'Posterior limb of internal capsule R', 20: 'Posterior limb of internal capsule L', 21: 'Retrolenticular part of internal capsule R', 22: 'Retrolenticular part of internal capsule L', 23: 'Anterior corona radiata R', 24: 'Anterior corona radiata L', 25: 'Superior corona radiata R', 26: 'Superior corona radiata L', 27: 'Posterior corona radiata R', 28: 'Posterior corona radiata L', 29: 'Posterior thalamic radiation (include optic radiation) R', 30: 'Posterior thalamic radiation (include optic radiation) L', 31: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R', 32: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L', 33: 'External capsule R', 34: 'External capsule L', 35: 'Cingulum (cingulate gyrus) R', 36: 'Cingulum (cingulate gyrus) L', 37: 'Cingulum (hippocampus) R', 38: 'Cingulum (hippocampus) L', 39: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R', 40: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L', 41: 'Superior longitudinal fasciculus R', 42: 'Superior longitudinal fasciculus L', 43: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R', 44: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L', 45: 'Uncinate fasciculus R', 46: 'Uncinate fasciculus L', 47: 'Tapetum R', 48: 'Tapetum L'}
# groups ['HO', 'HT', 'NC']
# Standard deviation of label Pontine crossing tract (a part of MCP): 4.76675811479e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.7657782617e-05
# Region: Pontine crossing tract (a part of MCP)
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.71043363001e-05
# 0.297037066067
# 0.687676894142
# 0.320177670057
# Standard deviation of label Genu of corpus callosum: 6.2583468408e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.14957749142e-05
# Region: Genu of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.88195620451e-05
# 0.994162343719
# 0.638251719207
# 0.531328724935
# Standard deviation of label Body of corpus callosum: 5.69409989552e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.62495565765e-05
# Region: Body of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.34245142392e-05
# 0.726564560712
# 0.396626730455
# 0.488133745779
# Standard deviation of label Splenium of corpus callosum: 5.95320073696e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.94266561009e-05
# Region: Splenium of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.71596831608e-05
# 0.381889510513
# 0.850928117166
# 0.306919476824
# Standard deviation of label Fornix (column and body of fornix): 0.000419463874557
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000410032979679
# Region: Fornix (column and body of fornix)
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000375923673239
# 0.370225527621
# 0.991443495312
# 0.213755879805
# Standard deviation of label Corticospinal tract R: 3.86418373319e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.85665095215e-05
# Region: Corticospinal tract R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.84829856346e-05
# 0.109290273458
# 0.292180601482
# 0.505884252164
# Standard deviation of label Corticospinal tract L: 5.84374404013e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.84213218781e-05
# Region: Corticospinal tract L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.83905696028e-05
# 0.0507020586694
# 0.473341567601
# 0.0786698747396
# Standard deviation of label Superior cerebellar peduncle L: 4.44788187698e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.41684569945e-05
# Region: Superior cerebellar peduncle L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.41405920215e-05
# 0.176108334699
# 0.367757315254
# 0.598864237011
# Standard deviation of label Cerebral peduncle R: 4.22286307483e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.1629473338e-05
# Region: Cerebral peduncle R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.15135743547e-05
# 0.0567314634886
# 0.989737448379
# 0.0129580857038
# Standard deviation of label Cerebral peduncle L: 8.36224178522e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 8.27115114859e-05
# Region: Cerebral peduncle L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 8.25810485858e-05
# 0.11315805883
# 0.988295735257
# 0.0305219246446
# Standard deviation of label Anterior limb of internal capsule R: 4.9442558955e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.87660443165e-05
# Region: Anterior limb of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.75392080297e-05
# 0.901215452238
# 0.843999083825
# 0.655060106456
# Standard deviation of label Anterior limb of internal capsule L: 5.26784791703e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.231503777e-05
# Region: Anterior limb of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.15850377753e-05
# 0.401912555393
# 0.756058061676
# 0.466819928884
# Standard deviation of label Posterior limb of internal capsule R: 4.31608270316e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.2654882237e-05
# Region: Posterior limb of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.25896453953e-05
# 0.0284371701767
# 0.121952070486
# 0.363400141825
# Standard deviation of label Posterior limb of internal capsule L: 5.07457361107e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.07328354983e-05
# Region: Posterior limb of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.07030402046e-05
# 0.0380515773204
# 0.117627592474
# 0.583222914255
# Standard deviation of label Retrolenticular part of internal capsule R: 4.39518462456e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.37777262099e-05
# Region: Retrolenticular part of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.34145059716e-05
# 0.000706125637416
# 0.0318679561942
# 0.0793284588699
# Standard deviation of label Retrolenticular part of internal capsule L: 4.19079304515e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.18946587385e-05
# Region: Retrolenticular part of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.11959846999e-05
# 0.0130420546676
# 0.0343266696628
# 0.827209979193
# Standard deviation of label Anterior corona radiata R: 4.74750434694e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.71155901101e-05
# Region: Anterior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.41344572987e-05
# 0.185750790408
# 0.116579526789
# 0.819138318648
# Standard deviation of label Anterior corona radiata L: 4.6469869909e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.60500472825e-05
# Region: Anterior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.30507481931e-05
# 0.0483528164781
# 0.0575622372357
# 0.893911432785
# Standard deviation of label Superior corona radiata R: 3.82532329911e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.81083516076e-05
# Region: Superior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.74744364136e-05
# 0.0255374001213
# 0.063920909882
# 0.416791192208
# Standard deviation of label Superior corona radiata L: 3.81824792195e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.78436129142e-05
# Region: Superior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.63403441415e-05
# 0.056281287203
# 0.0152347757062
# 0.515971955433
# Standard deviation of label Posterior corona radiata R: 5.10108267453e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.06889243583e-05
# Region: Posterior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.93358354472e-05
# 0.006407303668
# 0.035991787132
# 0.194242027032
# Standard deviation of label Posterior corona radiata L: 4.68781434174e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.67301034739e-05
# Region: Posterior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.42928165963e-05
# 0.0308721032527
# 0.139787290779
# 0.30316683052
# Standard deviation of label Posterior thalamic radiation (include optic radiation) R: 5.5060833539e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.49867109523e-05
# Region: Posterior thalamic radiation (include optic radiation) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.46577458995e-05
# 0.000741713867648
# 0.0126908364693
# 0.0792279701175
# Standard deviation of label Posterior thalamic radiation (include optic radiation) L: 5.6277959297e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.59803381882e-05
# Region: Posterior thalamic radiation (include optic radiation) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.47034332526e-05
# 0.00674606364314
# 0.0223542763432
# 0.540529778905
# Standard deviation of label Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R: 4.73128254933e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.63895690055e-05
# Region: Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.53842313969e-05
# 0.00165292618649
# 0.0124783171646
# 0.255511819391
# Standard deviation of label Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L: 4.71364972244e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.64697256401e-05
# Region: Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.54011050114e-05
# 0.000730223525709
# 0.0350309231936
# 0.0873618834166
# Standard deviation of label External capsule R: 5.49949381715e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.44545180618e-05
# Region: External capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.24043290232e-05
# 0.0303495320598
# 0.3506717381
# 0.0364280534431
# Standard deviation of label External capsule L: 4.95124150927e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.93892785368e-05
# Region: External capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.66279791496e-05
# 0.0463139996063
# 0.167905448982
# 0.332076717873
# Standard deviation of label Cingulum (cingulate gyrus) R: 3.97841620768e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.93643648187e-05
# Region: Cingulum (cingulate gyrus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.89481698039e-05
# 0.0697633922597
# 0.0120046379515
# 0.429877799664
# Standard deviation of label Cingulum (cingulate gyrus) L: 3.84353187332e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.83424545485e-05
# Region: Cingulum (cingulate gyrus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.81177290445e-05
# 0.0358609785554
# 0.0414481665193
# 0.8873104754
# Standard deviation of label Cingulum (hippocampus) R: 7.54376541947e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.53756816856e-05
# Region: Cingulum (hippocampus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.52899814918e-05
# 0.0138670021743
# 0.2140494463
# 0.0605522533605
# Standard deviation of label Cingulum (hippocampus) L: 6.55823521098e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.52566971919e-05
# Region: Cingulum (hippocampus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.50518496549e-05
# 0.0445639912131
# 0.0173642565644
# 0.624483565814
# Standard deviation of label Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R: 6.17654000036e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.07211927461e-05
# Region: Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.95238980098e-05
# 0.527840350823
# 0.659784260021
# 0.146620790891
# Standard deviation of label Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L: 5.50964831231e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.4993428307e-05
# Region: Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.4448365649e-05
# 0.231407682913
# 0.445336075527
# 0.633146006907
# Standard deviation of label Superior longitudinal fasciculus R: 3.58999026129e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.58922600699e-05
# Region: Superior longitudinal fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.56490692033e-05
# 0.0124146830108
# 0.0214764303081
# 0.658763407729
# Standard deviation of label Superior longitudinal fasciculus L: 3.48221391751e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.47214201505e-05
# Region: Superior longitudinal fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.38395109212e-05
# 0.0152435063629
# 0.0147879704748
# 0.774882268768
# Standard deviation of label Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R: 5.83355737885e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.80729581264e-05
# Region: Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.73566498939e-05
# 0.0403318000606
# 0.14359053028
# 0.263446789046
# Standard deviation of label Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L: 6.43527888923e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.39052776513e-05
# Region: Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.34771133346e-05
# 0.580374332639
# 0.455619778725
# 0.775554712052
# Standard deviation of label Uncinate fasciculus R: 3.49154582883e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.46708714129e-05
# Region: Uncinate fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.43528844306e-05
# 0.098896450901
# 0.293728337851
# 0.243260795261
# Standard deviation of label Uncinate fasciculus L: 6.24530462923e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.18950026458e-05
# Region: Uncinate fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.17533810258e-05
# 0.714711470236
# 0.553371607943
# 0.0845173206692
# Standard deviation of label Tapetum R: 0.000116205958565
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000115812151633
# Region: Tapetum R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000112401776069
# 0.0314528746604
# 0.0952186774485
# 0.380738160667
# Standard deviation of label Tapetum L: 0.000168711763914
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000168087063692
# Region: Tapetum L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000159798266916
# 0.517828716382
# 0.787247234943
# 0.607631494651

# %%
res.to_excel('/tmp/MD-labels-BSC-full-HOHTNC_wo_E2.xls')

# %%
res
# Out:
#                                              roi_name  (HO, HT)  (HO, NC)  \
# 0              Pontine crossing tract (a part of MCP)  0.297037  0.687677
# 1                             Genu of corpus callosum  0.994162  0.638252
# 2                             Body of corpus callosum  0.726565  0.396627
# 3                         Splenium of corpus callosum  0.381890  0.850928
# 4                  Fornix (column and body of fornix)  0.370226  0.991443
# 5                               Corticospinal tract R  0.109290  0.292181
# 6                               Corticospinal tract L  0.050702  0.473342
# 7                      Superior cerebellar peduncle L  0.176108  0.367757
# 8                                 Cerebral peduncle R  0.056731  0.989737
# 9                                 Cerebral peduncle L  0.113158  0.988296
# 10                Anterior limb of internal capsule R  0.901215  0.843999
# 11                Anterior limb of internal capsule L  0.401913  0.756058
# 12               Posterior limb of internal capsule R  0.028437  0.121952
# 13               Posterior limb of internal capsule L  0.038052  0.117628
# 14         Retrolenticular part of internal capsule R  0.000706  0.031868
# 15         Retrolenticular part of internal capsule L  0.013042  0.034327
# 16                          Anterior corona radiata R  0.185751  0.116580
# 17                          Anterior corona radiata L  0.048353  0.057562
# 18                          Superior corona radiata R  0.025537  0.063921
# 19                          Superior corona radiata L  0.056281  0.015235
# 20                         Posterior corona radiata R  0.006407  0.035992
# 21                         Posterior corona radiata L  0.030872  0.139787
# 22  Posterior thalamic radiation (include optic ra...  0.000742  0.012691
# 23  Posterior thalamic radiation (include optic ra...  0.006746  0.022354
# 24  Sagittal stratum (include inferior longitidina...  0.001653  0.012478
# 25  Sagittal stratum (include inferior longitidina...  0.000730  0.035031
# 26                                 External capsule R  0.030350  0.350672
# 27                                 External capsule L  0.046314  0.167905
# 28                       Cingulum (cingulate gyrus) R  0.069763  0.012005
# 29                       Cingulum (cingulate gyrus) L  0.035861  0.041448
# 30                           Cingulum (hippocampus) R  0.013867  0.214049
# 31                           Cingulum (hippocampus) L  0.044564  0.017364
# 32  Fornix (cres) / Stria terminalis (can not be r...  0.527840  0.659784
# 33  Fornix (cres) / Stria terminalis (can not be r...  0.231408  0.445336
# 34                 Superior longitudinal fasciculus R  0.012415  0.021476
# 35                 Superior longitudinal fasciculus L  0.015244  0.014788
# 36  Superior fronto-occipital fasciculus (could be...  0.040332  0.143591
# 37  Superior fronto-occipital fasciculus (could be...  0.580374  0.455620
# 38                              Uncinate fasciculus R  0.098896  0.293728
# 39                              Uncinate fasciculus L  0.714711  0.553372
# 40                                          Tapetum R  0.031453  0.095219
# 41                                          Tapetum L  0.517829  0.787247
#
#     (HT, NC)
# 0   0.320178
# 1   0.531329
# 2   0.488134
# 3   0.306919
# 4   0.213756
# 5   0.505884
# 6   0.078670
# 7   0.598864
# 8   0.012958
# 9   0.030522
# 10  0.655060
# 11  0.466820
# 12  0.363400
# 13  0.583223
# 14  0.079328
# 15  0.827210
# 16  0.819138
# 17  0.893911
# 18  0.416791
# 19  0.515972
# 20  0.194242
# 21  0.303167
# 22  0.079228
# 23  0.540530
# 24  0.255512
# 25  0.087362
# 26  0.036428
# 27  0.332077
# 28  0.429878
# 29  0.887310
# 30  0.060552
# 31  0.624484
# 32  0.146621
# 33  0.633146
# 34  0.658763
# 35  0.774882
# 36  0.263447
# 37  0.775555
# 38  0.243261
# 39  0.084517
# 40  0.380738
# 41  0.607631
