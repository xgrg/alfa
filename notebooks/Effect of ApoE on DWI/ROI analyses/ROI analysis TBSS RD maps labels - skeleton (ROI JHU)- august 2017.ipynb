# %% [raw]
# This plots ROI values extracted from images that have been normalized using DARTEL,
# but the values have been extracted from ROI derived from a prior analysis done using images normalized using DARTEL.

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py
# Out:
# /home/grg/jupyter/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/grg/jupyter/local/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# This collect the values from \*\_stats.csv files, i.e. values that have been extracted from ROI manually drawn in MNI space.
# The bad thing with this is that the ROI is defined in a reference space. This is subject to individual registration errors.

# %%
regions = range(2, 49)
for x in [9,10,11,12,13]:
    regions.remove(x)

#regions = [17,18,19,20]
names = {1: 'Middle cerebellar peduncle',
 2: 'Pontine crossing tract (a part of MCP)',
 3: 'Genu of corpus callosum',
 4: 'Body of corpus callosum',
 5: 'Splenium of corpus callosum',
 6: 'Fornix (column and body of fornix)',
 7: 'Corticospinal tract R',
 8: 'Corticospinal tract L',
 9: 'Medial lemniscus R',
 10: 'Medial lemniscus L',
 11: 'Inferior cerebellar peduncle R  ',
 12: 'Inferior cerebellar peduncle L',
 13: 'Superior cerebellar peduncle R',
 14: 'Superior cerebellar peduncle L',
 15: 'Cerebral peduncle R',
 16: 'Cerebral peduncle L',
 17: 'Anterior limb of internal capsule R',
 18: 'Anterior limb of internal capsule L',
 19: 'Posterior limb of internal capsule R',
 20: 'Posterior limb of internal capsule L',
 21: 'Retrolenticular part of internal capsule R',
 22: 'Retrolenticular part of internal capsule L',
 23: 'Anterior corona radiata R',
 24: 'Anterior corona radiata L',
 25: 'Superior corona radiata R',
 26: 'Superior corona radiata L',
 27: 'Posterior corona radiata R',
 28: 'Posterior corona radiata L',
 29: 'Posterior thalamic radiation (include optic radiation) R',
 30: 'Posterior thalamic radiation (include optic radiation) L',
 31: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R',
 32: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L',
 33: 'External capsule R',
 34: 'External capsule L',
 35: 'Cingulum (cingulate gyrus) R',
 36: 'Cingulum (cingulate gyrus) L',
 37: 'Cingulum (hippocampus) R',
 38: 'Cingulum (hippocampus) L',
 39: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R',
 40: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L',
 41: 'Superior longitudinal fasciculus R',
 42: 'Superior longitudinal fasciculus L',
 43: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R',
 44: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L',
 45: 'Uncinate fasciculus R',
 46: 'Uncinate fasciculus L',
 47: 'Tapetum R',
 48: 'Tapetum L'}

data = pd.read_excel('/home/grg/spm/data/covariates.xls')
data = data.set_index(data['subject'])
data = data.sort_values(['apo', 'subject'])
src = '/home/grg/tbss_bsc_subjects/roivalues_labels_tbss_RD_skel/'
filepattern = '*_stats.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]


#data.join(values)
#poly = ols(formula='roi ~ 1 + age', data=data.join(values)).fit()
res = plot_regions(data, regions, csvfiles, subjects, groups=['HO','HT','NC'], by='apo', names=names,ylim=[0.0005,0.0010])
# Out:
# {1: 'Middle cerebellar peduncle', 2: 'Pontine crossing tract (a part of MCP)', 3: 'Genu of corpus callosum', 4: 'Body of corpus callosum', 5: 'Splenium of corpus callosum', 6: 'Fornix (column and body of fornix)', 7: 'Corticospinal tract R', 8: 'Corticospinal tract L', 9: 'Medial lemniscus R', 10: 'Medial lemniscus L', 11: 'Inferior cerebellar peduncle R  ', 12: 'Inferior cerebellar peduncle L', 13: 'Superior cerebellar peduncle R', 14: 'Superior cerebellar peduncle L', 15: 'Cerebral peduncle R', 16: 'Cerebral peduncle L', 17: 'Anterior limb of internal capsule R', 18: 'Anterior limb of internal capsule L', 19: 'Posterior limb of internal capsule R', 20: 'Posterior limb of internal capsule L', 21: 'Retrolenticular part of internal capsule R', 22: 'Retrolenticular part of internal capsule L', 23: 'Anterior corona radiata R', 24: 'Anterior corona radiata L', 25: 'Superior corona radiata R', 26: 'Superior corona radiata L', 27: 'Posterior corona radiata R', 28: 'Posterior corona radiata L', 29: 'Posterior thalamic radiation (include optic radiation) R', 30: 'Posterior thalamic radiation (include optic radiation) L', 31: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R', 32: 'Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L', 33: 'External capsule R', 34: 'External capsule L', 35: 'Cingulum (cingulate gyrus) R', 36: 'Cingulum (cingulate gyrus) L', 37: 'Cingulum (hippocampus) R', 38: 'Cingulum (hippocampus) L', 39: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R', 40: 'Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L', 41: 'Superior longitudinal fasciculus R', 42: 'Superior longitudinal fasciculus L', 43: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R', 44: 'Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L', 45: 'Uncinate fasciculus R', 46: 'Uncinate fasciculus L', 47: 'Tapetum R', 48: 'Tapetum L'}
# groups ['HO', 'HT', 'NC']
# Standard deviation of label Pontine crossing tract (a part of MCP): 4.42866707163e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.42299023097e-05
# Region: Pontine crossing tract (a part of MCP)
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.37919647277e-05
# 0.307834170207
# 0.627194072253
# 0.416252502018
# Standard deviation of label Genu of corpus callosum: 6.25010000272e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.25008046164e-05
# Region: Genu of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.91237115065e-05
# 0.287187021398
# 0.069076408587
# 0.332760861061
# Standard deviation of label Body of corpus callosum: 6.30103197295e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.29927178219e-05
# Region: Body of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.92528707822e-05
# 0.495569771736
# 0.144621853576
# 0.256240930312
# Standard deviation of label Splenium of corpus callosum: 6.00680236603e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.84147937247e-05
# Region: Splenium of corpus callosum
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.68754472886e-05
# 0.245679438956
# 0.401139907111
# 0.492659556556
# Standard deviation of label Fornix (column and body of fornix): 0.000446479640431
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000439651397608
# Region: Fornix (column and body of fornix)
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.00039757454574
# 0.349637062895
# 0.963549526403
# 0.206526167205
# Standard deviation of label Corticospinal tract R: 3.51937151057e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.50347327674e-05
# Region: Corticospinal tract R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.50313813731e-05
# 0.405429113559
# 0.312275156573
# 0.725500224471
# Standard deviation of label Corticospinal tract L: 4.86484251616e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.86128184181e-05
# Region: Corticospinal tract L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.85730730102e-05
# 0.187609672997
# 0.498259301803
# 0.382072677977
# Standard deviation of label Superior cerebellar peduncle L: 4.23226265035e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.21282397134e-05
# Region: Superior cerebellar peduncle L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.19803523925e-05
# 0.0984397850026
# 0.27961743288
# 0.616332658394
# Standard deviation of label Cerebral peduncle R: 3.79854725555e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.79297671379e-05
# Region: Cerebral peduncle R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.75660834702e-05
# 0.0933391725994
# 0.769169324721
# 0.0643794816438
# Standard deviation of label Cerebral peduncle L: 5.54347611854e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.51254112867e-05
# Region: Cerebral peduncle L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.48429605171e-05
# 0.0138657625932
# 0.320860161811
# 0.0534846594227
# Standard deviation of label Anterior limb of internal capsule R: 4.83055975395e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.8047798703e-05
# Region: Anterior limb of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.68922428963e-05
# 0.735747134352
# 0.735956028252
# 0.968098160062
# Standard deviation of label Anterior limb of internal capsule L: 4.92505914312e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.92504549991e-05
# Region: Anterior limb of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.84194717865e-05
# 0.15384350042
# 0.162442099678
# 0.938217532024
# Standard deviation of label Posterior limb of internal capsule R: 4.14928685507e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.14654008959e-05
# Region: Posterior limb of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.14579103204e-05
# 0.0247099668451
# 0.162175137536
# 0.183230700209
# Standard deviation of label Posterior limb of internal capsule L: 4.94148489984e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.93400181765e-05
# Region: Posterior limb of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.90862281568e-05
# 0.0603481796987
# 0.156837049882
# 0.508041181218
# Standard deviation of label Retrolenticular part of internal capsule R: 4.77946038401e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.77760187293e-05
# Region: Retrolenticular part of internal capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.77522638221e-05
# 0.00203083079258
# 0.0644183537024
# 0.0523018539203
# Standard deviation of label Retrolenticular part of internal capsule L: 4.29964993466e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.28878199257e-05
# Region: Retrolenticular part of internal capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.25445631417e-05
# 0.0208278354408
# 0.0695381049054
# 0.606962847045
# Standard deviation of label Anterior corona radiata R: 5.25188798433e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.24034386645e-05
# Region: Anterior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.90264419354e-05
# 0.130742269519
# 0.0518933913013
# 0.632193690263
# Standard deviation of label Anterior corona radiata L: 5.06228764058e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.02477015144e-05
# Region: Anterior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.66357930583e-05
# 0.0603689641518
# 0.0401712209172
# 0.879478533915
# Standard deviation of label Superior corona radiata R: 3.86274683713e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.86216141761e-05
# Region: Superior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.81303705758e-05
# 0.0710869932861
# 0.140084622338
# 0.445500201835
# Standard deviation of label Superior corona radiata L: 3.95103450449e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.94940810966e-05
# Region: Superior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.838932823e-05
# 0.0535330633561
# 0.0259668868231
# 0.799101553893
# Standard deviation of label Posterior corona radiata R: 5.31156636095e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.23957925078e-05
# Region: Posterior corona radiata R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.16855210816e-05
# 0.0064604175193
# 0.0469625559482
# 0.0952625944294
# Standard deviation of label Posterior corona radiata L: 4.78660402114e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.78633928896e-05
# Region: Posterior corona radiata L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.63855827519e-05
# 0.0242034146763
# 0.124787862803
# 0.223875960595
# Standard deviation of label Posterior thalamic radiation (include optic radiation) R: 5.8680141792e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.84282921128e-05
# Region: Posterior thalamic radiation (include optic radiation) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.75534366752e-05
# 0.00373030735523
# 0.0227618711758
# 0.168204129062
# Standard deviation of label Posterior thalamic radiation (include optic radiation) L: 6.08401764067e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.07689338618e-05
# Region: Posterior thalamic radiation (include optic radiation) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.84414032759e-05
# 0.00152322617277
# 0.00561833572394
# 0.573341953587
# Standard deviation of label Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R: 5.2107317345e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.18910600717e-05
# Region: Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.09365538223e-05
# 0.00394395065608
# 0.0182545957408
# 0.294066596016
# Standard deviation of label Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L: 5.05929948848e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.05097408958e-05
# Region: Sagittal stratum (include inferior longitidinal fasciculus and inferior fronto-occipital fasciculus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.97031099335e-05
# 0.00176281545844
# 0.0322835561795
# 0.140798442919
# Standard deviation of label External capsule R: 5.03661426838e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.01651954734e-05
# Region: External capsule R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.78034154544e-05
# 0.0290593342749
# 0.396421895882
# 0.033252813069
# Standard deviation of label External capsule L: 4.78958623874e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.78955573664e-05
# Region: External capsule L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.50349984111e-05
# 0.0675960227146
# 0.391264173741
# 0.140701820629
# Standard deviation of label Cingulum (cingulate gyrus) R: 4.85474721025e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.7129830567e-05
# Region: Cingulum (cingulate gyrus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.60450611188e-05
# 0.0855756355034
# 0.01363501169
# 0.387917474799
# Standard deviation of label Cingulum (cingulate gyrus) L: 5.11591556042e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.99536057706e-05
# Region: Cingulum (cingulate gyrus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.89810044635e-05
# 0.148917540954
# 0.0376697593105
# 0.42032765424
# Standard deviation of label Cingulum (hippocampus) R: 7.70396405828e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.66684149956e-05
# Region: Cingulum (hippocampus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.66313842995e-05
# 0.00725707786009
# 0.329727803145
# 0.0043103240617
# Standard deviation of label Cingulum (hippocampus) L: 6.39487355723e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.33820516754e-05
# Region: Cingulum (hippocampus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.2976379189e-05
# 0.0523809042887
# 0.156949545356
# 0.436415145935
# Standard deviation of label Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R: 5.84335378229e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.80662027452e-05
# Region: Fornix (cres) / Stria terminalis (can not be resolved with current resolution) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.59368827997e-05
# 0.321777604376
# 0.941589649713
# 0.147231800105
# Standard deviation of label Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L: 5.52636595273e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.52523143057e-05
# Region: Fornix (cres) / Stria terminalis (can not be resolved with current resolution) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.41386972712e-05
# 0.462341972969
# 0.574217452415
# 0.882484407766
# Standard deviation of label Superior longitudinal fasciculus R: 4.04945689344e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.03357614783e-05
# Region: Superior longitudinal fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.02159680087e-05
# 0.0108308947278
# 0.0592228284715
# 0.288800205159
# Standard deviation of label Superior longitudinal fasciculus L: 3.9724627009e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.97235511777e-05
# Region: Superior longitudinal fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.89316362205e-05
# 0.0139943684523
# 0.0371298640411
# 0.433386964072
# Standard deviation of label Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R: 5.87495679019e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.86573521542e-05
# Region: Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.79371586201e-05
# 0.146436340729
# 0.196781310586
# 0.62113296449
# Standard deviation of label Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L: 6.59589836168e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.58849803578e-05
# Region: Superior fronto-occipital fasciculus (could be a part of anterior internal capsule) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.50920203328e-05
# 0.31700318303
# 0.309961105351
# 0.987280593441
# Standard deviation of label Uncinate fasciculus R: 3.64893943974e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.64879934201e-05
# Region: Uncinate fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.54554619024e-05
# 0.0403631702715
# 0.323537266021
# 0.0575953482722
# Standard deviation of label Uncinate fasciculus L: 6.82143205207e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.70688513335e-05
# Region: Uncinate fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.67251296395e-05
# 0.831953825006
# 0.483100587451
# 0.10532373311
# Standard deviation of label Tapetum R: 0.000122975025309
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000122813664642
# Region: Tapetum R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000119086658485
# 0.067245814019
# 0.120754438228
# 0.658262824107
# Standard deviation of label Tapetum L: 0.000169258888575
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 0.000168665417882
# Region: Tapetum L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 0.000163305513684
# 0.473388186699
# 0.694557243727
# 0.647116187854

# %%
res.to_excel('/tmp/RD-labels-BSC-full-HOHTNC.xls')
