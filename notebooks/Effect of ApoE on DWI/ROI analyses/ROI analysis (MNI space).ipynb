# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# Out:
# /home/grg/jupyter/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
spmdir = '/home/grg/spm/'
subjects = json.load(open(osp.join(spmdir, 'data', 'subjects.json')))

# %%
def getdict(data, key, column, column2=None, value=None):
    import string
    if not value is None:
        data = data[data[column2] == value]
        
    d1 = dict([(string.atoi(str(int(e))), v) for e, v in data[[key, column]].to_dict(orient='split')['data']])
    return d1

fsvol_fp = osp.join(spmdir, 'data', 'aseg FS ALFA.xlsx')
vvol = pd.read_excel(fsvol_fp)    
d = getdict(vvol, 'subject', 'Volume_mm3', 'StructName', 'Right-Lateral-Ventricle')

# %%
# From AAL V4, load labels - names translation table
labels_fp = '/home/grg/data/templates/MNI_atlas_templates/aal_MNI_V4.txt'
df = pd.read_csv(labels_fp, sep='\t', skiprows=0)
labels = {}
for i in range(1,117):
    labels[i] = json.loads(df.to_json()).items()[0][1][str(i)]

roiname = 'Hippocampus_L'
roilabel = [k for k,v in labels.items() if v == roiname][0]
print roiname, roilabel

def collect_data(verbose=False):
    
    # Loading json data etc..
    spmdir = '/home/grg/spm/'


    # Reading main tables with metadata
    demo_fp = osp.join(spmdir, 'data', 'Data_VBM_Alfa.csv')
    subj_fp= osp.join(spmdir, 'data', 'subjects.json')
    gend_fp= osp.join(spmdir, 'data', 'genders.json')
    educ_fp = osp.join(spmdir, 'data', 'educyears.json')
    tiv_fp = osp.join(spmdir, 'data', 'tiv.json')
    fsvol_fp = osp.join(spmdir, 'data', 'aseg FS ALFA.xlsx')
    ages_fp = osp.join(spmdir, 'data', 'age.json') # contains ages in days

    demo = pd.read_csv(demo_fp)
    subjects = json.load(open(subj_fp))
    print len(subjects)
    groups_size = [102, 44, 143, 160, 65]
    assert(sum(groups_size) == len(subjects))

    # Sorting out groups
    groups = []
    start = 0
    for size in groups_size:
        g = subjects[start:start + size]
        start = start + size
        groups.append(g)

    ages = json.load(open(ages_fp))
    genders = json.load(open(gend_fp))
    educyears = json.load(open(educ_fp))
    tivs = json.load(open(tiv_fp))
    vvol = pd.read_excel(fsvol_fp)    
    
    # FreeSurfer Volumes
    vvol_l = getdict(vvol, 'subject', 'Volume_mm3', 'StructName', 'Left-Lateral-Ventricle')
    vvol_r = getdict(vvol, 'subject', 'Volume_mm3', 'StructName', 'Right-Lateral-Ventricle')
    vvol_li = getdict(vvol, 'subject', 'Volume_mm3', 'StructName','Left-Inf-Lat-Vent')
    vvol_ri = getdict(vvol, 'subject', 'Volume_mm3', 'StructName','Right-Inf-Lat-Vent')
    vvol_3 = getdict(vvol, 'subject', 'Volume_mm3', 'StructName','3rd-Ventricle')
    vvol_4 = getdict(vvol, 'subject', 'Volume_mm3', 'StructName', '4th-Ventricle')    
    
    # Building dataframe
    data = []
    subj = []
    for s in subjects:    
        if verbose: print s
        group = [int(s in each) for each in groups]
        group_nb = group.index(1)
        row = []
        try:
            fsvol_l = (vvol_l[s] + vvol_li[s]) / tivs[str(s)]
            fsvol_r = (vvol_r[s] + vvol_ri[s]) / tivs[str(s)]
            fsvol = fsvol_l + fsvol_r
            age = ages[str(s)]
            row.append(group_nb)
            row.extend([age/365.25, genders[str(s)], educyears[str(s)], fsvol])            
            subj.append(s)
            data.append(row)
        except KeyError as e:
            print e
        except IndexError as e:
            print e
            print 'removed', s
            
    columns=['apo', 'age', 'gender', 'educyears', 'ventricles']
    return pd.DataFrame(data, index=subj, columns=columns)

data = collect_data()
#data.to_excel('/home/grg/spm/data/covariates.xls')
# Out:
# Hippocampus_L 37
# 514

# %%
def collect_roivalues(roilabel, verbose=False):
    ''' This collect the values from *_AAL_MD_stats.csv files, that is 
    MD mean values in every subject's NATIVE space.
    '''
    
    subjects  = json.load(open('/home/grg/spm/data/subjects.json'))
    data_wd = '/home/grg/data/ALFA_DWI'
    
    data = []
    subj = []
    
    for s in subjects:    
        fp = '/home/grg/spm/ROIapoE/ROI_ANTs/roivalues/%s_stats.csv'%s
        if verbose:
            print s, fp
        df = pd.read_csv(fp, sep='\t').set_index('ROI_label')   
        try:
            data.append(df.ix[roilabel]['mean'])            
            subj.append(s)            
        except KeyError as e:
            print 'KeyError: skipped subject', s, 'label', e
        except IndexError as e:
            print 'IndexError: skipped subject', s, 'label', e
    return pd.DataFrame(data, index=subj, columns=['roi'])

# %%
def correct(df):
    model = 'roi ~ 1 + C(apo) + gender + educyears + ventricles'
    test_scores = ols(model, data=df).fit()
    
    err = test_scores.predict(df) - df['roi']
    ycorr = np.mean(df['roi']) - err   
    
    return ycorr

# Loading, joining, dropping etc.
data = pd.read_excel('/home/grg/spm/data/covariates.xls')
#data = data.drop(data[data['ventricles']>30].index)
#roilabel = 1
#roivalues = collect_roivalues(roilabel)
#df = data.join(roivalues)
#df['subject'] = df.index
#df = df.sort_values(['apo', 'subject']).dropna()
#df = df.drop(df[df['ventricles']>30].index)

# Correcting data for covariates
#ycorr = correct(df)
#df = data.join(ycorr)
#df['subject'] = df.index
#df = df.sort_values(['apo', 'subject']).dropna()
#df = df.drop(df[df['ventricles']>30].index)


data.head()
# Out:
#        apo        age  gender  educyears  ventricles
# 10070    0  50.781656       0         10    4.520876
# 10102    0  64.065708       1         18   16.507219
# 10108    0  58.683094       0         15   10.421616
# 10235    0  61.245722       0          8    7.564201
# 10365    0  48.720055       0         12    7.770477

# %%
y_name = 'roi'
x_name = ['apo', 'age', 'gender', 'educyears', 'ventricles']
#test_scores = sm.OLS(np.asarray(df[y_name]), np.asarray(df[x_name])).fit()
model = 'roi ~ 1 + C(apo) + age + gender + educyears + ventricles'
test_scores = ols(model, data=df).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-af98b4c33ed6> in <module>()
#       3 #test_scores = sm.OLS(np.asarray(df[y_name]), np.asarray(df[x_name])).fit()
#       4 model = 'roi ~ 1 + C(apo) + age + gender + educyears + ventricles'
# ----> 5 test_scores = ols(model, data=df).fit()
#
# NameError: name 'df' is not defined

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

def set_figaxes(df):
    plt.xlabel('age')
    plt.ylabel('roi')
    plt.ylim([0.0005, df['roi'].max()])
    plt.xlim([df['age'].min(), df['age'].max()])

def plot_region(roiname, dataset, order=1, ax=None):
    if ax == None:
        fig = plt.figure(figsize=(6, 6))
        set_figaxes(dataset)
        ax = fig.add_subplot(111)

    colors = ['b','r','g','m','y']
    formulas = ['roi ~ 1 + age', 
                'roi ~ 1 + age + I(age**2)', 
                'roi ~ 1 + age + I(age**2) + I(age**3)']
    print 'Region:', roiname, '- Fitting order:', order, '- Formula:', formulas[order-1]
    
    # take each group separately  
    groups_names = ['apoe23', 'apoe24', 'apoe33', 'apoe34', 'apoe44']
    groups1 = []
    for i in xrange(5):
        groups1.append(dataset[dataset['apo'] == i])
    groups = []
    groups_names = ['HO', 'All']
    groups.append(pd.concat([groups1[i] for i in [4]]))
    groups.append(pd.concat([groups1[i] for i in [0,1,2,3]]))
        
    for i, df in enumerate(groups):
        ax.scatter(df['age'], df['roi'], edgecolors=colors[i], facecolors='none', 
                   label='%s'%groups_names[i].capitalize(), s=10, alpha=0.7)
        x = pd.DataFrame({'age': np.linspace(df['age'].min(), df['age'].max(), 100)})
        
        poly = ols(formula=formulas[order-1], data=df).fit()
        ypred = poly.predict(x)
        #print np.std(ypred)
        ax.plot(x['age'], ypred, colors[i]+'-', 
                label='%s n=%s $R^2$=%.3f $AIC$=%.2f $\sigma$=%.3e' 
                % (groups_names[i].capitalize(), order, poly.rsquared, poly.aic, np.std(ypred)), 
                alpha=1.0)

    ax.legend(prop={'size':8})
    ax.text(0.15, 0.95, roiname, horizontalalignment='center', verticalalignment='center', transform = ax.transAxes)
    plt.title(roiname)

# %%
def plot_regions(data, regions, nb_orders=3):
    nb_regions = len(regions)
    fig = plt.figure(figsize=(8*nb_orders, 8*nb_regions), dpi=300, facecolor='white')
    
    for i, roilabel in enumerate(regions):
        labels = ['coronaradiata', 'thalamus_R', 'orb_L', 'orb_R', 'hypothal_R', 'pons', 'thalamus_L', 'hypothal_L', 'unknown']
        roiname = '%s'%labels[roilabel-1]
        # 1-st order
        ax = fig.add_subplot(nb_regions, nb_orders, nb_orders*i + 1)
        roivalues = collect_roivalues(roilabel)
        df = data.join(roivalues)
        print np.std(df['roi'])
        ycorr = pd.DataFrame(correct(df), columns=['roi'])
        df = data.join(ycorr)
        df['subject'] = df.index
        df = df.sort_values(['apo', 'subject']).dropna()
    
        set_figaxes(df)
        print np.std(df['roi'])
        plot_region(roiname, df, order=1, ax=ax)

        # 2-nd order
        ax = fig.add_subplot(nb_regions, nb_orders, nb_orders*i + 2)
        roivalues = collect_roivalues(roilabel)
        df = data.join(roivalues)
        ycorr = pd.DataFrame(correct(df), columns=['roi'])
        df = data.join(ycorr)
        df['subject'] = df.index
        df = df.sort_values(['apo', 'subject']).dropna()
    
        set_figaxes(df)
        plot_region(roiname, df, order=2, ax=ax)

        # 3-rd order
        ax = fig.add_subplot(nb_regions, nb_orders, nb_orders*i + 3)
        roivalues = collect_roivalues(roilabel)
        df = data.join(roivalues)
        ycorr = pd.DataFrame(correct(df), columns=['roi'])
        df = data.join(ycorr)
        df['subject'] = df.index
        df = df.sort_values(['apo', 'subject']).dropna()
    
        set_figaxes(df)
        plot_region(roiname, df, order=3, ax=ax)

# %% [markdown]
# This collect the values from \*\_stats.csv files, i.e. values that have been extracted from ROI manually drawn in MNI space.
# The bad thing with this is that the ROI is defined in a reference space. This is subject to individual registration errors.

# %%
       
regions = [1,2,3,4,5,6,7,8]
plot_regions(data, regions)

#plot_regions(data, [71,72])
# Out:
# 8.16536651573e-05
# 6.98119134648e-05
# Region: coronaradiata - Fitting order: 1 - Formula: roi ~ 1 + age
# Region: coronaradiata - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Region: coronaradiata - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# 0.000323268833129
# 0.000289904193463
# Region: thalamus_R - Fitting order: 1 - Formula: roi ~ 1 + age
# Region: thalamus_R - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Region: thalamus_R - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# 0.00035250562215
# 0.000341113818495
# Region: orb_L - Fitting order: 1 - Formula: roi ~ 1 + age
# Region: orb_L - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Region: orb_L - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# 0.00027173288253
# 0.00026578634504
# Region: orb_R - Fitting order: 1 - Formula: roi ~ 1 + age
# Region: orb_R - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Region: orb_R - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# 0.00060863671585
# 0.000551459535681
# Region: hypothal_R - Fitting order: 1 - Formula: roi ~ 1 + age
# Region: hypothal_R - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Region: hypothal_R - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# 0.000268239746029
# 0.000253994776647
# Region: pons - Fitting order: 1 - Formula: roi ~ 1 + age
# Region: pons - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Region: pons - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# 0.000222097959003
# 0.000210740604869
# Region: thalamus_L - Fitting order: 1 - Formula: roi ~ 1 + age
# Region: thalamus_L - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Region: thalamus_L - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# 0.000563131059056
# 0.000515752248891
# Region: hypothal_L - Fitting order: 1 - Formula: roi ~ 1 + age
# Region: hypothal_L - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Region: hypothal_L - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)

# %%
import plotly
#plotly.init_notebook_mode()

def plotly_region(roilabel):
    to_remove = [55166, 66159, 77068, 10182, 13059, 66019, 66264, 77024, 77263,
            10846, 66026, 66039, 66131, 66368, 77027, 77047]
    data = collect_data()
    roivalues = collect_roivalues(roilabel)
    #data = data[data['apo']==0]
    df = data.join(roivalues)
    df['subject'] = df.index
    df = df.drop(to_remove)
    
    
    import plotly.plotly as py
    import plotly.graph_objs as go

    #data = [trace]

    # Plot and embed in ipython notebook!
    #

    trace = go.Scatter3d(
        x = df['age'],
        y = df['roi'],
        z = df['ventricles'],
        marker=dict(
            size='4',
            color = df['apo'], #set color equal to a variable
            colorscale='Jet',
            showscale=True),
        text = df['subject'],
        mode = 'markers'
    )

    data = [trace]

    # Plot and embed in ipython notebook!
    py.iplot(data)
    # or plot with: plot_url = py.plot(data, filename='basic-line')

# %%
plotly_region(1)
# Out:
# 514

# %%
data = collect_data()
roivalues = collect_roivalues(roilabel)
#data = data[data['apo']==0]
df = data.join(roivalues)
df['subject'] = df.index


import plotly.plotly as py
import plotly.graph_objs as go

#data = [trace]

# Plot and embed in ipython notebook!
#

trace = go.Scatter(
    x = df['age'],
    y = df['ventricles'],
    
    marker=dict(
        size='4',
        color = df['gender'], #set color equal to a variable
        colorscale='Jet',
        showscale=True),
    text = df['subject'],
    mode = 'markers'
)

data = [trace]

# Plot and embed in ipython notebook!
py.iplot(data)
# Out:
# 514
# KeyError: skipped subject 10070 label 37
# KeyError: skipped subject 10102 label 37
# KeyError: skipped subject 10108 label 37
# KeyError: skipped subject 10235 label 37
# KeyError: skipped subject 10365 label 37
# KeyError: skipped subject 10419 label 37
# KeyError: skipped subject 10463 label 37
# KeyError: skipped subject 10530 label 37
# KeyError: skipped subject 10551 label 37
# KeyError: skipped subject 10563 label 37
# KeyError: skipped subject 10576 label 37
# KeyError: skipped subject 10630 label 37
# KeyError: skipped subject 10668 label 37
# KeyError: skipped subject 10692 label 37
# KeyError: skipped subject 10693 label 37
# KeyError: skipped subject 10703 label 37
# KeyError: skipped subject 10725 label 37
# KeyError: skipped subject 10737 label 37
# KeyError: skipped subject 10756 label 37
# KeyError: skipped subject 10809 label 37
# KeyError: skipped subject 11045 label 37
# KeyError: skipped subject 11047 label 37
# KeyError: skipped subject 11048 label 37
# KeyError: skipped subject 11133 label 37
# KeyError: skipped subject 11180 label 37
# KeyError: skipped subject 11225 label 37
# KeyError: skipped subject 11262 label 37
# KeyError: skipped subject 11305 label 37
# KeyError: skipped subject 11351 label 37
# KeyError: skipped subject 11360 label 37
# KeyError: skipped subject 11387 label 37
# KeyError: skipped subject 11407 label 37
# KeyError: skipped subject 11414 label 37
# KeyError: skipped subject 11416 label 37
# KeyError: skipped subject 11550 label 37
# KeyError: skipped subject 11610 label 37
# KeyError: skipped subject 11614 label 37
# KeyError: skipped subject 11638 label 37
# KeyError: skipped subject 11658 label 37
# KeyError: skipped subject 11691 label 37
# KeyError: skipped subject 11721 label 37
# KeyError: skipped subject 11737 label 37
# KeyError: skipped subject 11768 label 37
# KeyError: skipped subject 11798 label 37
# KeyError: skipped subject 11803 label 37
# KeyError: skipped subject 11858 label 37
# KeyError: skipped subject 11902 label 37
# KeyError: skipped subject 11941 label 37
# KeyError: skipped subject 11975 label 37
# KeyError: skipped subject 11979 label 37
# KeyError: skipped subject 12032 label 37
# KeyError: skipped subject 12067 label 37
# KeyError: skipped subject 12079 label 37
# KeyError: skipped subject 12121 label 37
# KeyError: skipped subject 12140 label 37
# KeyError: skipped subject 12174 label 37
# KeyError: skipped subject 12244 label 37
# KeyError: skipped subject 12252 label 37
# KeyError: skipped subject 12323 label 37
# KeyError: skipped subject 12324 label 37
# KeyError: skipped subject 12331 label 37
# KeyError: skipped subject 12399 label 37
# KeyError: skipped subject 12425 label 37
# KeyError: skipped subject 12445 label 37
# KeyError: skipped subject 12479 label 37
# KeyError: skipped subject 12484 label 37
# KeyError: skipped subject 12493 label 37
# KeyError: skipped subject 12516 label 37
# KeyError: skipped subject 12637 label 37
# KeyError: skipped subject 12659 label 37
# KeyError: skipped subject 12730 label 37
# KeyError: skipped subject 12783 label 37
# KeyError: skipped subject 12787 label 37
# KeyError: skipped subject 12841 label 37
# KeyError: skipped subject 12920 label 37
# KeyError: skipped subject 12970 label 37
# KeyError: skipped subject 12976 label 37
# KeyError: skipped subject 13008 label 37
# KeyError: skipped subject 13035 label 37
# KeyError: skipped subject 13075 label 37
# KeyError: skipped subject 13090 label 37
# KeyError: skipped subject 13118 label 37
# KeyError: skipped subject 13138 label 37
# KeyError: skipped subject 13235 label 37
# KeyError: skipped subject 21092 label 37
# KeyError: skipped subject 44046 label 37
# KeyError: skipped subject 44205 label 37
# KeyError: skipped subject 55166 label 37
# KeyError: skipped subject 55529 label 37
# KeyError: skipped subject 55538 label 37
# KeyError: skipped subject 55854 label 37
# KeyError: skipped subject 66089 label 37
# KeyError: skipped subject 66125 label 37
# KeyError: skipped subject 66159 label 37
# KeyError: skipped subject 66239 label 37
# KeyError: skipped subject 66240 label 37
# KeyError: skipped subject 66270 label 37
# KeyError: skipped subject 66312 label 37
# KeyError: skipped subject 77068 label 37
# KeyError: skipped subject 77093 label 37
# KeyError: skipped subject 77094 label 37
# KeyError: skipped subject 77195 label 37
# KeyError: skipped subject 10015 label 37
# KeyError: skipped subject 10041 label 37
# KeyError: skipped subject 10090 label 37
# KeyError: skipped subject 10150 label 37
# KeyError: skipped subject 10282 label 37
# KeyError: skipped subject 10486 label 37
# KeyError: skipped subject 10518 label 37
# KeyError: skipped subject 10536 label 37
# KeyError: skipped subject 10645 label 37
# KeyError: skipped subject 11038 label 37
# KeyError: skipped subject 11144 label 37
# KeyError: skipped subject 11191 label 37
# KeyError: skipped subject 11195 label 37
# KeyError: skipped subject 11252 label 37
# KeyError: skipped subject 11436 label 37
# KeyError: skipped subject 11597 label 37
# KeyError: skipped subject 12015 label 37
# KeyError: skipped subject 12122 label 37
# KeyError: skipped subject 12245 label 37
# KeyError: skipped subject 12417 label 37
# KeyError: skipped subject 12704 label 37
# KeyError: skipped subject 12772 label 37
# KeyError: skipped subject 12930 label 37
# KeyError: skipped subject 13054 label 37
# KeyError: skipped subject 13070 label 37
# KeyError: skipped subject 21002 label 37
# KeyError: skipped subject 21011 label 37
# KeyError: skipped subject 55351 label 37
# KeyError: skipped subject 55353 label 37
# KeyError: skipped subject 55355 label 37
# KeyError: skipped subject 55488 label 37
# KeyError: skipped subject 55539 label 37
# KeyError: skipped subject 55636 label 37
# KeyError: skipped subject 55793 label 37
# KeyError: skipped subject 66020 label 37
# KeyError: skipped subject 66094 label 37
# KeyError: skipped subject 66164 label 37
# KeyError: skipped subject 66341 label 37
# KeyError: skipped subject 66492 label 37
# KeyError: skipped subject 77109 label 37
# KeyError: skipped subject 77152 label 37
# KeyError: skipped subject 77191 label 37
# KeyError: skipped subject 77224 label 37
# KeyError: skipped subject 77241 label 37
# KeyError: skipped subject 10013 label 37
# KeyError: skipped subject 10023 label 37
# KeyError: skipped subject 10024 label 37
# KeyError: skipped subject 10028 label 37
# KeyError: skipped subject 10032 label 37
# KeyError: skipped subject 10036 label 37
# KeyError: skipped subject 10038 label 37
# KeyError: skipped subject 10040 label 37
# KeyError: skipped subject 10042 label 37
# KeyError: skipped subject 10049 label 37
# KeyError: skipped subject 10052 label 37
# KeyError: skipped subject 10053 label 37
# KeyError: skipped subject 10056 label 37
# KeyError: skipped subject 10081 label 37
# KeyError: skipped subject 10117 label 37
# KeyError: skipped subject 10118 label 37
# KeyError: skipped subject 10151 label 37
# KeyError: skipped subject 10156 label 37
# KeyError: skipped subject 10158 label 37
# KeyError: skipped subject 10166 label 37
# KeyError: skipped subject 10170 label 37
# KeyError: skipped subject 10178 label 37
# KeyError: skipped subject 10182 label 37
# KeyError: skipped subject 10199 label 37
# KeyError: skipped subject 10200 label 37
# KeyError: skipped subject 10213 label 37
# KeyError: skipped subject 10217 label 37
# KeyError: skipped subject 10239 label 37
# KeyError: skipped subject 10242 label 37
# KeyError: skipped subject 10245 label 37
# KeyError: skipped subject 10248 label 37
# KeyError: skipped subject 10251 label 37
# KeyError: skipped subject 10253 label 37
# KeyError: skipped subject 10263 label 37
# KeyError: skipped subject 10265 label 37
# KeyError: skipped subject 10308 label 37
# KeyError: skipped subject 10313 label 37
# KeyError: skipped subject 10322 label 37
# KeyError: skipped subject 10325 label 37
# KeyError: skipped subject 10326 label 37
# KeyError: skipped subject 10329 label 37
# KeyError: skipped subject 10330 label 37
# KeyError: skipped subject 10354 label 37
# KeyError: skipped subject 10370 label 37
# KeyError: skipped subject 10385 label 37
# KeyError: skipped subject 10393 label 37
# KeyError: skipped subject 10417 label 37
# KeyError: skipped subject 10426 label 37
# KeyError: skipped subject 10528 label 37
# KeyError: skipped subject 10577 label 37
# KeyError: skipped subject 10678 label 37
# KeyError: skipped subject 10682 label 37
# KeyError: skipped subject 10697 label 37
# KeyError: skipped subject 10724 label 37
# KeyError: skipped subject 10821 label 37
# KeyError: skipped subject 10841 label 37
# KeyError: skipped subject 10850 label 37
# KeyError: skipped subject 10855 label 37
# KeyError: skipped subject 10858 label 37
# KeyError: skipped subject 10894 label 37
# KeyError: skipped subject 10900 label 37
# KeyError: skipped subject 10942 label 37
# KeyError: skipped subject 10946 label 37
# KeyError: skipped subject 11030 label 37
# KeyError: skipped subject 11063 label 37
# KeyError: skipped subject 11136 label 37
# KeyError: skipped subject 11137 label 37
# KeyError: skipped subject 11139 label 37
# KeyError: skipped subject 11152 label 37
# KeyError: skipped subject 11184 label 37
# KeyError: skipped subject 11257 label 37
# KeyError: skipped subject 11264 label 37
# KeyError: skipped subject 11426 label 37
# KeyError: skipped subject 11478 label 37
# KeyError: skipped subject 11590 label 37
# KeyError: skipped subject 11620 label 37
# KeyError: skipped subject 11679 label 37
# KeyError: skipped subject 11686 label 37
# KeyError: skipped subject 11830 label 37
# KeyError: skipped subject 12138 label 37
# KeyError: skipped subject 12239 label 37
# KeyError: skipped subject 12279 label 37
# KeyError: skipped subject 12327 label 37
# KeyError: skipped subject 12624 label 37
# KeyError: skipped subject 12699 label 37
# KeyError: skipped subject 12767 label 37
# KeyError: skipped subject 12861 label 37
# KeyError: skipped subject 12904 label 37
# KeyError: skipped subject 13059 label 37
# KeyError: skipped subject 13061 label 37
# KeyError: skipped subject 13144 label 37
# KeyError: skipped subject 13169 label 37
# KeyError: skipped subject 13188 label 37
# KeyError: skipped subject 13214 label 37
# KeyError: skipped subject 13215 label 37
# KeyError: skipped subject 13217 label 37
# KeyError: skipped subject 13238 label 37
# KeyError: skipped subject 13242 label 37
# KeyError: skipped subject 13312 label 37
# KeyError: skipped subject 13367 label 37
# KeyError: skipped subject 21042 label 37
# KeyError: skipped subject 21057 label 37
# KeyError: skipped subject 21073 label 37
# KeyError: skipped subject 44068 label 37
# KeyError: skipped subject 44091 label 37
# KeyError: skipped subject 44094 label 37
# KeyError: skipped subject 44119 label 37
# KeyError: skipped subject 44141 label 37
# KeyError: skipped subject 44151 label 37
# KeyError: skipped subject 44723 label 37
# KeyError: skipped subject 55057 label 37
# KeyError: skipped subject 55152 label 37
# KeyError: skipped subject 55216 label 37
# KeyError: skipped subject 55297 label 37
# KeyError: skipped subject 55323 label 37
# KeyError: skipped subject 55370 label 37
# KeyError: skipped subject 55469 label 37
# KeyError: skipped subject 55778 label 37
# KeyError: skipped subject 66019 label 37
# KeyError: skipped subject 66030 label 37
# KeyError: skipped subject 66042 label 37
# KeyError: skipped subject 66048 label 37
# KeyError: skipped subject 66050 label 37
# KeyError: skipped subject 66128 label 37
# KeyError: skipped subject 66133 label 37
# KeyError: skipped subject 66141 label 37
# KeyError: skipped subject 66169 label 37
# KeyError: skipped subject 66183 label 37
# KeyError: skipped subject 66264 label 37
# KeyError: skipped subject 66267 label 37
# KeyError: skipped subject 66268 label 37
# KeyError: skipped subject 66293 label 37
# KeyError: skipped subject 66335 label 37
# KeyError: skipped subject 66361 label 37
# KeyError: skipped subject 66498 label 37
# KeyError: skipped subject 77024 label 37
# KeyError: skipped subject 77037 label 37
# KeyError: skipped subject 77076 label 37
# KeyError: skipped subject 77151 label 37
# KeyError: skipped subject 77175 label 37
# KeyError: skipped subject 77188 label 37
# KeyError: skipped subject 77252 label 37
# KeyError: skipped subject 77263 label 37
# KeyError: skipped subject 10016 label 37
# KeyError: skipped subject 10025 label 37
# KeyError: skipped subject 10026 label 37
# KeyError: skipped subject 10029 label 37
# KeyError: skipped subject 10034 label 37
# KeyError: skipped subject 10035 label 37
# KeyError: skipped subject 10051 label 37
# KeyError: skipped subject 10099 label 37
# KeyError: skipped subject 10106 label 37
# KeyError: skipped subject 10134 label 37
# KeyError: skipped subject 10160 label 37
# KeyError: skipped subject 10162 label 37
# KeyError: skipped subject 10225 label 37
# KeyError: skipped subject 10226 label 37
# KeyError: skipped subject 10259 label 37
# KeyError: skipped subject 10317 label 37
# KeyError: skipped subject 10319 label 37
# KeyError: skipped subject 10324 label 37
# KeyError: skipped subject 10333 label 37
# KeyError: skipped subject 10338 label 37
# KeyError: skipped subject 10346 label 37
# KeyError: skipped subject 10361 label 37
# KeyError: skipped subject 10362 label 37
# KeyError: skipped subject 10396 label 37
# KeyError: skipped subject 10397 label 37
# KeyError: skipped subject 10416 label 37
# KeyError: skipped subject 10418 label 37
# KeyError: skipped subject 10433 label 37
# KeyError: skipped subject 10436 label 37
# KeyError: skipped subject 10450 label 37
# KeyError: skipped subject 10453 label 37
# KeyError: skipped subject 10461 label 37
# KeyError: skipped subject 10482 label 37
# KeyError: skipped subject 10493 label 37
# KeyError: skipped subject 10504 label 37
# KeyError: skipped subject 10522 label 37
# KeyError: skipped subject 10538 label 37
# KeyError: skipped subject 10541 label 37
# KeyError: skipped subject 10550 label 37
# KeyError: skipped subject 10593 label 37
# KeyError: skipped subject 10634 label 37
# KeyError: skipped subject 10657 label 37
# KeyError: skipped subject 10696 label 37
# KeyError: skipped subject 10735 label 37
# KeyError: skipped subject 10741 label 37
# KeyError: skipped subject 10744 label 37
# KeyError: skipped subject 10750 label 37
# KeyError: skipped subject 10778 label 37
# KeyError: skipped subject 10787 label 37
# KeyError: skipped subject 10794 label 37
# KeyError: skipped subject 10811 label 37
# KeyError: skipped subject 10822 label 37
# KeyError: skipped subject 10846 label 37
# KeyError: skipped subject 10870 label 37
# KeyError: skipped subject 10881 label 37
# KeyError: skipped subject 10901 label 37
# KeyError: skipped subject 10944 label 37
# KeyError: skipped subject 10972 label 37
# KeyError: skipped subject 10988 label 37
# KeyError: skipped subject 11007 label 37
# KeyError: skipped subject 11012 label 37
# KeyError: skipped subject 11019 label 37
# KeyError: skipped subject 11054 label 37
# KeyError: skipped subject 11092 label 37
# KeyError: skipped subject 11127 label 37
# KeyError: skipped subject 11156 label 37
# KeyError: skipped subject 11196 label 37
# KeyError: skipped subject 11201 label 37
# KeyError: skipped subject 11219 label 37
# KeyError: skipped subject 11222 label 37
# KeyError: skipped subject 11245 label 37
# KeyError: skipped subject 11247 label 37
# KeyError: skipped subject 11254 label 37
# KeyError: skipped subject 11292 label 37
# KeyError: skipped subject 11323 label 37
# KeyError: skipped subject 11327 label 37
# KeyError: skipped subject 11355 label 37
# KeyError: skipped subject 11383 label 37
# KeyError: skipped subject 11415 label 37
# KeyError: skipped subject 11458 label 37
# KeyError: skipped subject 11461 label 37
# KeyError: skipped subject 11474 label 37
# KeyError: skipped subject 11481 label 37
# KeyError: skipped subject 11514 label 37
# KeyError: skipped subject 11552 label 37
# KeyError: skipped subject 11583 label 37
# KeyError: skipped subject 11630 label 37
# KeyError: skipped subject 11641 label 37
# KeyError: skipped subject 11747 label 37
# KeyError: skipped subject 11778 label 37
# KeyError: skipped subject 11850 label 37
# KeyError: skipped subject 11872 label 37
# KeyError: skipped subject 11937 label 37
# KeyError: skipped subject 11943 label 37
# KeyError: skipped subject 12056 label 37
# KeyError: skipped subject 12186 label 37
# KeyError: skipped subject 12269 label 37
# KeyError: skipped subject 12296 label 37
# KeyError: skipped subject 12379 label 37
# KeyError: skipped subject 12409 label 37
# KeyError: skipped subject 12548 label 37
# KeyError: skipped subject 12715 label 37
# KeyError: skipped subject 12724 label 37
# KeyError: skipped subject 12771 label 37
# KeyError: skipped subject 12778 label 37
# KeyError: skipped subject 12810 label 37
# KeyError: skipped subject 12812 label 37
# KeyError: skipped subject 12823 label 37
# KeyError: skipped subject 12858 label 37
# KeyError: skipped subject 12874 label 37
# KeyError: skipped subject 12878 label 37
# KeyError: skipped subject 12941 label 37
# KeyError: skipped subject 12947 label 37
# KeyError: skipped subject 12995 label 37
# KeyError: skipped subject 13019 label 37
# KeyError: skipped subject 13043 label 37
# KeyError: skipped subject 13049 label 37
# KeyError: skipped subject 13063 label 37
# KeyError: skipped subject 13105 label 37
# KeyError: skipped subject 13127 label 37
# KeyError: skipped subject 13151 label 37
# KeyError: skipped subject 13236 label 37
# KeyError: skipped subject 13268 label 37
# KeyError: skipped subject 13293 label 37
# KeyError: skipped subject 13309 label 37
# KeyError: skipped subject 13322 label 37
# KeyError: skipped subject 13417 label 37
# KeyError: skipped subject 21012 label 37
# KeyError: skipped subject 21051 label 37
# KeyError: skipped subject 21056 label 37
# KeyError: skipped subject 21084 label 37
# KeyError: skipped subject 44004 label 37
# KeyError: skipped subject 44043 label 37
# KeyError: skipped subject 44057 label 37
# KeyError: skipped subject 44147 label 37
# KeyError: skipped subject 44491 label 37
# KeyError: skipped subject 44632 label 37
# KeyError: skipped subject 55200 label 37
# KeyError: skipped subject 55483 label 37
# KeyError: skipped subject 55667 label 37
# KeyError: skipped subject 55708 label 37
# KeyError: skipped subject 55734 label 37
# KeyError: skipped subject 66017 label 37
# KeyError: skipped subject 66026 label 37
# KeyError: skipped subject 66039 label 37
# KeyError: skipped subject 66131 label 37
# KeyError: skipped subject 66162 label 37
# KeyError: skipped subject 66368 label 37
# KeyError: skipped subject 77027 label 37
# KeyError: skipped subject 77034 label 37
# KeyError: skipped subject 77040 label 37
# KeyError: skipped subject 77044 label 37
# KeyError: skipped subject 77056 label 37
# KeyError: skipped subject 77096 label 37
# KeyError: skipped subject 77117 label 37
# KeyError: skipped subject 77130 label 37
# KeyError: skipped subject 77140 label 37
# KeyError: skipped subject 77192 label 37
# KeyError: skipped subject 77217 label 37
# KeyError: skipped subject 77254 label 37
# KeyError: skipped subject 10065 label 37
# KeyError: skipped subject 10071 label 37
# KeyError: skipped subject 10096 label 37
# KeyError: skipped subject 10144 label 37
# KeyError: skipped subject 10180 label 37
# KeyError: skipped subject 10212 label 37
# KeyError: skipped subject 10298 label 37
# KeyError: skipped subject 10334 label 37
# KeyError: skipped subject 10367 label 37
# KeyError: skipped subject 10496 label 37
# KeyError: skipped subject 10515 label 37
# KeyError: skipped subject 10613 label 37
# KeyError: skipped subject 10701 label 37
# KeyError: skipped subject 11015 label 37
# KeyError: skipped subject 11042 label 37
# KeyError: skipped subject 11114 label 37
# KeyError: skipped subject 11213 label 37
# KeyError: skipped subject 11291 label 37
# KeyError: skipped subject 11540 label 37
# KeyError: skipped subject 11561 label 37
# KeyError: skipped subject 11592 label 37
# KeyError: skipped subject 11593 label 37
# KeyError: skipped subject 11646 label 37
# KeyError: skipped subject 11656 label 37
# KeyError: skipped subject 11687 label 37
# KeyError: skipped subject 11711 label 37
# KeyError: skipped subject 11796 label 37
# KeyError: skipped subject 11829 label 37
# KeyError: skipped subject 11874 label 37
# KeyError: skipped subject 11882 label 37
# KeyError: skipped subject 11939 label 37
# KeyError: skipped subject 12125 label 37
# KeyError: skipped subject 12133 label 37
# KeyError: skipped subject 12172 label 37
# KeyError: skipped subject 12271 label 37
# KeyError: skipped subject 12304 label 37
# KeyError: skipped subject 12308 label 37
# KeyError: skipped subject 12356 label 37
# KeyError: skipped subject 12391 label 37
# KeyError: skipped subject 12483 label 37
# KeyError: skipped subject 12502 label 37
# KeyError: skipped subject 12511 label 37
# KeyError: skipped subject 12582 label 37
# KeyError: skipped subject 12636 label 37
# KeyError: skipped subject 12711 label 37
# KeyError: skipped subject 12765 label 37
# KeyError: skipped subject 12785 label 37
# KeyError: skipped subject 12893 label 37
# KeyError: skipped subject 12963 label 37
# KeyError: skipped subject 12975 label 37
# KeyError: skipped subject 13083 label 37
# KeyError: skipped subject 13244 label 37
# KeyError: skipped subject 13306 label 37
# KeyError: skipped subject 13345 label 37
# KeyError: skipped subject 21039 label 37
# KeyError: skipped subject 21130 label 37
# KeyError: skipped subject 44229 label 37
# KeyError: skipped subject 44660 label 37
# KeyError: skipped subject 55388 label 37
# KeyError: skipped subject 55630 label 37
# KeyError: skipped subject 66085 label 37
# KeyError: skipped subject 66257 label 37
# KeyError: skipped subject 66309 label 37
# KeyError: skipped subject 77047 label 37
# KeyError: skipped subject 77179 label 37
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~xgrg/8.embed" height="525px" width="100%"></iframe>

# %%
order = 1
for i in range(1, 9):
    roivalues = collect_roivalues(i)
    df = data.join(roivalues)
    ycorr = pd.DataFrame(correct(df), columns=['roi'])
    df = data.join(ycorr)
    df['subject'] = df.index
    df = df.sort_values(['apo', 'subject']).dropna()
    formulas = ['roi ~ 1 + age'] #, 
    #        'roi ~ 1 + age + I(age**2)', 
    #        'roi ~ 1 + age + I(age**2) + I(age**3)']

    poly = ols(formula=formulas[0], data=df).fit()
    print poly.summary()
    
    break
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    roi   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     5.929
# Date:                Wed, 01 Feb 2017   Prob (F-statistic):             0.0152
# Time:                        18:22:24   Log-Likelihood:                 4294.9
# No. Observations:                 498   AIC:                            -8586.
# Df Residuals:                     496   BIC:                            -8577.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.0008   1.56e-05     49.838      0.000         0.001     0.001
# age         6.521e-07   2.68e-07      2.435      0.015      1.26e-07  1.18e-06
# ==============================================================================
# Omnibus:                       45.813   Durbin-Watson:                   2.164
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.742
# Skew:                           0.569   Prob(JB):                     3.97e-19
# Kurtosis:                       4.670   Cond. No.                         464.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py
subjects = json.load(open(osp.join('/home/grg/spm', 'data', 'subjects.json')))
data = pd.read_excel('/tmp/covariates.xls')
data['subject'] = data.index
data = data.sort_values(['apo', 'subject'])
plot_regions(data, labels=[71,72], do_correct=False, src='/home/grg/data/ALFA_DWI/*/DWI', filepattern='%s*AAL_MNI_MD_stats.csv',
             subjects=subjects, names={70:'Caudate_L', 71:'Caudate_R'}, ylim=None, nb_orders=3)
# Out:
# Intercept    0.000721
# age          0.000002
# dtype: float64

# %% [markdown]
# # Same plots using roicollect.py

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py
#subjects = json.load(open(osp.join('/home/grg/spm', 'data', 'subjects.json')))
data = pd.read_excel('/tmp/covariates.xls')
data['subject'] = data.index
data = data.sort_values(['apo', 'subject'])
src='/home/grg/data/ALFA_DWI/*/DWI'
filepattern='*AAL_MNI_MD_stats.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0][:5]) for e in csvfiles]
labels = [1,2,3,4,5,6,7,8]
names = ['coronaradiata', 'thalamus_R', 'orb_L', 'orb_R', 'hypothal_R', 'pons', 'thalamus_L', 'hypothal_L', 'unknown']
plot_regions(data, labels, do_correct=False, csvfiles=csvfiles, groups=['HO', 'All'],
             subjects=subjects, names=dict([(e, n) for e,n in zip(labels, names)]), ylim=[0.001, 0.003], nb_orders=3)
# Out:
# Standard deviation of label coronaradiata: 0.000222264850326
# Region: coronaradiata - Fitting order: 1 - Formula: roi ~ 1 + age
# Standard deviation of label coronaradiata: 0.000222264850326
# Region: coronaradiata - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Standard deviation of label coronaradiata: 0.000222264850326
# Region: coronaradiata - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# Standard deviation of label thalamus_R: 0.000226707029485
# Region: thalamus_R - Fitting order: 1 - Formula: roi ~ 1 + age
# Standard deviation of label thalamus_R: 0.000226707029485
# Region: thalamus_R - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Standard deviation of label thalamus_R: 0.000226707029485
# Region: thalamus_R - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# Standard deviation of label orb_L: 0.000245148095132
# Region: orb_L - Fitting order: 1 - Formula: roi ~ 1 + age
# Standard deviation of label orb_L: 0.000245148095132
# Region: orb_L - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Standard deviation of label orb_L: 0.000245148095132
# Region: orb_L - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# Standard deviation of label orb_R: 0.000243744664792
# Region: orb_R - Fitting order: 1 - Formula: roi ~ 1 + age
# Standard deviation of label orb_R: 0.000243744664792
# Region: orb_R - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Standard deviation of label orb_R: 0.000243744664792
# Region: orb_R - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# Standard deviation of label hypothal_R: 0.00020279046759
# Region: hypothal_R - Fitting order: 1 - Formula: roi ~ 1 + age
# Standard deviation of label hypothal_R: 0.00020279046759
# Region: hypothal_R - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Standard deviation of label hypothal_R: 0.00020279046759
# Region: hypothal_R - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# Standard deviation of label pons: 0.00019789704466
# Region: pons - Fitting order: 1 - Formula: roi ~ 1 + age
# Standard deviation of label pons: 0.00019789704466
# Region: pons - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Standard deviation of label pons: 0.00019789704466
# Region: pons - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# Standard deviation of label thalamus_L: 0.000218971104198
# Region: thalamus_L - Fitting order: 1 - Formula: roi ~ 1 + age
# Standard deviation of label thalamus_L: 0.000218971104198
# Region: thalamus_L - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Standard deviation of label thalamus_L: 0.000218971104198
# Region: thalamus_L - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
# Standard deviation of label hypothal_L: 0.000227012911994
# Region: hypothal_L - Fitting order: 1 - Formula: roi ~ 1 + age
# Standard deviation of label hypothal_L: 0.000227012911994
# Region: hypothal_L - Fitting order: 2 - Formula: roi ~ 1 + age + I(age**2)
# Standard deviation of label hypothal_L: 0.000227012911994
# Region: hypothal_L - Fitting order: 3 - Formula: roi ~ 1 + age + I(age**2) + I(age**3)
