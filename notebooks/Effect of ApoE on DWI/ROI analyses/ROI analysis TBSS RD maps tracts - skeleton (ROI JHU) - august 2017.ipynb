# %% [markdown]
# This plots ROI values extracted from images that have been normalized using DARTEL,
# but the values have been extracted from ROI derived from a prior analysis done using images normalized using DARTEL.

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
# %run /home/grg/git/alfa/roicollect.py
# Out:
# /home/grg/jupyter/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/grg/jupyter/local/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# This collect the values from \*\_stats.csv files, i.e. values that have been extracted from ROI manually drawn in MNI space.
# The bad thing with this is that the ROI is defined in a reference space. This is subject to individual registration errors.

# %%
#regions = [11,12,13,14] 
#regions = [15,16,19,20]
#regions = [5,6,7,8]
regions = range(1,21)
#for x in [9]: #,10,11,12,13]:
#    regions.remove(x)
names = {1: 'Anterior thalamic radiation L',
 2: 'Anterior thalamic radiation R',
 3: 'Corticospinal tract L',
 4: 'Corticospinal tract R',
 5: 'Cingulum (cingulate gyrus) L',
 6: 'Cingulum (cingulate gyrus) R',
 7: 'Cingulum (hippocampus) L',
 8: 'Cingulum (hippocampus) R',
 9: 'Forceps major',
 10: 'Forceps minor',
 11: 'Inferior fronto-occipital fasciculus L',
 12: 'Inferior fronto-occipital fasciculus R',
 13: 'Inferior longitudinal fasciculus L',
 14: 'Inferior longitudinal fasciculus R',
 15: 'Superior longitudinal fasciculus L',
 16: 'Superior longitudinal fasciculus R',
 17: 'Uncinate fasciculus L',
 18: 'Uncinate fasciculus R',
 19: 'Superior longitudinal fasciculus (temporal part) L',
 20: 'Superior longitudinal fasciculus (temporal part) R'}

data = pd.read_excel('/tmp/covariates.xlsx')
data = data.set_index(data['subject'])
data = data.sort_values(['apo', 'subject'])
src = '/tmp/roivalues_tracts_tbss_RD_skel/'
filepattern = '*_stats.csv'
csvfiles = glob(osp.join(src, filepattern))
subjects = [string.atoi(e.split('/')[-1].split('_')[0]) for e in csvfiles]

#import json
#j = json.load(open('/home/grg/spm/data/matched_groups.json'))
#subjects = []
#for each in j:
#    subjects.extend(each)
#csvfiles = []
#for s in subjects:
#    csvfp = glob(osp.join(src, '%s%s'%(s, filepattern)))[0]
#    csvfiles.append(csvfp)



values = collect_roivalues(3, csvfiles=csvfiles, subjects=subjects)

#data.join(values)
#poly = ols(formula='roi ~ 1 + age', data=data.join(values)).fit()
res = plot_regions(data, regions, csvfiles, subjects, groups=['HO','notHO'], by='apo', names=names,ylim=[0.0005,0.0008])
# Out:
# {1: 'Anterior thalamic radiation L', 2: 'Anterior thalamic radiation R', 3: 'Corticospinal tract L', 4: 'Corticospinal tract R', 5: 'Cingulum (cingulate gyrus) L', 6: 'Cingulum (cingulate gyrus) R', 7: 'Cingulum (hippocampus) L', 8: 'Cingulum (hippocampus) R', 9: 'Forceps major', 10: 'Forceps minor', 11: 'Inferior fronto-occipital fasciculus L', 12: 'Inferior fronto-occipital fasciculus R', 13: 'Inferior longitudinal fasciculus L', 14: 'Inferior longitudinal fasciculus R', 15: 'Superior longitudinal fasciculus L', 16: 'Superior longitudinal fasciculus R', 17: 'Uncinate fasciculus L', 18: 'Uncinate fasciculus R', 19: 'Superior longitudinal fasciculus (temporal part) L', 20: 'Superior longitudinal fasciculus (temporal part) R'}
# groups ['HO', 'notHO']
# Standard deviation of label Anterior thalamic radiation L: 7.76361606168e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.7047685793e-05
# Region: Anterior thalamic radiation L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.07302210877e-05
# 0.404125588391
# Standard deviation of label Anterior thalamic radiation R: 7.20136826763e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.11633642866e-05
# Region: Anterior thalamic radiation R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.79006165974e-05
# 0.20227483764
# Standard deviation of label Corticospinal tract L: 3.99180138663e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.99108913895e-05
# Region: Corticospinal tract L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.97629060716e-05
# 0.0337211083903
# Standard deviation of label Corticospinal tract R: 3.18222995306e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 3.18214282088e-05
# Region: Corticospinal tract R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.16807270962e-05
# 0.178937882351
# Standard deviation of label Cingulum (cingulate gyrus) L: 5.18157377358e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.07479249035e-05
# Region: Cingulum (cingulate gyrus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.96880227725e-05
# 0.0684712946396
# Standard deviation of label Cingulum (cingulate gyrus) R: 4.86555881499e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.77826688158e-05
# Region: Cingulum (cingulate gyrus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.62414563718e-05
# 0.0607037239531
# Standard deviation of label Cingulum (hippocampus) L: 6.29313740836e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 6.24443347927e-05
# Region: Cingulum (hippocampus) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 6.21144457843e-05
# 0.0832887283962
# Standard deviation of label Cingulum (hippocampus) R: 7.8500971123e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 7.80083360751e-05
# Region: Cingulum (hippocampus) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 7.80042885718e-05
# 0.0503712631405
# Standard deviation of label Forceps major: 5.40816177597e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.39044043429e-05
# Region: Forceps major
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.13430718538e-05
# 0.336098909902
# Standard deviation of label Forceps minor: 4.87171949224e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.86595525506e-05
# Region: Forceps minor
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.4729291773e-05
# 0.0852745668876
# Standard deviation of label Inferior fronto-occipital fasciculus L: 4.32364655427e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.31649431754e-05
# Region: Inferior fronto-occipital fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.12638464158e-05
# 0.00153731928909
# Standard deviation of label Inferior fronto-occipital fasciculus R: 4.47332783378e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.46312507598e-05
# Region: Inferior fronto-occipital fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.28804102233e-05
# 0.0119866083103
# Standard deviation of label Inferior longitudinal fasciculus L: 4.59735987773e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.595705924e-05
# Region: Inferior longitudinal fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.45876451226e-05
# 0.00709265374382
# Standard deviation of label Inferior longitudinal fasciculus R: 4.42187094269e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.39298191064e-05
# Region: Inferior longitudinal fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.2919040674e-05
# 0.00290411433211
# Standard deviation of label Superior longitudinal fasciculus L: 4.04620453013e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.04457712265e-05
# Region: Superior longitudinal fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 3.93367265751e-05
# 0.0161020371609
# Standard deviation of label Superior longitudinal fasciculus R: 4.05824232587e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.04126388125e-05
# Region: Superior longitudinal fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.02535767572e-05
# 0.0104035993566
# Standard deviation of label Uncinate fasciculus L: 4.42858853515e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 4.37508943959e-05
# Region: Uncinate fasciculus L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.29477558251e-05
# 0.403109829505
# Standard deviation of label Uncinate fasciculus R: 5.0143528823e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.01423435773e-05
# Region: Uncinate fasciculus R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 4.80244127687e-05
# 0.275501919935
# Standard deviation of label Superior longitudinal fasciculus (temporal part) L: 5.89341035901e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.85391570975e-05
# Region: Superior longitudinal fasciculus (temporal part) L
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.84510613006e-05
# 0.00183437434091
# Standard deviation of label Superior longitudinal fasciculus (temporal part) R: 5.29171525206e-05
# Model used for correction: roi ~ 1 + gender
# Standard deviation after correction for model roi ~ 1 + gender: 5.28932874689e-05
# Region: Superior longitudinal fasciculus (temporal part) R
# Model used for correction: roi ~ 1 + gender + age
# Standard deviation after correction for model roi ~ 1 + gender + age: 5.27294124102e-05
# 5.69773898721e-05

# %%
res
# Out:
#                                              roi_name  (HO, notHO)
# 0                       Anterior thalamic radiation L     0.404126
# 1                       Anterior thalamic radiation R     0.202275
# 2                               Corticospinal tract L     0.033721
# 3                               Corticospinal tract R     0.178938
# 4                        Cingulum (cingulate gyrus) L     0.068471
# 5                        Cingulum (cingulate gyrus) R     0.060704
# 6                            Cingulum (hippocampus) L     0.083289
# 7                            Cingulum (hippocampus) R     0.050371
# 8                                       Forceps major     0.336099
# 9                                       Forceps minor     0.085275
# 10             Inferior fronto-occipital fasciculus L     0.001537
# 11             Inferior fronto-occipital fasciculus R     0.011987
# 12                 Inferior longitudinal fasciculus L     0.007093
# 13                 Inferior longitudinal fasciculus R     0.002904
# 14                 Superior longitudinal fasciculus L     0.016102
# 15                 Superior longitudinal fasciculus R     0.010404
# 16                              Uncinate fasciculus L     0.403110
# 17                              Uncinate fasciculus R     0.275502
# 18  Superior longitudinal fasciculus (temporal par...     0.001834
# 19  Superior longitudinal fasciculus (temporal par...     0.000057

# %%
res.to_excel('/tmp/RD-labels-BSC-full-HOnotHO.xls')

# %%
pwd
# Out:
# u'/home/grg/git/alfa/notebooks/ROI analyses'
