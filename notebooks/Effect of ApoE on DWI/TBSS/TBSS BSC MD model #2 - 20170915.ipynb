# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/tmp/ALFA_20170915/data/stats'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'model2.con')).readlines() if 'ContrastName' in e]
for i in range(1, 9):
    plot_tbss(osp.join(wd, 'tbss_MD_model2_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -15, 43, row_l=6, step=2, title=tcon[i-1])
# Out:
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmpJj6291.png (Recessive(+))
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat2.nii.gz probably empty tbss map
# Saving to... /tmp/tmp4FrC5S.png (Recessive(-))
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat3.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat3.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat3.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat3.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat3.nii.gz probably empty tbss map
# Saving to... /tmp/tmpy2Qc6F.png (Dominant(+))
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat4.nii.gz probably empty tbss map
# Saving to... /tmp/tmpCzTydr.png (Dominant(-))
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat5.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat5.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat5.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat5.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat5.nii.gz probably empty tbss map
# Saving to... /tmp/tmpjmsQEf.png (Additive(+))
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat6.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat6.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat6.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat6.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat6.nii.gz probably empty tbss map
# Saving to... /tmp/tmppW3fhx.png (Additive(-))
# Saving to... /tmp/tmpnw6C5V.png (Gender(m>f))
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat8.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat8.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat8.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat8.nii.gz probably empty tbss map
# /tmp/ALFA_20170915/data/stats/tbss_MD_model2_tfce_corrp_tstat8.nii.gz probably empty tbss map
# Saving to... /tmp/tmpHSBE2R.png (Gender(f>m))
