# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/tbss_fmodel//stats/'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'design1.con')).readlines() if 'ContrastName' in e]
for i in range(1, 16):
    plot_tbss(osp.join(wd, 'tbss_RD_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), 1, 32, step=2, title=tcon[i-1])
# Out:
# Saving to... /tmp/tmpAoJJuA.png (Recessive(+))
# Saving to... /tmp/tmp3QBJi6.png (Recessive(-))
# Saving to... /tmp/tmpvF8fbi.png (Dominant(+))
# Saving to... /tmp/tmpjSOush.png (Dominant(-))
# Saving to... /tmp/tmpV8zU2f.png (Additive(+))
# Saving to... /tmp/tmpaqGbr_.png (Additive(-))
# Saving to... /tmp/tmp01jYAN.png (HO>HT)
# Saving to... /tmp/tmpQG68QC.png (HO<HT)
# Saving to... /tmp/tmpqwGC7A.png (HO>NC)
# Saving to... /tmp/tmp1XxNqf.png (HO<NC)
# Saving to... /tmp/tmpu3eZfP.png (HT>NC)
# Saving to... /tmp/tmpoDjXwX.png (HT<NC)
# Saving to... /tmp/tmpmVj9Bp.png (Age(+))
# Saving to... /tmp/tmpzDw6o6.png (Education(+))
# Saving to... /tmp/tmpUmOPmB.png (Gender(men>women))
