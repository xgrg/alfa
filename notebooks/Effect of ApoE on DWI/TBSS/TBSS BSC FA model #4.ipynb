# %%
# %run /home/grg/git/alfa/nilearn-helper.py
# %matplotlib inline
wd = '/home/grg/bsc_output/data/stats/'
tcon = [e.rstrip('\n').split(' ')[-1].strip('"').rstrip('"') for e in open(osp.join(wd, 'model4.con')).readlines() if 'ContrastName' in e]
for i in range(1, 11):
    plot_tbss(osp.join(wd, 'tbss_FA_model4_tfce_corrp_tstat%s.nii.gz'%i), osp.join(wd, 'mean_FA_skeleton.nii.gz'), -44, -4, axis='y', row_l=6, step=2, title=tcon[i-1])
# Out:
# /home/grg/bsc_output/data/stats/tbss_FA_model4_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/bsc_output/data/stats/tbss_FA_model4_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/bsc_output/data/stats/tbss_FA_model4_tfce_corrp_tstat1.nii.gz probably empty tbss map
# /home/grg/bsc_output/data/stats/tbss_FA_model4_tfce_corrp_tstat1.nii.gz probably empty tbss map
# Saving to... /tmp/tmppphm1L.png (Recessive(+))
# /home/grg/bsc_output/data/stats/tbss_FA_model4_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/bsc_output/data/stats/tbss_FA_model4_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/bsc_output/data/stats/tbss_FA_model4_tfce_corrp_tstat2.nii.gz probably empty tbss map
# /home/grg/bsc_output/data/stats/tbss_FA_model4_tfce_corrp_tstat2.nii.gz probably empty tbss map
# Saving to... /tmp/tmpU1orJy.png (Recessive(-))
# /home/grg/bsc_output/data/stats/tbss_FA_model4_tfce_corrp_tstat3.nii.gz probably empty tbss map
# ...
