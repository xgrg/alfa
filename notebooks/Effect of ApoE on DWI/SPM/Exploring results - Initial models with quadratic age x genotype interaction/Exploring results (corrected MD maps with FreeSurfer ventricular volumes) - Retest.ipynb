# %% [markdown]
# # Exploring results (corrected MD maps with FreeSurfer ventricular volumes) - Retest

# %%
# %run /home/grg/git/alfa/nilearn-helper.py
import sys
import pandas as pd
sys.path.append('/home/grg/git/alfa/')
import multireg_spm12 as mreg
# %matplotlib inline

# %%
paramtype = 'MD_corr'
analysis_name='dm_%s_fsvol'%paramtype
analysis_wd = osp.join('/home/grg/spm/analysis_20170109/', analysis_name)
spm = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))
aal_fp = '/usr/local/MATLAB/R2014a/toolbox/spm12/toolbox/aal/ROI_MNI_V5.nii'
mask_fp = '/home/grg/spm/MNI_T1_brain_mask.nii'
excel_fp = '/home/grg/spm/designmat/%s.xls'%analysis_name
print 'Found SPM files:', spm
# Out:
# Found SPM files: ['/home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/SPM.mat']

# %%
print 'Reading', excel_fp, 'looking up column', paramtype, '...'
a = mreg.generic_version(excel_fp, analysis_wd, mask_fp, analysis_name)
n1 = a.get_node('modeldesign')
n3 = a.get_node('estimatecontrasts')
print '# of scans included in the analysis:', len(n1.inputs.in_files)
display_html(pd.DataFrame([e for e in n3.inputs.contrasts], 
             columns=['contrast name', 'contrast type', 'covariate names', 'covariate weights']))
# Out:
# Reading /home/grg/spm/designmat/dm_MD_corr_fsvol.xls looking up column MD_corr ...
# Analysis name: dm_MD_corr_fsvol
# First column: MD_corr
# Columns in the model: [u'Apoe2-3', u'Apoe2-4', u'Apoe3-3', u'Apoe3-4', u'Apoe4-4', u'age23', u'age24', u'age33', u'age34', u'age44', u'agesq23', u'agesq24', u'agesq33', u'agesq34', u'agesq44', u'gender', u'educyears', u'ventricles_FS']
# Analysis name: dm_MD_corr_fsvol
# Scans (514): [u'/home/grg/spm/MD_corr/10070_MD_corr.nii', u'/home/grg/spm/MD_corr/10102_MD_corr.nii', u'/home/grg/spm/MD_corr/10108_MD_corr.nii', u'/home/grg/spm/MD_corr/10235_MD_corr.nii', u'/home/grg/spm/MD_corr/10365_MD_corr.nii', u'/home/grg/spm/MD_corr/10419_MD_corr.nii', u'/home/grg/spm/MD_corr/10463_MD_corr.nii', u'/home/grg/spm/MD_corr/10530_MD_corr.nii', u'/home/grg/spm/MD_corr/10551_MD_corr.nii', u'/home/grg/spm/MD_corr/10563_MD_corr.nii', u'/home/grg/spm/MD_corr/10576_MD_corr.nii', u'/home/grg/spm/MD_corr/10630_MD_corr.nii', u'/home/grg/spm/MD_corr/10668_MD_corr.nii', u'/home/grg/spm/MD_corr/10692_MD_corr.nii', u'/home/grg/spm/MD_corr/10693_MD_corr.nii', u'/home/grg/spm/MD_corr/10703_MD_corr.nii', u'/home/grg/spm/MD_corr/10725_MD_corr.nii', u'/home/grg/spm/MD_corr/10737_MD_corr.nii', u'/home/grg/spm/MD_corr/10756_MD_corr.nii', u'/home/grg/spm/MD_corr/10809_MD_corr.nii', u'/home/grg/spm/MD_corr/11045_MD_corr.nii', u'/home/grg/spm/MD_corr/11047_MD_corr.nii', u'/home/grg/spm/MD_corr/11048_MD_corr.nii', u'/home/grg/spm/MD_corr/11133_MD_corr.nii', u'/home/grg/spm/MD_corr/11180_MD_corr.nii', u'/home/grg/spm/MD_corr/11225_MD_corr.nii', u'/home/grg/spm/MD_corr/11262_MD_corr.nii', u'/home/grg/spm/MD_corr/11305_MD_corr.nii', u'/home/grg/spm/MD_corr/11351_MD_corr.nii', u'/home/grg/spm/MD_corr/11360_MD_corr.nii', u'/home/grg/spm/MD_corr/11387_MD_corr.nii', u'/home/grg/spm/MD_corr/11407_MD_corr.nii', u'/home/grg/spm/MD_corr/11414_MD_corr.nii', u'/home/grg/spm/MD_corr/11416_MD_corr.nii', u'/home/grg/spm/MD_corr/11550_MD_corr.nii', u'/home/grg/spm/MD_corr/11610_MD_corr.nii', u'/home/grg/spm/MD_corr/11614_MD_corr.nii', u'/home/grg/spm/MD_corr/11638_MD_corr.nii', u'/home/grg/spm/MD_corr/11658_MD_corr.nii', u'/home/grg/spm/MD_corr/11691_MD_corr.nii', u'/home/grg/spm/MD_corr/11721_MD_corr.nii', u'/home/grg/spm/MD_corr/11737_MD_corr.nii', u'/home/grg/spm/MD_corr/11768_MD_corr.nii', u'/home/grg/spm/MD_corr/11798_MD_corr.nii', u'/home/grg/spm/MD_corr/11803_MD_corr.nii', u'/home/grg/spm/MD_corr/11858_MD_corr.nii', u'/home/grg/spm/MD_corr/11902_MD_corr.nii', u'/home/grg/spm/MD_corr/11941_MD_corr.nii', u'/home/grg/spm/MD_corr/11975_MD_corr.nii', u'/home/grg/spm/MD_corr/11979_MD_corr.nii', u'/home/grg/spm/MD_corr/12032_MD_corr.nii', u'/home/grg/spm/MD_corr/12067_MD_corr.nii', u'/home/grg/spm/MD_corr/12079_MD_corr.nii', u'/home/grg/spm/MD_corr/12121_MD_corr.nii', u'/home/grg/spm/MD_corr/12140_MD_corr.nii', u'/home/grg/spm/MD_corr/12174_MD_corr.nii', u'/home/grg/spm/MD_corr/12244_MD_corr.nii', u'/home/grg/spm/MD_corr/12252_MD_corr.nii', u'/home/grg/spm/MD_corr/12323_MD_corr.nii', u'/home/grg/spm/MD_corr/12324_MD_corr.nii', u'/home/grg/spm/MD_corr/12331_MD_corr.nii', u'/home/grg/spm/MD_corr/12399_MD_corr.nii', u'/home/grg/spm/MD_corr/12425_MD_corr.nii', u'/home/grg/spm/MD_corr/12445_MD_corr.nii', u'/home/grg/spm/MD_corr/12479_MD_corr.nii', u'/home/grg/spm/MD_corr/12484_MD_corr.nii', u'/home/grg/spm/MD_corr/12493_MD_corr.nii', u'/home/grg/spm/MD_corr/12516_MD_corr.nii', u'/home/grg/spm/MD_corr/12637_MD_corr.nii', u'/home/grg/spm/MD_corr/12659_MD_corr.nii', u'/home/grg/spm/MD_corr/12730_MD_corr.nii', u'/home/grg/spm/MD_corr/12783_MD_corr.nii', u'/home/grg/spm/MD_corr/12787_MD_corr.nii', u'/home/grg/spm/MD_corr/12841_MD_corr.nii', u'/home/grg/spm/MD_corr/12920_MD_corr.nii', u'/home/grg/spm/MD_corr/12970_MD_corr.nii', u'/home/grg/spm/MD_corr/12976_MD_corr.nii', u'/home/grg/spm/MD_corr/13008_MD_corr.nii', u'/home/grg/spm/MD_corr/13035_MD_corr.nii', u'/home/grg/spm/MD_corr/13075_MD_corr.nii', u'/home/grg/spm/MD_corr/13090_MD_corr.nii', u'/home/grg/spm/MD_corr/13118_MD_corr.nii', u'/home/grg/spm/MD_corr/13138_MD_corr.nii', u'/home/grg/spm/MD_corr/13235_MD_corr.nii', u'/home/grg/spm/MD_corr/21092_MD_corr.nii', u'/home/grg/spm/MD_corr/44046_MD_corr.nii', u'/home/grg/spm/MD_corr/44205_MD_corr.nii', u'/home/grg/spm/MD_corr/55166_MD_corr.nii', u'/home/grg/spm/MD_corr/55529_MD_corr.nii', u'/home/grg/spm/MD_corr/55538_MD_corr.nii', u'/home/grg/spm/MD_corr/55 ...
# Vectors (18)
# Names (18): [u'Apoe2-3', u'Apoe2-4', u'Apoe3-3', u'Apoe3-4', u'Apoe4-4', u'age23', u'age24', u'age33', u'age34', u'age44', u'agesq23', u'agesq24', u'agesq33', u'agesq34', u'agesq44', u'gender', u'educyears', u'ventricles_FS']
# Contrasts (11): [('Apo2-3>Apo2-4', 'T', ['Apoe2-3', 'Apoe2-4'], [1, -1]), ('Apo2-4>Apo3-3', 'T', ['Apoe2-4', 'Apoe3-3'], [1, -1]), ('Apo3-3>Apo3-4', 'T', ['Apoe3-3', 'Apoe3-4'], [1, -1]), ('Apo3-4>Apo4-4', 'T', ['Apoe3-4', 'Apoe4-4'], [1, -1]), ('Main effect ApoE', 'F', [('Apo2-3>Apo2-4', 'T', ['Apoe2-3', 'Apoe2-4'], [1, -1]), ('Apo2-4>Apo3-3', 'T', ['Apoe2-4', 'Apoe3-3'], [1, -1]), ('Apo3-3>Apo3-4', 'T', ['Apoe3-3', 'Apoe3-4'], [1, -1]), ('Apo3-4>Apo4-4', 'T', ['Apoe3-4', 'Apoe4-4'], [1, -1])]), ('C<NC', 'T', ['Apoe2-3', 'Apoe2-4', 'Apoe3-3', 'Apoe3-4', 'Apoe4-4'], [3, -2, 3, -2, -2]), ('C>NC', 'T', ['Apoe2-3', 'Apoe2-4', 'Apoe3-3', 'Apoe3-4', 'Apoe4-4'], [-3, 2, -3, 2, 2]), ('HO<HZ', 'T', ['Apoe2-3', 'Apoe2-4', 'Apoe3-3', 'Apoe3-4', 'Apoe4-4'], [1, 1, 1, 1, -4]), ('HO>HZ', 'T', ['Apoe2-3', 'Apoe2-4', 'Apoe3-3', 'Apoe3-4', 'Apoe4-4'], [-1, -1, -1, -1, 4]), ('HO<All_Age_Squared', 'T', ['agesq23', 'agesq24', 'agesq33', 'agesq34', 'agesq44'], [3, -2, 3, -2, -2]), ('HO>All_Age_Squared', 'T', ['agesq23', 'agesq24', 'agesq33', 'agesq34', 'agesq44'], [-3, 2, -3, 2, 2])]
# # of scans included in the analysis: 514
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contrast name</th>
#       <th>contrast type</th>
#       <th>covariate names</th>
#       <th>covariate weights</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Apo2-3&gt;Apo2-4</td>
#       <td>T</td>
#       <td>[Apoe2-3, Apoe2-4]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Apo2-4&gt;Apo3-3</td>
#       <td>T</td>
#       <td>[Apoe2-4, Apoe3-3]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Apo3-3&gt;Apo3-4</td>
#       <td>T</td>
#       <td>[Apoe3-3, Apoe3-4]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Apo3-4&gt;Apo4-4</td>
#       <td>T</td>
#       <td>[Apoe3-4, Apoe4-4]</td>
#       <td>[1.0, -1.0]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Main effect ApoE</td>
#       <td>F</td>
#       <td>[(Apo2-3&gt;Apo2-4, T, [Apoe2-3, Apoe2-4], [1.0, ...</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>C&lt;NC</td>
#       <td>T</td>
#       <td>[Apoe2-3, Apoe2-4, Apoe3-3, Apoe3-4, Apoe4-4]</td>
#       <td>[3.0, -2.0, 3.0, -2.0, -2.0]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>C&gt;NC</td>
#       <td>T</td>
#       <td>[Apoe2-3, Apoe2-4, Apoe3-3, Apoe3-4, Apoe4-4]</td>
#       <td>[-3.0, 2.0, -3.0, 2.0, 2.0]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>HO&lt;HZ</td>
#       <td>T</td>
#       <td>[Apoe2-3, Apoe2-4, Apoe3-3, Apoe3-4, Apoe4-4]</td>
#       <td>[1.0, 1.0, 1.0, 1.0, -4.0]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>HO&gt;HZ</td>
#       <td>T</td>
#       <td>[Apoe2-3, Apoe2-4, Apoe3-3, Apoe3-4, Apoe4-4]</td>
#       <td>[-1.0, -1.0, -1.0, -1.0, 4.0]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>HO&lt;All_Age_Squared</td>
#       <td>T</td>
#       <td>[agesq23, agesq24, agesq33, agesq34, agesq44]</td>
#       <td>[3.0, -2.0, 3.0, -2.0, -2.0]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>HO&gt;All_Age_Squared</td>
#       <td>T</td>
#       <td>[agesq23, agesq24, agesq33, agesq34, agesq44]</td>
#       <td>[-3.0, 2.0, -3.0, 2.0, 2.0]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
spm_mat_file = glob(osp.join(analysis_wd, 'estimatecontrasts/SPM.mat'))[0]
for i in range(6, 12):
    img = osp.join(analysis_wd, 'estimatecontrasts/spmT_00%02d.nii'%i)
    print img
    contrast_name = n3.inputs.contrasts[i-1][0]
    thresholded_map1, threshold1 = map_threshold(img, threshold=0.001, cluster_threshold=0)
    plotting.plot_glass_brain(thresholded_map1,
                      title='(%s) %s - T>%.02f - p<0.001 (uncor.)'%(paramtype, contrast_name, threshold1), colorbar=True,
                      black_bg=True, display_mode='ortho', threshold=threshold1)  
plotting.show()
# Out:
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0006.nii
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0007.nii
# /home/grg/jupyter/local/lib/python2.7/site-packages/nilearn/plotting/displays.py:656: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0008.nii
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0009.nii
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0010.nii
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0011.nii

# %%
for i in range(6, 12):
    img = osp.join(analysis_wd, 'estimatecontrasts/spmT_00%02d.nii'%i)
    print img
    contrast_name = n3.inputs.contrasts[i-1][0]
    thresholded_map1, threshold1 = map_threshold(img, threshold=0.001, cluster_threshold=0)

    plot_stat_map(thresholded_map1, threshold=threshold1, row_l=8, start=-32, end=34, step=2,
                  title= '(%s) %s - T>%.02f - p<0.001 (uncor.)'%(paramtype, contrast_name, threshold1))
        
plotting.show()
# Out:
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0006.nii
# Saving to... /tmp/tmp4gK5n8.png
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0007.nii
# Saving to... /tmp/tmpiM55lU.png
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0008.nii
# Saving to... /tmp/tmpkycfV9.png
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0009.nii
# Saving to... /tmp/tmpRaoYtx.png
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0010.nii
# Saving to... /tmp/tmpUdUWOF.png
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0011.nii
# Saving to... /tmp/tmpTlCTcw.png

# %%
sys.path.append('/home/grg/git/pyAAL/')
import pyAAL
reload(pyAAL)
print spm_mat_file

out = pyAAL.pyAAL(spm_mat_file, 6, mode=2)
pyAAL.to_dataframe(out)
# Out:
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/SPM.mat
# creating tempfile /tmp/tmp130btr.m
# matlab -nodisplay -nodesktop -nosplash -nojvm -r "addpath('/home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts');run('/tmp/tmp130btr');quit"
#
# Contrast: C<NC
#      x,y,z {mm}          nom du label % Cluster Nb Vx Cluster % Label  \
# 0   -14  16 -14           Olfactory_L     47.81           638  108.93
# 1   -14  16 -14              OFCmed_L     17.87           638   20.73
# 2   -14  16 -14     Frontal_Med_Orb_L     17.08           638   15.16
# 3   -14  16 -14             OFCpost_L     10.66           638   11.99
# 4   -14  16 -14             Caudate_L      3.29           638    2.18
# 5   -14  16 -14            Thalamus_L      2.35           638    1.36
# 6   -14  16 -14              Rectus_L      0.16           638    0.12
# 7   -14  16 -14               OUTSIDE      0.16           638    0.00
# 8   -14 -38  54  Paracentral_Lobule_L     43.48            69    2.22
# 9   -14 -38  54       Cingulate_Mid_L     27.54            69    0.98
# 10  -14 -38  54           Precuneus_L     21.74            69    0.43
# 11  -14 -38  54               OUTSIDE      1.45            69    0.00
# 12   26 -16  32               OUTSIDE      0.72           139    0.00
# 13  -12  34  32       Cingulate_Ant_L     76.09            46    2.50
# 14  -12  34  32  Frontal_Sup_Medial_L     13.04            46    0.20
# 15  -12  34  32       Frontal_Sup_2_L      6.52            46    0.06
# 16  -12  34  32               OUTSIDE      2.17            46    0.00
# 17   10 -86   0           Calcarine_R      4.35            23    0.05
# 18   10  18 -12              OFCmed_R     58.97            78    7.41
# 19   10  18 -12     Frontal_Med_Orb_R     16.67            78    1.52
# 20   10  18 -12           Olfactory_R      8.97            78    2.42
# 21   10  18 -12             Caudate_R      3.85            78    0.30
# 22   10  18 -12             OFCpost_R      2.56            78    0.36
# 23   10  18 -12              Rectus_R      1.28            78    0.13
# 24   10  18 -12               OUTSIDE      1.28            78    0.00
# 25   50  24   8     Frontal_Inf_Tri_R      6.67            15    0.05
# 26  -62 -50  10        Temporal_Mid_L      6.25            16    0.02
# 27   46   8 -28   Temporal_Pole_Mid_R     18.75            16    0.25
# 28   46   8 -28        Temporal_Mid_R      6.25            16    0.02
# 29   46   8 -28   Temporal_Pole_Sup_R      6.25            16    0.07
# 30  -46 -38   2        Temporal_Mid_L     41.67            24    0.20
# 31  -46 -38   2               OUTSIDE      4.17            24    0.00
# 32  -48   2  20       Rolandic_Oper_L     93.10            29    2.73
# 33  -48   2  20          Precentral_L      3.45            29    0.03
# 34  -20  -6  10             Putamen_L     66.67            15    0.99
# 35  -20  -6  10               OUTSIDE      6.67            15    0.00
# 36  -14 -48  22      Cingulate_Post_L     90.48            42    8.21
# 37  -14 -48  22           Calcarine_L      4.76            42    0.09
# 38  -14 -48  22               OUTSIDE      2.38            42    0.00
# 39    2  34 -12       Cingulate_Ant_R     63.64            22    1.07
# 40    2  34 -12     Frontal_Med_Orb_R     13.64            22    0.35
# 41    2  34 -12     Frontal_Med_Orb_L      4.55            22    0.14
# 42    8   0 -12               OUTSIDE      7.69            13    0.00
#
#    Nb Vx Label
# 0          280
# 1          550
# 2          719
# 3          567
# 4          962
# 5         1100
# 6          852
# 7            0
# 8         1349
# 9         1941
# 10        3528
# 11           0
# 12           0
# 13        1400
# 14        2992
# 15        4873
# 16           0
# 17        1861
# 18         621
# 19         856
# 20         289
# 21         994
# 22         561
# 23         745
# 24           0
# 25        2151
# 26        4942
# 27        1187
# 28        4409
# 29        1338
# 30        4942
# 31           0
# 32         990
# 33        3526
# 34        1009
# 35           0
# 36         463
# 37        2258
# 38           0
# 39        1313
# 40         856
# 41         719
# 42           0

# %%
i=6
img = osp.join(analysis_wd, 'estimatecontrasts/spmT_00%02d.nii'%i)
print img
contrast_name = n3.inputs.contrasts[i-1][0]
thresholded_map1, threshold1 = map_threshold(img, threshold=0.001, cluster_threshold=0)

plot_stat_map(thresholded_map1, threshold=threshold1, row_l=8, start=28, end=34, step=2,
              title= '') #(%s) %s - T>%.02f - p<0.001 (uncor.)'%(paramtype, contrast_name, threshold1))
# Out:
# /home/grg/spm/analysis_20170109/dm_MD_corr_fsvol/estimatecontrasts/spmT_0006.nii
# Saving to... /tmp/tmpjswiyh.png
